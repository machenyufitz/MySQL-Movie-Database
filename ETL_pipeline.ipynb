# %% [markdown]
# # Intro
#
# This script builds a database of film metadata from a list of IMDB Film IDs supplied by the user.  It is structured as an ETL pipeline:
#
# * The **Extract** stage takes the raw data from IMDB.  At the end of this stage, raw data is stored as a list-of-lists.
# * The **Transform** stage normalizes the data from IMDB.  At the end of this stage, each table entry is complete and stored as a dictionary where the keys are column names.
# * The **Load** Stage outputs a series of SQL INSERT statements.
#
# ## Intro: Dependencies and Script Parameters

# %%
import requests
import re
from bs4 import BeautifulSoup

# If the VERBOSE flag is set, then intermediate steps in the data pipeline will be shown.
VERBOSE = True

# This is the input - a list of imdb IDs for the films that will compose the database.
imdb_ids  =  ['tt0859635', 'tt0486551', 'tt0331953', 'tt0456554', 'tt1135525', 'tt0245686', 
              'tt0114694', 'tt0115697', 'tt0144557', 'tt0348333', 'tt0366551', #one invalid in this row
              'tt0069239', 'tt0077914', 'tt0455407', 'tt0166843', 'tt0095652', 'tt1134854', 
              'tt0088993', 'tt0082622', 'tt0077402', 'tt0848557', 'tt0067341', 'tt0418819', 
              'tt0119177', 'tt0253556', 'tt0119116', 'tt0448134', 'tt0361862', 'tt0118929', 
              'tt1182345', 'tt0118884', 'tt0462504', 'tt0381849', 'tt0433387', 'tt0114746']

# %% [markdown]
# ## Intro: Helper functions
#
# These (mostly pretty simple) functions help the ETL pipeline below, but are not directly related to its logic, so are placed here to help the later sections of code flow better.  There are no dependencies among the helper functions, so they are in alphabetical order.

# %%
# find_the_money( s)
# find_the_time( s)
#
# These functions search the text string s for a
# dollar or minute value and return the corresponding
# quantity as an integer
#
def find_the_money( s):
    dollar_amounts = re.findall(r'\$[0-9,]+', s)
    for d in dollar_amounts:
        return int(d[1:].replace(',', ''))
    return None
    
    
def find_the_time( s):
    minute_amounts = re.findall(r'[0-9]+ min', s)
    for m in minute_amounts:
        return int(m[:-4])
    return None

# print_dd(  name, dd )
# print_lol( name, lol)
# print_section_header( s)
#
# These functions nicely print out either a data dictionary,
# a list-of-lists, or a fancy section header,
# Used for VERBOSE mode

def print_dd( name, dd):
    print(f'{name}\n' + '-'*len(name))
    for k, v in dd.items():
        print( f'\t{k}\t:\t{v}') 

def print_lol( name, lol):
    print(f'{name}\n' + '-'*len(name))        
    for l in lol:
            print('\t'+str(l))       

def print_section_header( s):
    fancy_title  = f'||     {s}     ||'
    fancy_break = '||' + ' '*(len(fancy_title) - 4) + '||'
    fancy_line = '=' * len(fancy_title) 
    print( '\n'.join([
        fancy_line, 
        fancy_break,
        fancy_title, 
        fancy_break,
        fancy_line
    ]))

# search_in_soup
# Looks inside of soup for a BeautifulSoup object wih
# a base tag of tag_type containing search_text,
# and returns the first success.
# 
def search_in_soup(soup, tag_type, search_text):
    candidates = soup.find_all(tag_type)
    
    for c in candidates:
        tag_text = c.text
        if re.search(search_text, tag_text):
            return c
    return None

# sql_insert_from_dd
# Generates the SQL statement to load the data dictionary dd
# into a table named table_name.
#
def sql_insert_from_dd( table_name, dd):
    return_string = f'INSERT INTO {table_name}'
    k_s = []
    v_s = []
    for k, v in dd.items():
        k_s.append(k)
        if isinstance( v, str):
            v_s.append( f'"{v}"')
        elif v == None:
            v_s.append('Null')
        else:
            v_s.append(str(v))
    return f'{return_string} ({", ".join(k_s)}) VALUES ({", ".join(v_s)});'
 
# text_field_s
# text_field_m
# text_field_l
#
# Short, medium, and long text fields.
# Truncate to the appropriate length and
# replace all ' with "
#
def text_field(s, l):
    TEXT_LENGTH = l
    t = s.lstrip().replace( '"', "'")
    if len(t) > TEXT_LENGTH:
        t = t[:TEXT_LENGTH-3] + '...'
    return t 

def text_field_l(s):
    return text_field(s, 400)

def text_field_m(s):
    return text_field(s, 200)

def text_field_s(s):
    return text_field(s, 45)

# %% [markdown]
# # Extract
# ## Extract: the main metadata extraction script

# %%
def scrape_all_metadata(imdb_id):
    movie_dd = scrape_movie_info(imdb_id)
    
    all_lols = { # lol for list-of-lists
        "Tagline" : scrape_taglines(imdb_id), 
        "Quote"   : scrape_quotes(imdb_id),
        "Summary": scrape_summaries(imdb_id),
        
        "Production": scrape_production_info(imdb_id),
        "Genre": scrape_genres(imdb_id),
        "Person": scrape_cast(imdb_id),
    }
    cast_we_care_about = get_cast_names( imdb_id)
    all_lols["Award"] = scrape_awards( imdb_id, cast_we_care_about)
    
    return movie_dd, all_lols

# %% [markdown]
# ## Extract: information from the main IMDB page

# %%
def scrape_movie_info(imdb_id):
    imdb_url =  f"https://www.imdb.com/title/{imdb_id}/"
    r       =   requests.get(imdb_url)
    soup    =   BeautifulSoup(r.text, 'html.parser')
    title_div = soup.find('div', class_='title_wrapper')
    
    movie_dd = {}
    movie_dd['movie_id'] = imdb_id
    
    title_div = soup.find('div', class_='title_wrapper')
    title_and_year = title_div.h1.text

    try:
        movie_year = int(title_and_year[-6:-2])
    except:
        movie_year = None
    movie_dd['movie_year'] = movie_year
    
    movie_title = title_and_year[:-8]
    movie_dd['movie_title'] = text_field_m(movie_title)
    
    details_div = soup.find('div', id='titleDetails')
    try:
        budget_div  = search_in_soup( details_div, 'div', 'Budget')
        budget = find_the_money(budget_div.text)
    except:
        budget = None
    movie_dd['movie_budget']     = budget  
    
    try:
        boxOffice_div  = search_in_soup( details_div, 'div', 'Cumulative Worldwide Gross')
        boxOffice = find_the_money(boxOffice_div.text)
    except:
        boxOffice = None
    movie_dd['movie_boxoffice'] = boxOffice
    
    runtime_div = search_in_soup( details_div, 'div', 'Runtime')
    runtime = find_the_time( runtime_div.text)
    movie_dd['movie_runtime'] = runtime
    
    return movie_dd

# %%
def scrape_genres(imdb_id):
    imdb_url =  f"https://www.imdb.com/title/{imdb_id}/"
    r       =   requests.get(imdb_url)
    soup    =   BeautifulSoup(r.text, 'html.parser')
    
    storyline_div = soup.find('div', id='titleStoryLine')
    genres_div  = search_in_soup( storyline_div, 'div', 'Genre')
    genre_links = genres_div.find_all('a')

    return_list = []
    for l in genre_links:
        genre_item = [imdb_id, text_field_s(l.text)]
        if genre_item not in return_list:
            return_list.append(genre_item)

    return return_list

# %% [markdown]
# ## Extract: a single text field from a single page

# %%
def scrape_taglines(imdb_id):

    # web setup
    full_link = 'https://www.imdb.com/title/' + imdb_id + '/taglines?ref_=tt_stry_tg'

    source = requests.get(full_link).text
    soup = BeautifulSoup(source, 'html.parser')

    # list of all attributes
    soda_lst = soup.find_all('div', class_='soda odd')

    # tagline
    tagline_lst = list(soda_lst)
    real_lst = []

    # creating lists
    for line in range(2):
        try:
            real_lst.append([imdb_id, text_field_m(tagline_lst[line].text.strip())])
        except:
            pass

    return real_lst


def scrape_quotes(imdb_id):

    # web setup
    full_link = 'https://www.imdb.com/title/' + imdb_id + '/quotes/?tab=qt&ref_=tt_trv_qu'

    source = requests.get(full_link).text
    soup = BeautifulSoup(source, 'html.parser')

    # list of all attributes
    l_lst = soup.find('div', class_='list')

    # quotes
    quote_lst = list(l_lst)
    real_quote = []

    for quote in range(4):
        try:
            real_quote.append([imdb_id, text_field_l(quote_lst[quote].find('div', class_='sodatext').text)])
        except:
            pass

    return real_quote


def scrape_summaries(imdb_id):

    # web setup
    full_link = 'https://www.imdb.com/title/' + imdb_id + '/plotsummary?ref_=tt_stry_pl'

    source = requests.get(full_link).text
    soup = BeautifulSoup(source, 'html.parser')

    # list of attributes
    zebra = soup.find('ul', class_='ipl-zebra-list')
    zebra_lst = zebra.find_all('li', class_='ipl-zebra-list__item')

    # summaries
    sum_lst = list(zebra_lst)
    real_lst = []

    for line in range(2):
        try:
            real_lst.append([imdb_id, text_field_l(sum_lst[line].text.strip())])
        except:
            pass

    return real_lst


def scrape_production_info(imdb_id):
    # web setup
    full_link = 'https://www.imdb.com/title/' + imdb_id + '/companycredits?ref_=ttfc_ql_4'

    source = requests.get(full_link).text
    soup = BeautifulSoup(source, 'html.parser')

    # list with all attributes
    simple_lst = soup.find_all('ul', class_='simpleList')

    # production companies
    production_lst = list(simple_lst[0])
    real_lst = []

    # creating lists
    for tag in range(len(production_lst)):
        try:
            prod_item = [imdb_id, text_field_s(production_lst[tag].a.text)]
            if prod_item not in real_lst:
                real_lst.append(prod_item)
        except:
            pass

    return real_lst

# %% [markdown]
# # Extract: cast and awards

# %%
def scrape_cast(imdb_id):
    url = "https://www.imdb.com/title/" + "imdb_id"
    casts = []
    names = get_cast_names(imdb_id)
    check = 0
    stop = len(names)
    while check < stop:
        if check == 0 or check == 1:
            casts.append([imdb_id, check, text_field_s(names[check])])
            check += 1
        else:
            casts.append([imdb_id, 2, text_field_s(names[check])])
            check += 1
    return casts

def get_cast_names(imdb_id):
    url = "https://www.imdb.com/title/" + imdb_id
    names = []
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    out = soup.find_all('div', class_='credit_summary_item')
    directors = out[0].text.split()
    director = directors[1] + ' ' + directors[2]
    names.append(text_field_s(director))
    writers = out[1].text.split()
    writer = writers[1] + ' ' + writers[2]
    names.append(text_field_s(writer))
    stars = out[2].text.split('|')[0].split('\n')[2].split(',')
    for i in stars:
        if i not in names:
            names.append(text_field_s(i))
    return names

def scrape_awards(imdb_id, important):
    results = []
    awd_url = "https://www.imdb.com/title/" + imdb_id + "/awards"
    awd_r = requests.get(awd_url)
    awd_soup = BeautifulSoup(awd_r.text, 'html.parser')
  
    awd_out = awd_soup.find_all('table', class_='awards')
    #print(len(awd_out))
    awards = {}
    for block in awd_out:
        text = block.text.split(' '*6)
        text = [i for i in text if i !='']
        #print(text)
        prefix = [i for i in text[0].split('\n') if i != '']
        prefix = ' '.join([str(elem) for elem in prefix[::-1]])
        for i in text[1:]:
            record = [j for j in i.split('\n') if j != '']
            if len(record) > 0:
                suffix = record[0]
                award = prefix + ': ' + suffix
                people = tuple(record[1:])
                awards[people] = award
    #print(awards)
    results = []
    for p in important:
        if len(results) == 3:
            return results
        for k,v in awards.items():
            if p in k:
                results.append([imdb_id, p, text_field_m(v)])
                break
    
    if len(results) < 1:
        for k, v in awards.items():
            if k not in important:
                results.append([imdb_id, None, text_field_m(v)])
    
    return results

# %%
imdb_id = 'tt0859635'
cast_we_care_about = get_cast_names( imdb_id)

print(cast_we_care_about)
print( scrape_awards(imdb_id, cast_we_care_about ))
# Out:
# ['Jay Chandrasekhar', 'Jay Chandrasekhar', 'Kevin Heffernan', 'Steve Lemme ']
# [['tt0859635', None, 'Golden Trailer Nominee: Best Radio/Audio Spot'], ['tt0859635', None, 'Golden Trailer Winner: Best Teaser Poster'], ['tt0859635', None, 'Golden Trailer Winner: Best Trailerbyte for a Feature Film']]

# %% [markdown]
# ## Extract: extraction loop

# %%
ready_to_load = {}
ready_to_load['Movie'] = []

raw_data = {
    "Tagline"   : [],
    "Quote"   : [],
    "Summary": [],
    "Production": [],
    "Genre": [],
    "Person": [],    
    "Award": []
}

for id in imdb_ids:
    print(f'Scraping from {id}...')
    movie_dd, lols = scrape_all_metadata(id)
    
    ready_to_load['Movie'].append(movie_dd)
    
    for name, lol in lols.items():
        try:
            raw_data[name].extend(lol) 
        except:
            pass
# Out:
# Scraping from tt0859635...
# Scraping from tt0486551...
# Scraping from tt0331953...
# Scraping from tt0456554...
# Scraping from tt1135525...
# Scraping from tt0245686...
# Scraping from tt0114694...
# Scraping from tt0115697...
# Scraping from tt0144557...
# Scraping from tt0348333...
# Scraping from tt0366551...
# Scraping from tt0069239...
# Scraping from tt0077914...
# Scraping from tt0455407...
# Scraping from tt0166843...
# Scraping from tt0095652...
# Scraping from tt1134854...
# Scraping from tt0088993...
# Scraping from tt0082622...
# Scraping from tt0077402...
# Scraping from tt0848557...
# Scraping from tt0067341...
# Scraping from tt0418819...
# Scraping from tt0119177...
# Scraping from tt0253556...
# Scraping from tt0119116...
# Scraping from tt0448134...
# Scraping from tt0361862...
# Scraping from tt0118929...
# Scraping from tt1182345...
# Scraping from tt0118884...
# Scraping from tt0462504...
# Scraping from tt0381849...
# Scraping from tt0433387...
# Scraping from tt0114746...

# %%
if VERBOSE:
    print( "There is no list-of-lists for the Movie table; that data is already in the finalized data dict.\n")
    for name, lol in raw_data.items():
        print_lol(name, lol)
# Out:
# There is no list-of-lists for the Movie table; that data is already in the finalized data dict.
#
# Tagline
# -------
# 	['tt0859635', 'The time is meow.']
# 	['tt0859635', "Don't Miss It!"]
# 	['tt0486551', "Bring on the beer. They've got the nuts."]
# 	['tt0486551', 'Comedy on tap']
# 	['tt0331953', 'A vacation to die for.']
# 	['tt0331953', 'Sun, Sea, Sex and Slaughter (Ireland DVD)']
# 	['tt0456554', 'Sex. Drugs. Nakedness. Rude language... And proud of it!']
# 	['tt1135525', "Bring a bib, it's gonna get messy"]
# 	['tt0245686', "Keep on Moppin' in the Free world."]
# 	['tt0245686', 'He Came. He Cleaned. He Conquered']
# 	['tt0114694', "If at first you don't succeed, lower your standards."]
# 	['tt0115697', "There's one in every family."]
# 	['tt0348333', 'Hungry for Laughs? (DVD)']
# 	['tt0348333', 'A comedy of massive portions']
# 	['tt0366551', 'Fast Food. High Times.']
# 	['tt0069239', 'Caviar in the kitchen - nothing in the bedroom']
# 	['tt0069239', "first NIGHT OF THE LIVING DEAD then DAWN OF THE DEAD - NOW George A. Romero's [Season of the Witch]"]
# 	['tt0077914', 'A Vampire for Our Age of Disbelief']
# 	['tt0077914', "See It with Someone You're Sure of..."]
# 	['tt0455407', 'Fear Thy Neighbor']
# 	['tt0455407', 'Welcome to Ogden Marsh, the friendliest place on earth']
# 	['tt0166843', "There's more to love than just moving in"]
# 	['tt0166843', 'Every woman knows why the wrong man is irresistible!']
# 	['tt0095652', 'A man trapped within his own body. An animal trained to read and carry out thoughts. One with a mind for revenge. The other with an instinct for carrying out that revenge.']
# 	['tt0095652', 'See no evil...hear no evil...speak no evil...think no evil.']
# 	['tt1134854', "Death isn't what it used to be."]
# 	['tt0088993', 'The Dead have waited. The day has come.']
# 	['tt0088993', 'Now life has become a NIGHTMARE!']
# 	['tt0082622', 'From the Master of Action and Suspense!']
# 	['tt0082622', 'Ride to live. Live to die.']
# 	['tt0077402', "George A. Romero's classic 1978 gore-fest, Dawn of the Dead, is back."]
# 	['tt0077402', "First there was 'NIGHT OF THE LIVING DEAD'... Now GEORGE A. ROMERO'S [Dawn of the Dead]"]
# 	['tt0848557', 'Shoot the dead.']
# 	['tt0848557', 'Where will you be when the end begins?']
# 	['tt0067341', 'Something is after Jessica. Something very cold, very wet... and very dead...']
# 	['tt0418819', 'The dead shall inherit the Earth.']
# 	['tt0418819', 'Rise of the Zombies']
# 	['tt0119177', 'The Prisoner. His Cell.']
# 	['tt0119177', 'A life is a dangerous thing to share.']
# 	['tt0253556', 'Fight Fire With Fire']
# 	['tt0253556', "They're extremely intelligent. Highly evolved. And they don't like sharing the planet."]
# 	['tt0119116', 'It Mu5t Be Found.']
# 	['tt0119116', '250 years in the future, all will be lost unless the fifth element is found.']
# 	['tt0448134', 'Dark days are coming.']
# 	['tt0448134', 'If it dies, so do we.']
# 	['tt0361862', "How do you wake up from a nightmare, if you're not asleep?"]
# 	['tt0361862', 'A little guilt goes a long way...']
# 	['tt0118929', 'They built the city to see what makes us tick. Last night one of us went off.']
# 	['tt0118929', 'Darkness Falls Soon']
# 	['tt1182345', "The last place you'd ever expect to find yourself"]
# 	['tt0118884', 'Get ready to take a chance on something that just might end up being the most profoundly impactful moment for humanity, for the history... of history.']
# 	['tt0118884', 'A message from deep space. Who will be the first to go? A journey to the heart of the universe.']
# 	['tt0462504', 'A true story of survival... declassified.']
# 	['tt0462504', "Based on the extraordinary true story of one man's fight for freedom"]
# 	['tt0381849', 'Time waits for one man']
# 	['tt0114746', 'The future is history.']
# Quote
# -----
# 	['tt0859635', 'Genevieve Aubois:\nI coach a girls hockey team so I know my way around a gash.  ']
# 	['tt0859635', "Guy LeFranc:\nGreat Tim Horton's ghost!  "]
# 	['tt0486551', 'Barry Badrinath:\nI wish it were winter so we could freeze it into ice blocks and skate on it and melt it in the spring time and drink it!  ']
# 	['tt0486551', "Barry Badrinath:\nI was in Thailand playing ping-pong in Ding Dang. I was in a real high stakes game in some opium den. Turns out the guys I was playing aren't the kind of guys who like to lose. After I beat 'em, they beat me. Worked me over pretty good. And this is hard to say... they held me down and shoved a ping-pong paddle up my ass. It's never been the same. Damaged goods. \nSteve 'Fink' Fi..."]
# 	['tt0331953', 'Putman:\n[with disdain]\nWhat kind of a man has sex with a goat? \nJuan:\nHey, I used a condom. \nJenny:\n[who had had sex with Juan]\nYou told me they were against your religion. \nJuan:\nEhh, you know, I need to find Peen-a-lope. I am sure you all understand.  ']
# 	['tt0331953', "Juan:\n[after 'interrogating' Penelope by having passionate sex]\nI may need a few more hours to pump her for information.  "]
# 	['tt0456554', "Alex:\nAnyway, I was wondering if maybe I could crash here for a while. \nDante:\nWhoa, I don't know, man. I got a business to run. This is like my office as well as my home. Plus, the lion comes in a couple days. \nAlex:\nYou're getting a lion? \nDante:\nYeah. \nAlex:\nWhy? \nDante:\nTo protect my shit. \nAlex:\nNever heard of a dog? \nDante:\nDude, you can get past a dog. Nobody fucks with a lion. \nAlex:\nYe..."]
# 	['tt0456554', "Alex:\nDude, your bed is a car... \nJeff:\nYeah, but it's a fucking sweet car.  "]
# 	['tt1135525', 'Cleon Salmon:\nYou know what ten grand feels like in your pocket? It feels like a third cock.  ']
# 	['tt1135525', "Cleon Salmon:\nWho is Guy... Meatdrapes? What kind of name is that? \nGuy:\nIt's, um, it's Metdrapedes, sir. It's Greek. \nCleon Salmon:\nI think you're pronouncing it wrong. This says Meatdrapes. \nGuy:\nIt's actually pronounced Metdrapedes. \nCleon Salmon:\nWell, why doesn't it sound like that when I say it? Meatdrapes.  "]
# 	['tt0245686', "Joe Dirt:\nSo you're gonna tell me that you don't have no black cats, no Roman Candles, or screaming mimis? \nKicking Wing:\nNo. \nJoe Dirt:\nOh come on, man. You got no lady fingers, fuzz buttles, snicker bombs, church burners, finger blasters, gut busters, zippity do das, or crap flappers? \nKicking Wing:\nNo, I don't. \nJoe Dirt:\nYou're gonna stand there, ownin' a fireworks stand, and tell me you do..."]
# 	['tt0245686', "Clem:\n[talking to fire extinguisher]\nYou're talking to me all wrong... It's the wrong tone. You do it again and I'll stab you in the face with a soldering iron. Hey, tell me, does your mother sew? BOOM. Get her to sew that!  "]
# 	['tt0114694', "[saying it correctly]\n\nTommy:\nI can get a good look at a T-bone by sticking my head up a bull's ass, but I'd rather take a butcher's word for it.  "]
# 	['tt0114694', "Tommy:\nBrothers don't shake hands. Brothers gotta hug.  "]
# 	['tt0115697', "[phoning citizens in an attempt to secure votes]\n\nMike:\nHi there, this is Mike Donnelly. I work over here at the recreational center. To be honest with you, I pretty much run the place ha, ha, ha. Is this ah Pat Gyles? Good, Good. Hey, hope everything's going great in your fine town of... er... Avery? Edward! Ha, ha, ha. Say, the reason I'm calling is I wanted to tell you a little bit about the..."]
# 	['tt0115697', "[Mike is pretending to be a cop, Steve is pretending to be a prisoner]\n\nSteve:\nRo-ads. Ro-ods. \nMike:\nQuiet back there! I've taken enough guff from you for one day! \n[turns to state trooper]\n\nMike:\nRaving psycho! Butchered 400 chickens and screwed a beagle. I'm taking him back to Nevada where he's wanted for banging horses!  "]
# 	['tt0144557', "Zach:\nSo what's his name? \nFelix Bean:\nTraci Shannon. \nZach:\nTraci Shannon! That's not just a firsty, firsty. It's also a girly girly  "]
# 	['tt0144557', "Matt:\nWell hey, Sara. \nSara:\nHey, Matt. Grogan's so funny. \nMatt:\nYeah. Hey, sounds to me like you like him. \nSara:\nWell... \nMatt:\nWow. You and Garbage Dick. That's great, I mean he was just saying that... \nSara:\nWait, what did you say? \nMatt:\nI was just saying how Garbage Dick told me how he thought you were... \nSara:\nGarbage Dick? \nMatt:\nYeah. Oh, no, no. It's no big deal. I mean, that was at..."]
# 	['tt0348333', "Monty:\n[using a Forrest Gump voice]\nMomma said they's my magic shoes. Mama said they would take me anywhere. 'Course Mama used to beat me with a rubber hose and call me a retard.  "]
# 	['tt0348333', "Dan:\nWe need to seize the day. Be enthusiastic. \nFloyd:\n[enthusiastically]\nYeah! Carpe deez nuts! God I can't wait to quit this job!  "]
# 	['tt0366551', 'Harold:\nDid Doogie Howser just steal my fucking car?  ']
# 	['tt0366551', "Harold:\nSo what are you in here for? \nTarik:\nFor being black. \nHarold:\nSeriously. \nTarik:\nI am serious. You wanna know what happened? I was walking out of a Barnes & Noble, and a cop stops me. Now evidently, a black guy robbed a store in Newark. I told him, 'I haven't even been to Newark in months.' So he starts beating me with his gun, telling me to stop resisting arrest. \nHarold:\nHoly shit! W..."]
# 	['tt0069239', "Shirley:\n[reading from the Witchcraft primer]\n'The religion offers, further, a retreat for emotional women, repressed women, masculine women and those suffering from personal disappointment or nervous maladjustment.' Christ, what other kind of women are there? No wonder this stuff's getting so damn popular.  "]
# 	['tt0069239', 'Jack:\nYour own goddamned daughter, balled in the next room and you go with it.  ']
# 	['tt0077914', "Martin Madahas:\nThings only seem to be magic. There is no real magic. There's no real magic ever.  "]
# 	['tt0077914', "Christina:\nHow old are you, Martin? \nMartin Madahas:\nOh, I'm old. \nChristina:\nHow old? \nMartin Madahas:\nEighty four.  "]
# 	['tt0455407', "David Dutton:\nDon't ask me why I can't leave without my wife and I won't ask you why you can.  "]
# 	['tt0455407', "David Dutton:\n[In the car wash, to the Deputy firing his shotgun out of the car window]\nRUSSELL! \nRussell Clank:\nI saw a movement! \nDavid Dutton:\nEverything is fuckin' moving!  "]
# 	['tt0166843', "Chris Bradley:\nDad, I just don't want to go to work in your baby food factory. And, I don't want to sell vacuum cleaners. I don't want to sell little toy plastic aircraft carriers. I don't wanna... I don't know what I want. \nMr. Bradley:\nChris, I think I understand what you're talking about. A little bit anyway. But these problems are a little bit like going to Howard Johnsons for some ice crea..."]
# 	['tt0166843', "Mr. Bradley:\nChris... why don't you let me send you back to school? I might as well put my money to good use. \nChris Bradley:\nNo thanks, Dad, I don't want to hold back my education. \nMr. Bradley:\nYou better come down out of those clouds, boy... or you're not going to be worth the powder to blow you to hell.  "]
# 	['tt0095652', "Geoffrey Fisher:\nYou're a clinical cunt.  "]
# 	['tt0095652', "Geoffrey Fisher:\nThat's one of the advantages of working in a chem lab. I finally figured it out, Allan. Every three days that I stay awake, I gain 24 hours. That's 122 days every year. So even if I die at 50, I will have lived 65 years.  "]
# 	['tt1134854', "Sarge 'Nicotine' Crocket:\nWhere's Cisco? \nTomboy:\nHe's... in heaven... telling the Virgin Mary he can change her life.  "]
# 	['tt1134854', "[first lines]\n\nSarge 'Nicotine' Crocket:\n[voice-over]\nLast time anyone counted, fifty-three million people were dying every year, a hundred-fifty thousand every day, a hundred and seven every minute, and that was in normal times.  "]
# 	['tt0088993', "Captain Rhodes:\n[as the zombies are disembowling him and eating his entrails]\nChoke on 'em!  "]
# 	['tt0088993', "Dr. Logan:\n[interrupting Rhodes]\nIs there food? \nRhodes:\n[screaming]\nI'm running this monkey farm now Frankenstein and I wanna know... what the fuck you're doing with my time?  "]
# 	['tt0082622', "Linet:\nEverybody here made a conscious, adult decision to be here. To be with you. When you go crazy, you force them to rethink that decision. You've got to... \nBilly:\nCompromise. \nLinet:\nChange doesn't have to mean compromise. We're bigger now. Things are different. Christ, we've got an overhead. \nBilly:\nPublicity helps the overhead by bringing in more crowds, more suckerheaded American driftw..."]
# 	['tt0082622', "Merlin:\nIf I didn't believe in magic, I'd still be treating gall bladders, prostates and stuff like that. See, magic ain't got nothing to do with organs and glands and busted necks. Magic got to do with the soul, man. Only the soul's got destiny. It got wings. It's can fly. That's magic. The body? The body's just got a few minutes down here in the dirt with the rest of us. \nBilly:\nYou see thing..."]
# 	['tt0077402', "Francine Parker:\nThey're still here. \nStephen:\nThey're after us. They know we're still in here. \nPeter:\nThey're after the place. They don't know why; they just remember. Remember that they want to be in here. \nFrancine Parker:\nWhat the hell are they? \nPeter:\nThey're us, that's all, when there's no more room in hell. \nStephen:\nWhat? \nPeter:\nSomething my granddad used to tell us. You know Macumba..."]
# 	['tt0077402', 'Dr. Foster:\nEvery dead body that is not exterminated becomes one of them. It gets up and kills! The people it kills get up and kill!  ']
# 	['tt0848557', "Looter:\nWhat the fuck are you doing here? \nJason:\nWhat the fuck are you doing here? \nLooter:\n[holding TV]\nI'm just stealing shit. But you... what's a guy with a video camera doing in the women's dorm, huh?  "]
# 	['tt0848557', '[last lines]\n\nDebra:\nJason once said he thought he could help, maybe even save some lives. This is the last thing he downloaded before he died: a couple of hometown Joes who went out to shoot at targets. But that day, they used people. Dead people. You know, just for fun? There was one target that was different from the rest. A woman... tied by her hair to the branch of a tree. The boys had thi...']
# 	['tt0067341', "Emily:\nIt's not the cake!  "]
# 	['tt0067341', "Jessica:\nI sit here and I can't believe that it happened. And yet I have to believe it. Dreams or nightmares? Madness or sanity? I don't know which is which.  "]
# 	['tt0418819', "Kaufman:\nIn a world where the dead are returning to life, the word 'trouble' loses much of its meaning.  "]
# 	['tt0418819', "Mike:\nThey're pretending to be alive... \nRiley:\nIsn't that what we're doing? Pretending to be alive?  "]
# 	['tt0119177', "[last lines]\n\nVincent:\n[voiceover]\nFor someone who was never meant for this world, I must confess I'm suddenly having a hard time leaving it. Of course, they say every atom in our bodies was once part of a star. Maybe I'm not leaving... maybe I'm going home.  "]
# 	['tt0119177', 'Vincent:\nYou want to know how I did it? This is how I did it, Anton: I never saved anything for the swim back.  ']
# 	['tt0253556', "[referring to the dragons]\n\nDenton Van Zan:\nEver see a male? \nQuinn Abercromby:\nWhen I'm running for my life I generally don't look back at the plumbing.  "]
# 	['tt0253556', 'Denton Van Zan:\nEnvy the country that has heroes, huh? I say pity the country that needs them.  ']
# 	['tt0119116', 'Police:\nAre you classified as human? \nKorben Dallas:\nNegative, I am a meat popsicle.  ']
# 	['tt0119116', "Korben Dallas:\n[Leans down and kisses Leeloo. Leeloo swipes his gun and holds it to his head]\n\nKorben Dallas:\nYou're right, you're right, I shouldn't have done that. I'm sorry. \nLeeloo:\nSenno ecto gammat! \nKorben Dallas:\nI'm sorry, I'm sorry! \nLeeloo:\necto gammat! \nKorben Dallas:\n[In a later scene]\nWhen she woke up, she said a bunch a stuff. I didn't understand any of it but... what does 'ecto ..."]
# 	['tt0448134', 'Pinbacker:\nAt the end of time, a moment will come when just one man remains. Then the moment will pass. Man will be gone. There will be nothing to show that we were ever here... but stardust.  ']
# 	['tt0448134', "[last lines]\n\nCapa:\nSo if you wake up one morning and it's a particularly beautiful day, you'll know we made it. Okay, I'm signing out.  "]
# 	['tt0361862', "Trevor Reznik:\nStevie, I haven't slept in a year. \nStevie:\nJesus Christ! \nTrevor Reznik:\nI tried him too.  "]
# 	['tt0361862', "Stevie:\nAre you okay? \nTrevor Reznik:\nDon't I look okay? \nStevie:\nIf you were any thinner, you wouldn't exist.  "]
# 	['tt0118929', 'Dr. Schreber:\nI call them the Strangers. They abducted us and brought us here. This city, everyone in it... is their experiment. They mix and match our memories as they see fit, trying to divine what makes us unique. One day, a man might be an inspector. The next, someone entirely different. When they want to study a murderer, for instance, they simply imprint one of their citizens with a new p...']
# 	['tt0118929', "John Murdoch:\nWhen was the last time you remember doing something during the day? \nInspector Frank Bumstead:\nWhat do you mean? \nJohn Murdoch:\nI just mean during the day. Daylight. When was the last time you remember seeing it? And I'm not talking about some distant, half-forgotten childhood memory, I mean like yesterday. Last week. Can you come up with a single memory? You can't, can you? You k..."]
# 	['tt1182345', 'GERTY:\nI hope life on Earth is everything you remember it to be.  ']
# 	['tt1182345', "Sam Bell:\nYou'd be okay? \nGERTY:\nOf course. The new Sam and I will be back to our programming as soon as I finished rebooting. \nSam Bell:\nGerty, we're not programmed. We're people, do you understand?  "]
# 	['tt0118884', "Alien:\nYou're an interesting species. An interesting mix. You're capable of such beautiful dreams, and such horrible nightmares. You feel so lost, so cut off, so alone, only you're not. See, in all our searching, the only thing we've found that makes the emptiness bearable, is each other.  "]
# 	['tt0118884', "[last lines]\n\nEllie Arroway:\n[to a group of children]\nI'll tell you one thing about the universe, though. The universe is a pretty big place. It's bigger than anything anyone has ever dreamed of before. So if it's just us... seems like an awful waste of space. Right?  "]
# 	['tt0462504', 'Dieter:\nEmpty what is full. Fill what is empty. Scratch what itches.  ']
# 	['tt0462504', 'Dieter:\nNo, I never wanted to go to war. I just wanted to fly.  ']
# 	['tt0381849', "Dan Evans:\n[while being choked]\nI ain't never been no hero, Wade. The only battle I seen, we was in retreat. My foot got shot off by one of my own men. You try telling that story to your boy. See how he he looks at you then.  "]
# 	['tt0381849', "Dan Evans:\nI ain't stubborn. \nBen Wade:\nExcuse me? \nDan Evans:\nYou said I was stubborn, for keeping my family on a dying ranch. It's my son, Mark. The young one. He got tuberculosis when he was two. Doctor said he would die if he didn't have a dry climate, so... \nBen Wade:\n[interrupting]\nWhy are you tellin' me this? \nDan Evans:\nI don't know. I guess I just... wanted you to know that I ain't stu..."]
# 	['tt0433387', "Jim Davis:\nI'm a soldier of the apocalypse, man!  "]
# 	['tt0433387', 'Mike Alonzo:\nHow was it like to straight up whack em up ? \nMike Alonzo:\nPoint and shoot. Pop, pop - move on! You do not stop and think!  ']
# 	['tt0114746', "Jeffrey Goines:\nThere's the television. It's all right there - all right there. Look, listen, kneel, pray. Commercials! We're not productive anymore. We don't make things anymore. It's all automated. What are we *for* then? We're consumers, Jim. Yeah. Okay, okay. Buy a lot of stuff, you're a good citizen. But if you don't buy a lot of stuff, if you don't, what are you then, I ask you? What? Men..."]
# 	['tt0114746', "Jeffrey Goines:\nThere's no right, there's no wrong, there's only popular opinion.  "]
# Summary
# -------
# 	['tt0859635', 'When a border dispute arises between the U.S. and Canada, the Super Troopers are tasked with establishing a Highway Patrol station in the disputed area.\n\n—Fox Searchlight Pictures']
# 	['tt0859635', 'Several years after the first film, the officers have been fired from the Spurbury Police Department after taking Fred Savage on a ride-along that resulted in his death. Farva (Heffernan) is now a construction supervisor, with Mac (Lemme) and Rabbit (Stolhanske) working for him. Thorny (Chandrasekhar) works in logging, and Foster (Soter) is living with his girlfriend and former coworker, Spurbu...']
# 	['tt0486551', "Two brothers travel to Germany for Oktoberfest, only to stumble upon a secret, centuries-old competition described as a 'Fight Club' with beer games.\n\n—Anonymous"]
# 	['tt0486551', "After the death of their grandfather Johann von Wolfhause, the brothers Jan and Todd Wolfhouse travel to Munich to fulfill a family tradition, spreading the ashes of Johann during the Oktoberfest. Their contact brings them to a secret beer competition, the Beerfest', where they are offended by Baron Wolfgang von Wolfhausen and the German branch of their family that accuse their great-grandmothe..."]
# 	['tt0331953', "When a serial killer interrupts the fun at the swanky Coconut Pete's Coconut Beach Resort--a hedonistic island paradise for swingers--it's up to the club's staff to stop the violence...or at least hide it.\n\n—Anonymous"]
# 	['tt0331953', 'Broken Lizard is surrounded by limber, wanton women on a booze-soaked island resort owned by Coconut Pete, a rock star has-been. But the non-stop party takes a turn for the weird when dead bodies start turning up. Everyone begins to look suspicious. Could it be Sam, of the Fun Police brigade, who is quick-on-the-trigger with his tequila-loaded Super Soaker; Jenny, the over-sexed fitness instruc...']
# 	['tt0456554', 'A thirty-five-year-old video game tester has to move in with his grandma and her two old lady roommates.']
# 	['tt0456554', "When his roommate spends the rent money on hookers, Alex, a 35 year old video game tester has to find a new place to live. After an 'encounter' with his friend's mom, Alex is forced to move in with his grandmother. Trying to save face with his younger co-workers, Alex says that 'a really cute chick said I could sleep with her and her two crazy girlfriends' (meaning his grandmother and her two r..."]
# 	['tt1135525', 'The owner of a Miami restaurant indebted to the mob institutes a contest to see what waiter can earn the most money in one night.\n\n—Anonymous']
# 	['tt1135525', "The brutal former heavyweight boxing champion Cleon 'Slammin'' Salmon, now owner of a Miami restaurant, institutes a competition to see which waiter can earn the most money in one night: the winner stands to gain $10,000, while the loser will endure a beating at the hands of the champ.\n\n—Anonymous"]
# 	['tt0245686', 'After being abandoned by his parents at the Grand Canyon, Joe Dirt tells the story of his journey to find his parents.']
# 	['tt0245686', 'Joe Dirt is a janitor with a mullet hairdo, acid-washed jeans and a dream to find the parents that he lost at the Grand Canyon when he was a belligerent, trailer park-raised eight-year-old. Now, blasting Van Halen in his jacked-up economy car, the irrepressibly optimistic Joe hits the road alone in search of his folks. As his wandering, misguided search takes him from one hilarious misadventure...']
# 	['tt0114694', 'After his auto-parts tycoon father dies, the overweight, underachieving son teams up with a snide accountant to try and save the family business.\n\n—Dynasti Noble']
# 	['tt0114694', "Tommy Callahan Jr. is a slow-witted, clumsy guy who recently graduated college after attending for seven years. His father, Big Tom Callahan, owns an auto parts factory in Ohio. When Tommy arrives back home, he finds he has a position at the factory waiting for him. His dad also introduces Tommy to the new brake pad division of the factory and to Tommy's soon-to-be stepmother, Beverly, and her ..."]
# 	['tt0115697', "A gubernatorial candidate hires a wormy special assistant whose only job is to make sure the candidate's well-meaning but incompetent brother doesn't ruin the election.\n\n—<jgp3553@yahoo.com>"]
# 	['tt0115697', 'Comedy about the prospective Washington State Governor Al Donnelly whose only stumbling block on the road to power is his embarrassing younger brother Mike. To keep him out of mischief, Al forces one of his aides, Steve Dodds to keep an eye on him during the election. However, this is easier said than done...\n\n—Jonathan Broxton <j.w.broxton@sheffield.ac.uk>']
# 	['tt0144557', "A student falls in love with a fellow student who is defending his buddies in university court. He 'proves his love' (more like his masculinity) to her by playing rugby against her ex-boyfriend.\n\n—Tristan Lawrence <tlawrence@pmsystems.com>"]
# 	['tt0348333', 'Young employees at Shenaniganz restaurant collectively stave off boredom and adulthood with their antics.\n\n—Anonymous']
# 	['tt0348333', "It's the dinner shift at Shenanigan's. Dan, the clueless boss, assigns Mitch, 22, a trainee, to Monty, the smooth talker who chases girls for one-night stands. Dean, a waiter, also 22, feels that life is passing him by. Dan offers him the assistant manager job and gives him until midnight to decide. Other waiters, cooks, and bus boys have their issues and personalities. Bishop, the dishwasher, ..."]
# 	['tt0366551', 'A Korean-American office worker and his Indian-American stoner friend embark on a quest to satisfy their desire for White Castle burgers.\n\n—Anonymous']
# 	['tt0366551', 'Harold Lee and Kumar Patel are two stoners who end up getting the munchies. What they crave the most after seeing a TV advertisement, is a trip to White Castle. So from here, follows a journey for the burgers they require. On their way they will encounter many obstacles including a raccoon, a racist officer, and a horny Neil Patrick Harris.\n\n—Film_Fan']
# 	['tt0069239', 'A neglected, unhappy suburban housewife with gets mixed up in witchcraft with unexpected consequences.\n\n—Anonymous']
# 	['tt0069239', 'Joan Mitchell is an alienated suburban housewife pushing 40, who has a boorish businessman husband and a distant, distracted 19-year-old daughter whose, on the verge of moving out of the house. Frustrated at her current situation, Joan seeks solace in witchcraft after visiting Marion Hamilton, a local tarot reader and leader of a secret black arts wicca sect, who inspires Joan to follow her own...']
# 	['tt0077914', 'A young man, who believes himself to be a vampire, goes to live with his elderly and hostile cousin in a small Pennsylvania town where he tries to redeem his blood-craving urges.\n\n—matt-282']
# 	['tt0077914', "George Romero does for vampires what he has already done to zombies - an intense and realistic treatment that follows the exploits of Martin, who claims to be 84 years old, and who certainly drinks human blood. The boy arrives in Pittsburgh to stay with his cousin, who promises to save Martin's soul and destroy him once he is finished, but Martin's loneliness finds other means of release.\n\n—Dav..."]
# 	['tt0455407', 'After a strange and insecure plane crash, an unusual toxic virus enters a quaint farming town. A young couple are quarantined, but they fight for survival along with help from a couple of people.\n\n—Bethan']
# 	['tt0455407', 'As a toxin begins to turn the residents of Ogden Marsh, Iowa into violent psychopaths, sheriff David Dutton tries to make sense of the situation while he, his wife, and two other unaffected townspeople band together in a fight for survival.\n\n—ahmetkozan']
# 	['tt0166843', 'A young man returns to his home city of Pittsburgh and moves in with an older woman whom he begins to rely on for emotional and financial support.\n\n—matt-282']
# 	['tt0166843', 'Chris Bradley is a young man who returns to his home city of Pittsburgh after several years of drifting and working odd jobs around the country since his discharge from the U.S. Army. Rejecting moving back in with his father and not wanting to return to the family business of manufacturing baby food, Chris meets and shacks up with Lynn, an older woman who works as a model in local TV commercial...']
# 	['tt0095652', 'A quadriplegic man has a trained monkey help him with his paralysis, until the little monkey begins to develop feelings, and rage, against its new master.\n\n—Matt Patay']
# 	['tt0095652', "When Allan becomes a quadriplegic he loses all hope for living until he meets Ella - a monkey trained to fetch and carry for him around the house, obeying him in all things. But Ella is part of another experiment, and when she starts responding to Allan's underlying rage and frustration she has the ability to carry out her master's darkest wishes.\n\n—David Carroll <davidc@atom.ansto.gov.au>"]
# 	['tt1134854', 'On an island off the coast of North America, local residents simultaneously fight a zombie epidemic while hoping for a cure to return their un-dead relatives back to their human state.\n\n—Anonymous']
# 	['tt1134854', "In the Plum Island, off the coast of Delaware, the long feud between the families of the patriarchs Captain Patrick O'Flynn (Kenneth Welsh) that intends to eliminate the zombies and Seamus Muldoon (Richard Fitzpatrick) that intends to keep his undead relatives waiting for a cure culminates with O'Flynn expelled from Plum. Meanwhile in the continent Sarge 'Nicotine' Crocket (Alan Van Sprang), Ch..."]
# 	['tt0088993', 'A small group of military officers and scientists dwell in an underground bunker as the world above is overrun by zombies.\n\n—Anonymous']
# 	['tt0088993', "Zombies rule the world, except for a small group of scientists and military personnel who reside in an underground bunker in Florida. The scientists are using the undead in gruesome experiments; much to the chagrin of the military. Finally the military finds that their men have been used in the scientists' experiments, and banish the scientists to the caves that house the Living Dead. Unfortuna..."]
# 	['tt0082622', 'A medieval reenactment troupe find it increasingly difficult to keep their family-like group together, with pressure from local law enforcement, interest from entertainment agents and a growing sense of delusion from their leader.\n\n—Daniel Jos. Leary']
# 	['tt0082622', "A travelling troupe of jousters and performers are slowly cracking under the pressure of hick cops, financial troubles and their failure to live up to their own ideals. The group's leader, King Billy, is increasingly unable to maintain his warrior's rule while the Black Knight is being tempted away to LA and stardom, as they all have to ask why they were here in the first place.\n\n—David Carroll..."]
# 	['tt0077402', 'Following an ever-growing epidemic of zombies that have risen from the dead, two Philadelphia S.W.A.T. team members, a traffic reporter, and his television executive girlfriend seek refuge in a secluded shopping mall.\n\n—Anonymous']
# 	['tt0077402', 'The zombie apocalypse has hit Earth. Two personnel from a TV station and two policemen set off in a helicopter to find a safe place to hide out. Their search leads them to a shopping mall where they manage to find a place that, while not zombie-free, is quite secure. So far, so good.\n\n—grantss']
# 	['tt0848557', 'A group of young film students run into real-life zombies while filming a horror movie of their own.\n\n—Anonymous']
# 	['tt0848557', "While filming a horror movie of mummy in a forest, the students and their professor of the University of Pittsburgh hear on the TV the news that the dead are awaking and walking. Ridley and Francine decide to leave the group, while Jason heads to the dormitory of his girlfriend Debra Monahan. She does not succeed in contacting her family and they travel in Mary's van to the house of Debra's par..."]
# 	['tt0067341', 'A recently institutionalized woman has bizarre experiences after moving into a supposedly haunted country farmhouse and fears she may be losing her sanity once again.\n\n—Scott']
# 	['tt0067341', "After a stint in a psychiatric facility Jessica, her husband and a friend move to remote farm they have recently purchased. There they find a young woman by the name of Emily living in the house and they invite her to stay. When Jessica goes for a swim in the lake, she sees a body just below the water's surface. When they go into the village to sell some old furniture, they learn that a woman b..."]
# 	['tt0418819', 'The living dead have taken over the world, and the last humans live in a walled city to protect themselves as they come to grips with the situation.\n\n—Erik Paniccia']
# 	['tt0418819', "Now that zombies have taken over the world, the living have built a walled-in city to keep the dead out. But all's not well where it's most safe, as a revolution plans to overthrow the city leadership, and the zombies are turning into more advanced creatures.\n\n—Anonymous"]
# 	['tt0119177', 'A genetically inferior man assumes the identity of a superior one in order to pursue his lifelong dream of space travel.\n\n—Anonymous']
# 	['tt0119177', 'In the not-too-distant future, a less-than-perfect man wants to travel to the stars. Society has categorized Vincent Freeman as less than suitable given his genetic make-up and he has become one of the underclass of humans that are only useful for menial jobs. To move ahead, he assumes the identity of Jerome Morrow, a perfect genetic specimen who is a paraplegic as a result of a car accident. W...']
# 	['tt0253556', 'A brood of fire-breathing dragons emerges from the earth and begins setting everything ablaze, establishing dominance over the planet.\n\n—Anonymous']
# 	['tt0253556', 'In present-day London, 12-year-old Quinn Abercromby witnesses the awakening of a hibernating dragon from a centuries-long slumber, the result of a construction dig supervised by his mother and an incident for which Quinn feels partially responsible. Twenty years later, the adult Quinn (Christian Bale) is the fire chief of a refortified castle community, responsible for dousing the blazes lit by...']
# 	['tt0119116', 'In the colorful future, a cab driver unwittingly becomes the central figure in the search for a legendary cosmic weapon to keep Evil and Mr. Zorg at bay.\n\n—Murray Chapman']
# 	['tt0119116', 'In the twenty-third century, the universe is threatened by evil. The only hope for mankind is the Fifth Element, who comes to Earth every five thousand years to protect the humans with four stones of the four elements: fire, water, Earth and air. A Mondoshawan spacecraft is bringing The Fifth Element back to Earth but it is destroyed by the evil Mangalores. However, a team of scientists use the...']
# 	['tt0448134', 'A team of international astronauts are sent on a dangerous mission to reignite the dying Sun with a nuclear fission bomb in 2057.\n\n—Skip4591']
# 	['tt0448134', "50 years into the future, the Sun begins to die, and Earth is dying as a result. A team of astronauts is sent to revive the Sun - but the mission fails. Seven years later, a new team is sent to finish the mission as mankind's last hope.\n\n—harpster_2004@yahoo.co.uk"]
# 	['tt0361862', "An industrial worker who hasn't slept in a year begins to doubt his own sanity.\n\n—IMDb Editors"]
# 	['tt0361862', 'Trevor Reznik is a machinist in a factory. An extreme case of insomnia has led to him not sleeping in a year, and his body withering away to almost nothing. He has an obsessive compulsion to write himself reminder notes and keep track of his dwindling weight, both scribbled on yellow stickies in his apartment. The only person he lets into his life in an emotional sense is Stevie, a prostitute, ...']
# 	['tt0118929', 'A man struggles with memories of his past, which includes a wife he cannot remember, and a nightmarish world, no one else seems to be waking up from.\n\n—John Sacksteder <jsack@ka.net>']
# 	['tt0118929', 'John Murdoch awakens alone in a strange hotel to find that he has lost his memory and is wanted for a series of brutal and bizarre murders. While trying to piece together his past, he stumbles upon a fiendish underworld controlled by a group of beings known as The Strangers who possess the ability to put people to sleep and alter the city and its inhabitants. Now Murdoch must find a way to stop...']
# 	['tt1182345', "Astronaut Sam Bell has a quintessentially personal encounter toward the end of his three-year stint on the Moon, where he, working alongside his computer, GERTY, sends back to Earth parcels of a resource that has helped diminish our planet's power problems.\n\n—Anonymous"]
# 	['tt1182345', "Sam Bell has a three year contract to work for Lunar Industries. For the contract's entire duration, he is the sole employee based at their lunar station. His primary job responsibility is to harvest and periodically rocket back to Earth supplies of helium-3, the current clean and abundant fuel used on Earth. There is no direct communication link available between the lunar station and Earth, s..."]
# 	['tt0118884', 'Dr. Ellie Arroway, after years of searching, finds conclusive radio proof of extraterrestrial intelligence, sending plans for a mysterious machine.\n\n—Jon Reeves <jreeves@imdb.com>']
# 	['tt0118884', 'Astronomer Dr. Ellie Arroway has long been interested in contact to faraway lands, a love fostered in her childhood by her father, Ted Arroway (David Morse), who died when she was nine-years-old, leaving her orphaned. Her current work in monitoring for extraterrestrial life is based on that love and is in part an homage to her father. Ever since funding from the National Science Foundation (N.S...']
# 	['tt0462504', "A U.S. fighter pilot's epic struggle of survival after being shot down on a mission over Laos during the Vietnam War."]
# 	['tt0462504', 'In 1965, while bombing Laos in a classified mission, the propeller plane of the German-American US Navy pilot Dieter Dengler is hit and crashes in the jungle. Dieter is arrested by the peasants, tortured by the Vietcong and sent to a prisoner camp, where he meets five other mentally deranged prisoners and guards. He becomes close to Duane and organizes an escape plan; however, the unstable Gene...']
# 	['tt0381849', "A small-time rancher agrees to hold a captured outlaw who's awaiting a train to go to court in Yuma. A battle of wills ensues as the outlaw tries to psych out the rancher.\n\n—Anonymous"]
# 	['tt0381849', "Rancher Dan Evans heads into Bisbee to clear up issues concerning the sale of his land when he witnesses the closing events of a stagecoach robbery led by famed outlaw Ben Wade. Shortly thereafter, Wade is captured by the law in Bisbee and Evans finds himself one of the escorts who will take Wade to the 3:10 to Yuma train in Contention for the reward of $200. Evans' effort to take Wade to the s..."]
# 	['tt0433387', 'A tough-minded drama about two friends in South Central Los Angeles and the violence that comes between them.\n\n—Anonymous']
# 	['tt0433387', 'Jim Davis is an ex-Army Ranger who finds himself slipping back into his old life of petty crime after a job offer from the LAPD evaporates. His best friend is pressured by his girlfriend Sylvia to find a job, but Jim is more interested in hanging out and making cash from small heists, while trying to get a law enforcement job so he can marry his Mexican girlfriend.\n\n—batfreak79']
# 	['tt0114746', 'In a future world devastated by disease, a convict is sent back in time to gather information about the man-made virus that wiped out most of the human population on the planet.\n\n—Anonymous']
# 	['tt0114746', "An intense film about time travel, this Sci-Fi entry was directed by Terry Gilliam, a member of the comedy troupe Monty Python. The film stars Bruce Willis as James Cole, a prisoner of the state in the year 2035 who can earn parole if he agrees to travel back in time and thwart a devastating plague. The virus has wiped out most of the Earth's population and the remainder live underground becaus..."]
# Production
# ----------
# 	['tt0859635', 'Votiv Films']
# 	['tt0859635', 'Broken Lizard Industries']
# 	['tt0859635', 'Cataland Films']
# 	['tt0859635', 'Heretical Reason Productions']
# 	['tt0859635', "Needle's Eye Productions"]
# 	['tt0486551', 'Warner Bros.']
# 	['tt0486551', 'Legendary Entertainment']
# 	['tt0486551', 'Gerber Pictures']
# 	['tt0486551', 'Cataland Films']
# 	['tt0486551', 'Broken Lizard Industries']
# 	['tt0486551', 'Adobe Pictures']
# 	['tt0331953', 'Broken Lizard Industries']
# 	['tt0331953', 'Cataland Films']
# 	['tt0331953', 'Coconut Pete Productions']
# 	['tt0331953', 'Fox Searchlight Pictures']
# 	['tt0456554', 'Twentieth Century Fox']
# 	['tt0456554', 'Level 1 Entertainment']
# 	['tt0456554', 'Happy Madison Productions']
# 	['tt1135525', 'Broken Lizard Industries']
# 	['tt1135525', 'Cataland Films']
# 	['tt0245686', 'Columbia Pictures']
# 	['tt0245686', 'Happy Madison Productions']
# 	['tt0245686', 'Robert Simonds Productions']
# 	['tt0114694', 'Broadway Pictures']
# 	['tt0114694', 'Paramount Pictures']
# 	['tt0115697', 'Broadway Pictures']
# 	['tt0115697', 'Paramount Pictures']
# 	['tt0144557', 'Broken Lizard Industries']
# 	['tt0144557', 'Cataland Films']
# 	['tt0348333', 'Eden Rock Media']
# 	['tt0348333', 'Element Films']
# 	['tt0348333', 'L.I.F.T. Production']
# 	['tt0348333', 'Wisenheimer Films']
# 	['tt0366551', 'Endgame Entertainment']
# 	['tt0366551', 'Harold & Kumar']
# 	['tt0366551', 'Kingsgate Films']
# 	['tt0366551', 'New Line Cinema']
# 	['tt0366551', 'Senator International']
# 	['tt0069239', 'The Latent Image']
# 	['tt0077914', 'Laurel Productions']
# 	['tt0077914', 'Braddock Associates']
# 	['tt0455407', 'Overture Films']
# 	['tt0455407', 'Participant']
# 	['tt0455407', 'Imagenation Abu Dhabi FZ']
# 	['tt0455407', 'Penn Station Entertainment']
# 	['tt0166843', 'The Latent Image']
# 	['tt0166843', 'At Play With the Angels']
# 	['tt0095652', 'Orion Pictures']
# 	['tt1134854', 'Blank of the Dead Productions']
# 	['tt1134854', 'Devonshire Productions']
# 	['tt1134854', 'New Romero']
# 	['tt1134854', 'Sudden Storm Productions']
# 	['tt0088993', 'United Film Distribution Company (UFDC)']
# 	['tt0088993', 'Laurel Entertainment Inc.']
# 	['tt0082622', 'United Film Distribution Company (UFDC)']
# 	['tt0082622', 'Laurel Productons']
# 	['tt0077402', 'Laurel Group']
# 	['tt0077402', 'Dawn Associates']
# 	['tt0848557', 'Artfire Films']
# 	['tt0848557', 'Romero-Grunwald Productions']
# 	['tt0067341', 'Paramount Pictures']
# 	['tt0067341', 'The Jessica Company']
# 	['tt0418819', 'Universal Pictures']
# 	['tt0418819', 'Atmosphere Entertainment MM']
# 	['tt0418819', 'Romero-Grunwald Productions']
# 	['tt0418819', 'Wild Bunch']
# 	['tt0418819', 'Rangerkim']
# 	['tt0418819', 'Ontario Media Development Corporation (OMDC)']
# 	['tt0418819', 'Exception Wild Bunch']
# 	['tt0119177', 'Columbia Pictures']
# 	['tt0119177', 'Jersey Films']
# 	['tt0253556', 'Touchstone Pictures']
# 	['tt0253556', 'Spyglass Entertainment']
# 	['tt0253556', 'The Zanuck Company']
# 	['tt0253556', 'Tripod Entertainment']
# 	['tt0253556', 'World 2000 Entertainment']
# 	['tt0119116', 'Columbia Pictures']
# 	['tt0119116', 'Gaumont']
# 	['tt0119116', 'Pinewood Studios']
# 	['tt0448134', 'DNA Films']
# 	['tt0448134', 'Ingenious Film Partners']
# 	['tt0448134', 'Moving Picture Company (MPC)']
# 	['tt0448134', 'UK Film Council']
# 	['tt0361862', 'Filmax Group']
# 	['tt0361862', 'Castelao Producciones']
# 	['tt0361862', 'Canal+ España']
# 	['tt0361862', 'Instituto de la Cinematografía y de las Ar...']
# 	['tt0361862', 'ICF']
# 	['tt0361862', 'Castelao Pictures']
# 	['tt0118929', 'Mystery Clock Cinema']
# 	['tt0118929', 'New Line Cinema']
# 	['tt1182345', 'Sony Pictures Classics']
# 	['tt1182345', 'Stage 6 Films']
# 	['tt1182345', 'Liberty Films UK']
# 	['tt1182345', 'Xingu Films']
# 	['tt1182345', 'Limelight Fund']
# 	['tt1182345', 'Lunar Industries']
# 	['tt1182345', 'Independent']
# 	['tt0118884', 'Warner Bros.']
# 	['tt0118884', 'South Side Amusement Company']
# 	['tt0462504', 'Metro-Goldwyn-Mayer (MGM)']
# 	['tt0462504', 'Top Gun Productions']
# 	['tt0462504', 'Thema Production']
# 	['tt0462504', 'Gibraltar Films']
# 	['tt0462504', 'Blue Rider Pictures']
# 	['tt0462504', 'Bruin Grip Services']
# 	['tt0381849', 'Lionsgate']
# 	['tt0381849', 'Tree Line Film']
# 	['tt0381849', 'Relativity Media']
# 	['tt0381849', 'Columbia Pictures']
# 	['tt0381849', 'Yuma']
# 	['tt0433387', 'Andrea Sperling Productions']
# 	['tt0433387', 'C.M. Films']
# 	['tt0433387', 'Crave Films']
# 	['tt0433387', 'Harsh Times']
# 	['tt0114746', 'Universal Pictures']
# 	['tt0114746', 'Atlas Entertainment']
# 	['tt0114746', 'Classico']
# 	['tt0114746', 'Twelve Monkeys Productions']
# Genre
# -----
# 	['tt0859635', 'Comedy']
# 	['tt0859635', 'Crime']
# 	['tt0859635', 'Mystery']
# 	['tt0486551', 'Comedy']
# 	['tt0331953', 'Comedy']
# 	['tt0331953', 'Horror']
# 	['tt0331953', 'Mystery']
# 	['tt0331953', 'Thriller']
# 	['tt0456554', 'Comedy']
# 	['tt1135525', 'Comedy']
# 	['tt0245686', 'Adventure']
# 	['tt0245686', 'Comedy']
# 	['tt0245686', 'Drama']
# 	['tt0114694', 'Adventure']
# 	['tt0114694', 'Comedy']
# 	['tt0115697', 'Comedy']
# 	['tt0144557', 'Comedy']
# 	['tt0144557', 'Drama']
# 	['tt0144557', 'Romance']
# 	['tt0348333', 'Comedy']
# 	['tt0366551', 'Adventure']
# 	['tt0366551', 'Comedy']
# 	['tt0069239', 'Drama']
# 	['tt0069239', 'Horror']
# 	['tt0077914', 'Drama']
# 	['tt0077914', 'Horror']
# 	['tt0455407', 'Horror']
# 	['tt0455407', 'Thriller']
# 	['tt0166843', 'Comedy']
# 	['tt0166843', 'Drama']
# 	['tt0166843', 'Romance']
# 	['tt0095652', 'Drama']
# 	['tt0095652', 'Horror']
# 	['tt0095652', 'Sci-Fi']
# 	['tt0095652', 'Thriller']
# 	['tt1134854', 'Comedy']
# 	['tt1134854', 'Drama']
# 	['tt1134854', 'Horror']
# 	['tt1134854', 'Thriller']
# 	['tt0088993', 'Horror']
# 	['tt0088993', 'Thriller']
# 	['tt0082622', 'Action']
# 	['tt0082622', 'Drama']
# 	['tt0077402', 'Action']
# 	['tt0077402', 'Adventure']
# 	['tt0077402', 'Horror']
# 	['tt0077402', 'Thriller']
# 	['tt0848557', 'Fantasy']
# 	['tt0848557', 'Horror']
# 	['tt0848557', 'Sci-Fi']
# 	['tt0848557', 'Thriller']
# 	['tt0067341', 'Drama']
# 	['tt0067341', 'Horror']
# 	['tt0067341', 'Mystery']
# 	['tt0418819', 'Horror']
# 	['tt0418819', 'Sci-Fi']
# 	['tt0418819', 'Thriller']
# 	['tt0119177', 'Drama']
# 	['tt0119177', 'Sci-Fi']
# 	['tt0119177', 'Thriller']
# 	['tt0253556', 'Action']
# 	['tt0253556', 'Adventure']
# 	['tt0253556', 'Fantasy']
# 	['tt0253556', 'Thriller']
# 	['tt0119116', 'Action']
# 	['tt0119116', 'Adventure']
# 	['tt0119116', 'Sci-Fi']
# 	['tt0448134', 'Sci-Fi']
# 	['tt0448134', 'Thriller']
# 	['tt0361862', 'Drama']
# 	['tt0361862', 'Thriller']
# 	['tt0118929', 'Mystery']
# 	['tt0118929', 'Sci-Fi']
# 	['tt0118929', 'Thriller']
# 	['tt1182345', 'Drama']
# 	['tt1182345', 'Mystery']
# 	['tt1182345', 'Sci-Fi']
# 	['tt0118884', 'Drama']
# 	['tt0118884', 'Mystery']
# 	['tt0118884', 'Sci-Fi']
# 	['tt0118884', 'Thriller']
# 	['tt0462504', 'Action']
# 	['tt0462504', 'Biography']
# 	['tt0462504', 'Drama']
# 	['tt0462504', 'Thriller']
# 	['tt0462504', 'War']
# 	['tt0381849', 'Action']
# 	['tt0381849', 'Crime']
# 	['tt0381849', 'Drama']
# 	['tt0381849', 'Western']
# 	['tt0433387', 'Action']
# 	['tt0433387', 'Crime']
# 	['tt0433387', 'Drama']
# 	['tt0433387', 'Thriller']
# 	['tt0114746', 'Mystery']
# 	['tt0114746', 'Sci-Fi']
# 	['tt0114746', 'Thriller']
# Person
# ------
# 	['tt0859635', 0, 'Jay Chandrasekhar']
# 	['tt0859635', 1, 'Jay Chandrasekhar']
# 	['tt0859635', 2, 'Kevin Heffernan']
# 	['tt0859635', 2, 'Steve Lemme ']
# 	['tt0486551', 0, 'Jay Chandrasekhar']
# 	['tt0486551', 1, 'Jay Chandrasekhar']
# 	['tt0486551', 2, 'Kevin Heffernan']
# 	['tt0486551', 2, 'Steve Lemme ']
# 	['tt0331953', 0, 'Jay Chandrasekhar']
# 	['tt0331953', 1, 'Jay Chandrasekhar']
# 	['tt0331953', 2, 'Bill Paxton']
# 	['tt0331953', 2, 'Kevin Heffernan ']
# 	['tt0456554', 0, 'Nicholaus Goossen']
# 	['tt0456554', 1, 'Barry Wernick,']
# 	['tt0456554', 2, 'Allen Covert']
# 	['tt0456554', 2, 'Linda Cardellini']
# 	['tt0456554', 2, 'Shirley Jones ']
# 	['tt1135525', 0, 'Kevin Heffernan']
# 	['tt1135525', 1, 'Jay Chandrasekhar']
# 	['tt1135525', 2, 'Michael Clarke Duncan']
# 	['tt1135525', 2, 'Jay Chandrasekhar']
# 	['tt1135525', 2, 'Kevin Heffernan ']
# 	['tt0245686', 0, 'Dennie Gordon']
# 	['tt0245686', 1, 'David Spade,']
# 	['tt0245686', 2, 'David Spade']
# 	['tt0245686', 2, 'Brittany Daniel']
# 	['tt0245686', 2, 'Dennis Miller ']
# 	['tt0114694', 0, 'Peter Segal']
# 	['tt0114694', 1, 'Bonnie Turner,']
# 	['tt0114694', 2, 'Chris Farley']
# 	['tt0114694', 2, 'David Spade']
# 	['tt0114694', 2, 'Brian Dennehy ']
# 	['tt0115697', 0, 'Penelope Spheeris']
# 	['tt0115697', 1, 'Fred Wolf']
# 	['tt0115697', 2, 'Chris Farley']
# 	['tt0115697', 2, 'David Spade']
# 	['tt0115697', 2, 'Tim Matheson ']
# 	['tt0144557', 0, 'Jay Chandrasekhar']
# 	['tt0144557', 1, 'Jay Chandrasekhar']
# 	['tt0144557', 2, 'Kevin Heffernan']
# 	['tt0144557', 2, 'Steve Lemme ']
# 	['tt0348333', 0, 'Rob McKittrick']
# 	['tt0348333', 1, 'Rob McKittrick']
# 	['tt0348333', 2, 'Ryan Reynolds']
# 	['tt0348333', 2, 'Anna Faris']
# 	['tt0348333', 2, 'John Francis Daley ']
# 	['tt0366551', 0, 'Danny Leiner']
# 	['tt0366551', 1, 'Jon Hurwitz,']
# 	['tt0366551', 2, 'John Cho']
# 	['tt0366551', 2, 'Kal Penn']
# 	['tt0366551', 2, 'Ethan Embry ']
# 	['tt0069239', 0, 'George A.']
# 	['tt0069239', 1, 'George A.']
# 	['tt0069239', 2, 'Jan White']
# 	['tt0069239', 2, 'Raymond Laine']
# 	['tt0069239', 2, 'Ann Muffly ']
# 	['tt0077914', 0, 'George A.']
# 	['tt0077914', 1, 'George A.']
# 	['tt0077914', 2, 'John Amplas']
# 	['tt0077914', 2, 'Lincoln Maazel']
# 	['tt0077914', 2, 'Christine Forrest ']
# 	['tt0455407', 0, 'Breck Eisner']
# 	['tt0455407', 1, 'Scott Kosar']
# 	['tt0455407', 2, 'Radha Mitchell']
# 	['tt0455407', 2, 'Timothy Olyphant']
# 	['tt0455407', 2, 'Danielle Panabaker ']
# 	['tt0166843', 0, 'George A.']
# 	['tt0166843', 1, 'Rudy Ricci']
# 	['tt0166843', 2, 'Raymond Laine']
# 	['tt0166843', 2, 'Judith Ridley']
# 	['tt0166843', 2, 'Johanna Lawrence ']
# 	['tt0095652', 0, 'George A.']
# 	['tt0095652', 1, 'Michael Stewart']
# 	['tt0095652', 2, 'Jason Beghe']
# 	['tt0095652', 2, 'John Pankow']
# 	['tt0095652', 2, 'Kate McNeil ']
# 	['tt1134854', 0, 'George A.']
# 	['tt1134854', 1, 'George A.']
# 	['tt1134854', 2, 'Alan Van Sprang']
# 	['tt1134854', 2, 'Kenneth Welsh']
# 	['tt1134854', 2, 'Kathleen Munroe ']
# 	['tt0088993', 0, 'George A.']
# 	['tt0088993', 1, 'George A.']
# 	['tt0088993', 2, 'Lori Cardille']
# 	['tt0088993', 2, 'Terry Alexander']
# 	['tt0088993', 2, 'Joseph Pilato ']
# 	['tt0082622', 0, 'George A.']
# 	['tt0082622', 1, 'George A.']
# 	['tt0082622', 2, 'Ed Harris']
# 	['tt0082622', 2, 'Gary Lahti']
# 	['tt0082622', 2, 'Tom Savini ']
# 	['tt0077402', 0, 'George A.']
# 	['tt0077402', 1, 'George A.']
# 	['tt0077402', 2, 'David Emge']
# 	['tt0077402', 2, 'Ken Foree']
# 	['tt0077402', 2, 'Scott H. Reiniger ']
# 	['tt0848557', 0, 'George A.']
# 	['tt0848557', 1, 'George A.']
# 	['tt0848557', 2, 'Michelle Morgan']
# 	['tt0848557', 2, 'Joshua Close']
# 	['tt0848557', 2, 'Shawn Roberts ']
# 	['tt0067341', 0, 'John D.']
# 	['tt0067341', 1, 'John D.']
# 	['tt0067341', 2, 'Zohra Lampert']
# 	['tt0067341', 2, 'Barton Heyman']
# 	['tt0067341', 2, "Kevin O'Connor "]
# 	['tt0418819', 0, 'George A.']
# 	['tt0418819', 1, 'George A.']
# 	['tt0418819', 2, 'John Leguizamo']
# 	['tt0418819', 2, 'Asia Argento']
# 	['tt0418819', 2, 'Simon Baker ']
# 	['tt0119177', 0, 'Andrew Niccol']
# 	['tt0119177', 1, 'Andrew Niccol']
# 	['tt0119177', 2, 'Ethan Hawke']
# 	['tt0119177', 2, 'Uma Thurman']
# 	['tt0119177', 2, 'Jude Law ']
# 	['tt0253556', 0, 'Rob Bowman']
# 	['tt0253556', 1, 'Gregg Chabot']
# 	['tt0253556', 2, 'Matthew McConaughey']
# 	['tt0253556', 2, 'Christian Bale']
# 	['tt0253556', 2, 'Izabella Scorupco ']
# 	['tt0119116', 0, 'Luc Besson']
# 	['tt0119116', 1, 'Luc Besson']
# 	['tt0119116', 2, 'Bruce Willis']
# 	['tt0119116', 2, 'Milla Jovovich']
# 	['tt0119116', 2, 'Gary Oldman ']
# 	['tt0448134', 0, 'Danny Boyle']
# 	['tt0448134', 1, 'Alex Garland']
# 	['tt0448134', 2, 'Cillian Murphy']
# 	['tt0448134', 2, 'Rose Byrne']
# 	['tt0448134', 2, 'Chris Evans ']
# 	['tt0361862', 0, 'Brad Anderson']
# 	['tt0361862', 1, 'Scott Kosar']
# 	['tt0361862', 2, 'Christian Bale']
# 	['tt0361862', 2, 'Jennifer Jason Leigh']
# 	['tt0361862', 2, 'Aitana Sánchez-Gijón ']
# 	['tt0118929', 0, 'Alex Proyas']
# 	['tt0118929', 1, 'Alex Proyas']
# 	['tt0118929', 2, 'Rufus Sewell']
# 	['tt0118929', 2, 'Kiefer Sutherland']
# 	['tt0118929', 2, 'Jennifer Connelly ']
# 	['tt1182345', 0, 'Duncan Jones']
# 	['tt1182345', 1, 'Duncan Jones']
# 	['tt1182345', 2, 'Sam Rockwell']
# 	['tt1182345', 2, 'Kevin Spacey']
# 	['tt1182345', 2, 'Dominique McElligott ']
# 	['tt0118884', 0, 'Robert Zemeckis']
# 	['tt0118884', 1, 'James V.']
# 	['tt0118884', 2, 'Jodie Foster']
# 	['tt0118884', 2, 'Matthew McConaughey']
# 	['tt0118884', 2, 'Tom Skerritt ']
# 	['tt0462504', 0, 'Werner Herzog']
# 	['tt0462504', 1, 'Werner Herzog']
# 	['tt0462504', 2, 'Christian Bale']
# 	['tt0462504', 2, 'Steve Zahn']
# 	['tt0462504', 2, 'Jeremy Davies ']
# 	['tt0381849', 0, 'James Mangold']
# 	['tt0381849', 1, 'Halsted Welles']
# 	['tt0381849', 2, 'Russell Crowe']
# 	['tt0381849', 2, 'Christian Bale']
# 	['tt0381849', 2, 'Ben Foster ']
# 	['tt0433387', 0, 'David Ayer']
# 	['tt0433387', 1, 'David Ayer']
# 	['tt0433387', 2, 'Christian Bale']
# 	['tt0433387', 2, 'Freddy Rodríguez']
# 	['tt0433387', 2, 'Eva Longoria ']
# 	['tt0114746', 0, 'Terry Gilliam']
# 	['tt0114746', 1, 'Chris Marker']
# 	['tt0114746', 2, 'Bruce Willis']
# 	['tt0114746', 2, 'Madeleine Stowe']
# 	['tt0114746', 2, 'Brad Pitt ']
# Award
# -----
# 	['tt0859635', None, 'Golden Trailer Nominee: Best Radio/Audio Spot']
# 	['tt0859635', None, 'Golden Trailer Winner: Best Teaser Poster']
# 	['tt0859635', None, 'Golden Trailer Winner: Best Trailerbyte for a Feature Film']
# 	['tt0486551', None, 'Stinker Award Nominee: Most Painfully Unfunny Comedy']
# 	['tt0486551', None, 'Stinker Award Nominee: Most Annoying Fake Accent: Female']
# 	['tt0456554', None, 'Razzie Award Nominee: Worst Actor of the Decade']
# 	['tt0456554', None, 'Razzie Award Nominee: and ']
# 	['tt0456554', None, 'Razzie Award Nominee:   Little Nicky']
# 	['tt0245686', 'David Spade', 'Stinker Award Winner: Worst On-Screen Hairstyle']
# 	['tt0114694', 'Chris Farley', 'MTV Movie Award Winner: Best On-Screen Duo']
# 	['tt0114694', 'David Spade', 'MTV Movie Award Winner: Best On-Screen Duo']
# 	['tt0144557', 'Jay Chandrasekhar', 'Golden Starfish Award Winner: Best American Independent Film']
# 	['tt0144557', 'Jay Chandrasekhar', 'Golden Starfish Award Winner: Best American Independent Film']
# 	['tt0366551', 'John Cho', 'MTV Movie Award Nominee: Best On-Screen Team']
# 	['tt0366551', 'Kal Penn', 'MTV Movie Award Nominee: Best On-Screen Team']
# 	['tt0077914', None, 'Special Award Winner: Best Rediscoveries']
# 	['tt0455407', 'Breck Eisner', 'Fright Meter Award Nominee: Best Director']
# 	['tt0455407', 'Timothy Olyphant', 'Scream Award Nominee: Best Horror Actor']
# 	['tt0095652', None, "International Fantasy Film Award Winner George A. Romero Critics' Award Winner: Best Film"]
# 	['tt1134854', None, 'Canadian Cinema Editors Award Nominee: Best Editing in Feature Length']
# 	['tt0088993', 'Lori Cardille', 'Caixa de Catalunya Winner: Best Actress']
# 	['tt0077402', None, 'Saturn Award Winner: Best DVD Classic Film Release']
# 	['tt0077402', None, 'Saturn Award Nominee: Best Make-Up']
# 	['tt0077402', None, 'Golden Satellite Award Nominee: Best Overall DVD']
# 	['tt0848557', None, 'Rondo Statuette Nominee: Best Film']
# 	['tt0418819', 'John Leguizamo', 'Chainsaw Award Winner: Best Actor']
# 	['tt0418819', 'Asia Argento', 'Scream Award Nominee: Scream Queen']
# 	['tt0119177', 'Andrew Niccol', 'Hugo Nominee: Best Dramatic Presentation']
# 	['tt0119177', 'Andrew Niccol', 'Hugo Nominee: Best Dramatic Presentation']
# 	['tt0119177', 'Ethan Hawke', 'OFTA Film Award Nominee: Best Sci-Fi/Fantasy/Horror Actor']
# 	['tt0253556', 'Rob Bowman', 'Rondo Statuette Nominee: Best Genre Film']
# 	['tt0119116', 'Luc Besson', 'Stinker Award Nominee: Worst Sense of Direction (Stop them before they direct again!)']
# 	['tt0119116', 'Luc Besson', 'Stinker Award Nominee: Worst Sense of Direction (Stop them before they direct again!)']
# 	['tt0119116', 'Bruce Willis', 'OFTA Film Award Winner: Best Sci-Fi/Fantasy/Horror Actor']
# 	['tt0448134', 'Danny Boyle', 'ALFS Award Nominee: British Director of the Year']
# 	['tt0448134', 'Cillian Murphy', 'Scream Award Nominee: Sci-Fi Star']
# 	['tt0361862', 'Brad Anderson', 'Narcisse Award Winner: Best Fantastic Feature Film']
# 	['tt0361862', 'Scott Kosar', 'Chainsaw Award Nominee: Best Screenplay']
# 	['tt0361862', 'Christian Bale', 'ALFS Award Nominee: British Actor of the Year']
# 	['tt0118929', 'Alex Proyas', 'Saturn Award Winner: Best Director']
# 	['tt0118929', 'Alex Proyas', 'Saturn Award Winner: Best Director']
# 	['tt0118929', 'Rufus Sewell', 'OFTA Film Award Winner: Best Sci-Fi/Fantasy/Horror Actor']
# 	['tt1182345', 'Duncan Jones', 'BAFTA Film Award Winner: Outstanding Debut by a British Writer, Director or Producer']
# 	['tt1182345', 'Duncan Jones', 'BAFTA Film Award Winner: Outstanding Debut by a British Writer, Director or Producer']
# 	['tt1182345', 'Sam Rockwell', 'Golden Space Needle Award Winner: Best Actor']
# 	['tt0118884', 'Robert Zemeckis', 'Saturn Award Winner: Best Director']
# 	['tt0118884', 'Jodie Foster', 'Audience Award Winner: Best Actress']
# 	['tt0118884', 'Matthew McConaughey', 'Blockbuster Entertainment Award Nominee: Favorite Actor - Drama']
# 	['tt0462504', 'Christian Bale', 'Satellite Award Nominee: Best Actor in a Motion Picture, Drama']
# 	['tt0462504', 'Steve Zahn', 'Independent Spirit Award Nominee: Best Supporting Male']
# 	['tt0381849', 'Russell Crowe', 'Actor Nominee: Outstanding Performance by a Cast in a Motion Picture']
# 	['tt0381849', 'Christian Bale', 'Actor Nominee: Outstanding Performance by a Cast in a Motion Picture']
# 	['tt0433387', 'Christian Bale', 'DFCC Nominee: Best Actor']
# 	['tt0114746', 'Terry Gilliam', 'Empire Award Winner: Best Director']
# 	['tt0114746', 'Chris Marker', 'Hugo Nominee: Best Dramatic Presentation']
# 	['tt0114746', 'Bruce Willis', 'Saturn Award Winner: Best Actor']

# %% [markdown]
# # Transform
# ## Transform: only needs an identifier

# %%
# Taglines, Quotes, and Summaries only need a unique identifier attached to each value.
needs_an_identifier = [
    'Tagline',
    'Summary',
    'Quote'
]
for t_name in needs_an_identifier:   
    table_data = []
    for i, [movie_id, text] in enumerate( raw_data[t_name]):   
        dd = {
            f'{t_name.lower()}_id': i,
            'movie_id': movie_id,
            f'{t_name.lower()}_text': text
        }
        table_data.append(dd)
    ready_to_load[t_name] = table_data

# %% [markdown]
# ## Transform: implement M:N relationship

# %%
MN_relationship = {
    # a:b where
    #  a is key for the raw, unnormalized data
    #  b is the name for the new intermediate table
    #
    'Genre' : 'MovieGenre',
    'Production' : 'MovieProduction',
    'Person': 'Role'
}
MN_cols = {
    'Genre' : ['movie_id', 'genre_id'],
    'Production': ['movie_id', 'production_id'],
    'Person': ['movie_id', 'role_code', 'person_id']
}

for t_o, t_MN in MN_relationship.items():
    unnormalized_data = raw_data[ t_o]
    connections = []
    
    final_column_values = set()
    for r in unnormalized_data:
        final_column_values.add(r[-1])
 
    value_ids = []
    unique_col_ids = {}
    for col_id, col_text in enumerate(final_column_values):
        unique_col_ids[col_id] = col_text
        value_ids.append({
            f'{t_o.lower()}_id' : col_id,
            f'{t_o.lower()}_name' : col_text
        })
    for r in unnormalized_data:
        dd = {}
        current_final_col = r[-1]
        
        for col_id, col_text in unique_col_ids.items():
            if col_text == current_final_col:
                MN_dd = {}
                for i in range( len(r) - 1 ):
                    MN_dd[MN_cols[t_o][i]] = r[i]
                MN_dd[MN_cols[t_o][-1]] = col_id
                connections.append( MN_dd)
        
    ready_to_load[ t_o] = value_ids
    ready_to_load[t_MN] = connections

# %% [markdown]
# ## Transform: match awards to person

# %%
awards = []

i = 0
for r in raw_data['Award']:
    person_id = None
    for entry in ready_to_load['Person']:
        if entry['person_name'] == r[1]:
            person_id = entry['person_id']

    awards.append({
        'award_id' : i,
        'movie_id' : r[0],
        'person_id': person_id,
        'award_text': r[2]
    })
    i = i + 1
ready_to_load['Award'] = awards

# %% [markdown]
# ## Transform: Rolecodes are hardcoded

# %%
ready_to_load['RoleCode'] = [
    {
        'role_code': 0, 
        'role_name': 'Director'
    },{
        'role_code': 1, 
        'role_name': 'Writer'
    },{
        'role_code': 2, 
        'role_name': 'Actor'
    }
]

# %% [markdown]
# ## Transform: show finalized data if VERBOSE

# %%
if VERBOSE:
    table_num = 0
    for t_name, t_data in ready_to_load.items():
        table_num = table_num + 1
        print_section_header(f'{table_num}. {t_name}')

        num_rows = len( t_data)
        for i in range( num_rows):
            print_dd(f'{t_name} {str(i)}', t_data[i])
        print()
# Out:
# ======================
# ||                  ||
# ||     1. Movie     ||
# ||                  ||
# ======================
# Movie 0
# -------
# 	movie_id	:	tt0859635
# 	movie_year	:	2018
# 	movie_title	:	Super Troopers 2
# 	movie_budget	:	13500000
# 	movie_boxoffice	:	31626386
# 	movie_runtime	:	100
# Movie 1
# -------
# 	movie_id	:	tt0486551
# 	movie_year	:	2006
# 	movie_title	:	Beerfest
# 	movie_budget	:	17500000
# 	movie_boxoffice	:	20387597
# 	movie_runtime	:	110
# Movie 2
# -------
# 	movie_id	:	tt0331953
# 	movie_year	:	2004
# 	movie_title	:	Club Dread
# 	movie_budget	:	8600000
# 	movie_boxoffice	:	7565807
# 	movie_runtime	:	104
# Movie 3
# -------
# 	movie_id	:	tt0456554
# 	movie_year	:	2006
# 	movie_title	:	Grandma's Boy
# 	movie_budget	:	None
# 	movie_boxoffice	:	6566277
# 	movie_runtime	:	94
# Movie 4
# -------
# 	movie_id	:	tt1135525
# 	movie_year	:	2009
# 	movie_title	:	The Slammin' Salmon
# 	movie_budget	:	None
# 	movie_boxoffice	:	60421
# 	movie_runtime	:	99
# Movie 5
# -------
# 	movie_id	:	tt0245686
# 	movie_year	:	2001
# 	movie_title	:	Joe Dirt
# 	movie_budget	:	17700000
# 	movie_boxoffice	:	30987695
# 	movie_runtime	:	91
# Movie 6
# -------
# 	movie_id	:	tt0114694
# 	movie_year	:	1995
# 	movie_title	:	Tommy Boy
# 	movie_budget	:	None
# 	movie_boxoffice	:	32679899
# 	movie_runtime	:	97
# Movie 7
# -------
# 	movie_id	:	tt0115697
# 	movie_year	:	1996
# 	movie_title	:	Black Sheep
# 	movie_budget	:	None
# 	movie_boxoffice	:	32417995
# 	movie_runtime	:	87
# Movie 8
# -------
# 	movie_id	:	tt0144557
# 	movie_year	:	1996
# 	movie_title	:	Puddle Cruiser
# 	movie_budget	:	160000
# 	movie_boxoffice	:	None
# 	movie_runtime	:	102
# Movie 9
# -------
# 	movie_id	:	tt0348333
# 	movie_year	:	2005
# 	movie_title	:	Waiting...
# 	movie_budget	:	3000000
# 	movie_boxoffice	:	18637690
# 	movie_runtime	:	94
# Movie 10
# --------
# 	movie_id	:	tt0366551
# 	movie_year	:	2004
# 	movie_title	:	Harold & Kumar Go to White Castle
# 	movie_budget	:	9000000
# 	movie_boxoffice	:	23936908
# 	movie_runtime	:	88
# Movie 11
# --------
# 	movie_id	:	tt0069239
# 	movie_year	:	1972
# 	movie_title	:	Season of the Witch
# 	movie_budget	:	90000
# 	movie_boxoffice	:	None
# 	movie_runtime	:	130
# Movie 12
# --------
# 	movie_id	:	tt0077914
# 	movie_year	:	1977
# 	movie_title	:	Martin
# 	movie_budget	:	80000
# 	movie_boxoffice	:	None
# 	movie_runtime	:	95
# Movie 13
# --------
# 	movie_id	:	tt0455407
# 	movie_year	:	2010
# 	movie_title	:	The Crazies
# 	movie_budget	:	20000000
# 	movie_boxoffice	:	54806823
# 	movie_runtime	:	101
# Movie 14
# --------
# 	movie_id	:	tt0166843
# 	movie_year	:	1971
# 	movie_title	:	There's Always Vanilla
# 	movie_budget	:	70000
# 	movie_boxoffice	:	None
# 	movie_runtime	:	93
# Movie 15
# --------
# 	movie_id	:	tt0095652
# 	movie_year	:	1988
# 	movie_title	:	Monkey Shines
# 	movie_budget	:	7000000
# 	movie_boxoffice	:	5344577
# 	movie_runtime	:	113
# Movie 16
# --------
# 	movie_id	:	tt1134854
# 	movie_year	:	2009
# 	movie_title	:	Survival of the Dead
# 	movie_budget	:	4000000
# 	movie_boxoffice	:	386078
# 	movie_runtime	:	90
# Movie 17
# --------
# 	movie_id	:	tt0088993
# 	movie_year	:	1985
# 	movie_title	:	Day of the Dead
# 	movie_budget	:	3500000
# 	movie_boxoffice	:	5000000
# 	movie_runtime	:	96
# Movie 18
# --------
# 	movie_id	:	tt0082622
# 	movie_year	:	1981
# 	movie_title	:	Knightriders
# 	movie_budget	:	3000000
# 	movie_boxoffice	:	None
# 	movie_runtime	:	146
# Movie 19
# --------
# 	movie_id	:	tt0077402
# 	movie_year	:	1978
# 	movie_title	:	Dawn of the Dead
# 	movie_budget	:	650000
# 	movie_boxoffice	:	159822
# 	movie_runtime	:	127
# Movie 20
# --------
# 	movie_id	:	tt0848557
# 	movie_year	:	2007
# 	movie_title	:	Diary of the Dead
# 	movie_budget	:	2000000
# 	movie_boxoffice	:	5540941
# 	movie_runtime	:	95
# Movie 21
# --------
# 	movie_id	:	tt0067341
# 	movie_year	:	1971
# 	movie_title	:	Let's Scare Jessica to Death
# 	movie_budget	:	180000
# 	movie_boxoffice	:	None
# 	movie_runtime	:	89
# Movie 22
# --------
# 	movie_id	:	tt0418819
# 	movie_year	:	2005
# 	movie_title	:	Land of the Dead
# 	movie_budget	:	15000000
# 	movie_boxoffice	:	47074133
# 	movie_runtime	:	93
# Movie 23
# --------
# 	movie_id	:	tt0119177
# 	movie_year	:	1997
# 	movie_title	:	Gattaca
# 	movie_budget	:	36000000
# 	movie_boxoffice	:	12532777
# 	movie_runtime	:	106
# Movie 24
# --------
# 	movie_id	:	tt0253556
# 	movie_year	:	2002
# 	movie_title	:	Reign of Fire
# 	movie_budget	:	60000000
# 	movie_boxoffice	:	82150183
# 	movie_runtime	:	101
# Movie 25
# --------
# 	movie_id	:	tt0119116
# 	movie_year	:	1997
# 	movie_title	:	The Fifth Element
# 	movie_budget	:	93000000
# 	movie_boxoffice	:	263920180
# 	movie_runtime	:	126
# Movie 26
# --------
# 	movie_id	:	tt0448134
# 	movie_year	:	2007
# 	movie_title	:	Sunshine
# 	movie_budget	:	None
# 	movie_boxoffice	:	34806360
# 	movie_runtime	:	107
# Movie 27
# --------
# 	movie_id	:	tt0361862
# 	movie_year	:	2004
# 	movie_title	:	The Machinist
# 	movie_budget	:	5000000
# 	movie_boxoffice	:	8203235
# 	movie_runtime	:	101
# Movie 28
# --------
# 	movie_id	:	tt0118929
# 	movie_year	:	1998
# 	movie_title	:	Dark City
# 	movie_budget	:	27000000
# 	movie_boxoffice	:	27200316
# 	movie_runtime	:	100
# Movie 29
# --------
# 	movie_id	:	tt1182345
# 	movie_year	:	2009
# 	movie_title	:	Moon
# 	movie_budget	:	5000000
# 	movie_boxoffice	:	9760107
# 	movie_runtime	:	97
# Movie 30
# --------
# 	movie_id	:	tt0118884
# 	movie_year	:	1997
# 	movie_title	:	Contact
# 	movie_budget	:	90000000
# 	movie_boxoffice	:	171120329
# 	movie_runtime	:	150
# Movie 31
# --------
# 	movie_id	:	tt0462504
# 	movie_year	:	2006
# 	movie_title	:	Rescue Dawn
# 	movie_budget	:	10000000
# 	movie_boxoffice	:	7177143
# 	movie_runtime	:	120
# Movie 32
# --------
# 	movie_id	:	tt0381849
# 	movie_year	:	2007
# 	movie_title	:	3:10 to Yuma
# 	movie_budget	:	55000000
# 	movie_boxoffice	:	70016220
# 	movie_runtime	:	122
# Movie 33
# --------
# 	movie_id	:	tt0433387
# 	movie_year	:	2005
# 	movie_title	:	Harsh Times
# 	movie_budget	:	2000000
# 	movie_boxoffice	:	5969708
# 	movie_runtime	:	116
# Movie 34
# --------
# 	movie_id	:	tt0114746
# 	movie_year	:	1995
# 	movie_title	:	12 Monkeys
# 	movie_budget	:	29000001
# 	movie_boxoffice	:	168839459
# 	movie_runtime	:	129
#
# ========================
# ||                    ||
# ||     2. Tagline     ||
# ||                    ||
# ========================
# Tagline 0
# ---------
# 	tagline_id	:	0
# 	movie_id	:	tt0859635
# 	tagline_text	:	The time is meow.
# Tagline 1
# ---------
# 	tagline_id	:	1
# 	movie_id	:	tt0859635
# 	tagline_text	:	Don't Miss It!
# Tagline 2
# ---------
# 	tagline_id	:	2
# 	movie_id	:	tt0486551
# 	tagline_text	:	Bring on the beer. They've got the nuts.
# Tagline 3
# ---------
# 	tagline_id	:	3
# 	movie_id	:	tt0486551
# 	tagline_text	:	Comedy on tap
# Tagline 4
# ---------
# 	tagline_id	:	4
# 	movie_id	:	tt0331953
# 	tagline_text	:	A vacation to die for.
# Tagline 5
# ---------
# 	tagline_id	:	5
# 	movie_id	:	tt0331953
# 	tagline_text	:	Sun, Sea, Sex and Slaughter (Ireland DVD)
# Tagline 6
# ---------
# 	tagline_id	:	6
# 	movie_id	:	tt0456554
# 	tagline_text	:	Sex. Drugs. Nakedness. Rude language... And proud of it!
# Tagline 7
# ---------
# 	tagline_id	:	7
# 	movie_id	:	tt1135525
# 	tagline_text	:	Bring a bib, it's gonna get messy
# Tagline 8
# ---------
# 	tagline_id	:	8
# 	movie_id	:	tt0245686
# 	tagline_text	:	Keep on Moppin' in the Free world.
# Tagline 9
# ---------
# 	tagline_id	:	9
# 	movie_id	:	tt0245686
# 	tagline_text	:	He Came. He Cleaned. He Conquered
# Tagline 10
# ----------
# 	tagline_id	:	10
# 	movie_id	:	tt0114694
# 	tagline_text	:	If at first you don't succeed, lower your standards.
# Tagline 11
# ----------
# 	tagline_id	:	11
# 	movie_id	:	tt0115697
# 	tagline_text	:	There's one in every family.
# Tagline 12
# ----------
# 	tagline_id	:	12
# 	movie_id	:	tt0348333
# 	tagline_text	:	Hungry for Laughs? (DVD)
# Tagline 13
# ----------
# 	tagline_id	:	13
# 	movie_id	:	tt0348333
# 	tagline_text	:	A comedy of massive portions
# Tagline 14
# ----------
# 	tagline_id	:	14
# 	movie_id	:	tt0366551
# 	tagline_text	:	Fast Food. High Times.
# Tagline 15
# ----------
# 	tagline_id	:	15
# 	movie_id	:	tt0069239
# 	tagline_text	:	Caviar in the kitchen - nothing in the bedroom
# Tagline 16
# ----------
# 	tagline_id	:	16
# 	movie_id	:	tt0069239
# 	tagline_text	:	first NIGHT OF THE LIVING DEAD then DAWN OF THE DEAD - NOW George A. Romero's [Season of the Witch]
# Tagline 17
# ----------
# 	tagline_id	:	17
# 	movie_id	:	tt0077914
# 	tagline_text	:	A Vampire for Our Age of Disbelief
# Tagline 18
# ----------
# 	tagline_id	:	18
# 	movie_id	:	tt0077914
# 	tagline_text	:	See It with Someone You're Sure of...
# Tagline 19
# ----------
# 	tagline_id	:	19
# 	movie_id	:	tt0455407
# 	tagline_text	:	Fear Thy Neighbor
# Tagline 20
# ----------
# 	tagline_id	:	20
# 	movie_id	:	tt0455407
# 	tagline_text	:	Welcome to Ogden Marsh, the friendliest place on earth
# Tagline 21
# ----------
# 	tagline_id	:	21
# 	movie_id	:	tt0166843
# 	tagline_text	:	There's more to love than just moving in
# Tagline 22
# ----------
# 	tagline_id	:	22
# 	movie_id	:	tt0166843
# 	tagline_text	:	Every woman knows why the wrong man is irresistible!
# Tagline 23
# ----------
# 	tagline_id	:	23
# 	movie_id	:	tt0095652
# 	tagline_text	:	A man trapped within his own body. An animal trained to read and carry out thoughts. One with a mind for revenge. The other with an instinct for carrying out that revenge.
# Tagline 24
# ----------
# 	tagline_id	:	24
# 	movie_id	:	tt0095652
# 	tagline_text	:	See no evil...hear no evil...speak no evil...think no evil.
# Tagline 25
# ----------
# 	tagline_id	:	25
# 	movie_id	:	tt1134854
# 	tagline_text	:	Death isn't what it used to be.
# Tagline 26
# ----------
# 	tagline_id	:	26
# 	movie_id	:	tt0088993
# 	tagline_text	:	The Dead have waited. The day has come.
# Tagline 27
# ----------
# 	tagline_id	:	27
# 	movie_id	:	tt0088993
# 	tagline_text	:	Now life has become a NIGHTMARE!
# Tagline 28
# ----------
# 	tagline_id	:	28
# 	movie_id	:	tt0082622
# 	tagline_text	:	From the Master of Action and Suspense!
# Tagline 29
# ----------
# 	tagline_id	:	29
# 	movie_id	:	tt0082622
# 	tagline_text	:	Ride to live. Live to die.
# Tagline 30
# ----------
# 	tagline_id	:	30
# 	movie_id	:	tt0077402
# 	tagline_text	:	George A. Romero's classic 1978 gore-fest, Dawn of the Dead, is back.
# Tagline 31
# ----------
# 	tagline_id	:	31
# 	movie_id	:	tt0077402
# 	tagline_text	:	First there was 'NIGHT OF THE LIVING DEAD'... Now GEORGE A. ROMERO'S [Dawn of the Dead]
# Tagline 32
# ----------
# 	tagline_id	:	32
# 	movie_id	:	tt0848557
# 	tagline_text	:	Shoot the dead.
# Tagline 33
# ----------
# 	tagline_id	:	33
# 	movie_id	:	tt0848557
# 	tagline_text	:	Where will you be when the end begins?
# Tagline 34
# ----------
# 	tagline_id	:	34
# 	movie_id	:	tt0067341
# 	tagline_text	:	Something is after Jessica. Something very cold, very wet... and very dead...
# Tagline 35
# ----------
# 	tagline_id	:	35
# 	movie_id	:	tt0418819
# 	tagline_text	:	The dead shall inherit the Earth.
# Tagline 36
# ----------
# 	tagline_id	:	36
# 	movie_id	:	tt0418819
# 	tagline_text	:	Rise of the Zombies
# Tagline 37
# ----------
# 	tagline_id	:	37
# 	movie_id	:	tt0119177
# 	tagline_text	:	The Prisoner. His Cell.
# Tagline 38
# ----------
# 	tagline_id	:	38
# 	movie_id	:	tt0119177
# 	tagline_text	:	A life is a dangerous thing to share.
# Tagline 39
# ----------
# 	tagline_id	:	39
# 	movie_id	:	tt0253556
# 	tagline_text	:	Fight Fire With Fire
# Tagline 40
# ----------
# 	tagline_id	:	40
# 	movie_id	:	tt0253556
# 	tagline_text	:	They're extremely intelligent. Highly evolved. And they don't like sharing the planet.
# Tagline 41
# ----------
# 	tagline_id	:	41
# 	movie_id	:	tt0119116
# 	tagline_text	:	It Mu5t Be Found.
# Tagline 42
# ----------
# 	tagline_id	:	42
# 	movie_id	:	tt0119116
# 	tagline_text	:	250 years in the future, all will be lost unless the fifth element is found.
# Tagline 43
# ----------
# 	tagline_id	:	43
# 	movie_id	:	tt0448134
# 	tagline_text	:	Dark days are coming.
# Tagline 44
# ----------
# 	tagline_id	:	44
# 	movie_id	:	tt0448134
# 	tagline_text	:	If it dies, so do we.
# Tagline 45
# ----------
# 	tagline_id	:	45
# 	movie_id	:	tt0361862
# 	tagline_text	:	How do you wake up from a nightmare, if you're not asleep?
# Tagline 46
# ----------
# 	tagline_id	:	46
# 	movie_id	:	tt0361862
# 	tagline_text	:	A little guilt goes a long way...
# Tagline 47
# ----------
# 	tagline_id	:	47
# 	movie_id	:	tt0118929
# 	tagline_text	:	They built the city to see what makes us tick. Last night one of us went off.
# Tagline 48
# ----------
# 	tagline_id	:	48
# 	movie_id	:	tt0118929
# 	tagline_text	:	Darkness Falls Soon
# Tagline 49
# ----------
# 	tagline_id	:	49
# 	movie_id	:	tt1182345
# 	tagline_text	:	The last place you'd ever expect to find yourself
# Tagline 50
# ----------
# 	tagline_id	:	50
# 	movie_id	:	tt0118884
# 	tagline_text	:	Get ready to take a chance on something that just might end up being the most profoundly impactful moment for humanity, for the history... of history.
# Tagline 51
# ----------
# 	tagline_id	:	51
# 	movie_id	:	tt0118884
# 	tagline_text	:	A message from deep space. Who will be the first to go? A journey to the heart of the universe.
# Tagline 52
# ----------
# 	tagline_id	:	52
# 	movie_id	:	tt0462504
# 	tagline_text	:	A true story of survival... declassified.
# Tagline 53
# ----------
# 	tagline_id	:	53
# 	movie_id	:	tt0462504
# 	tagline_text	:	Based on the extraordinary true story of one man's fight for freedom
# Tagline 54
# ----------
# 	tagline_id	:	54
# 	movie_id	:	tt0381849
# 	tagline_text	:	Time waits for one man
# Tagline 55
# ----------
# 	tagline_id	:	55
# 	movie_id	:	tt0114746
# 	tagline_text	:	The future is history.
#
# ========================
# ||                    ||
# ||     3. Summary     ||
# ||                    ||
# ========================
# Summary 0
# ---------
# 	summary_id	:	0
# 	movie_id	:	tt0859635
# 	summary_text	:	When a border dispute arises between the U.S. and Canada, the Super Troopers are tasked with establishing a Highway Patrol station in the disputed area.
#
# —Fox Searchlight Pictures
# Summary 1
# ---------
# 	summary_id	:	1
# 	movie_id	:	tt0859635
# 	summary_text	:	Several years after the first film, the officers have been fired from the Spurbury Police Department after taking Fred Savage on a ride-along that resulted in his death. Farva (Heffernan) is now a construction supervisor, with Mac (Lemme) and Rabbit (Stolhanske) working for him. Thorny (Chandrasekhar) works in logging, and Foster (Soter) is living with his girlfriend and former coworker, Spurbu...
# Summary 2
# ---------
# 	summary_id	:	2
# 	movie_id	:	tt0486551
# 	summary_text	:	Two brothers travel to Germany for Oktoberfest, only to stumble upon a secret, centuries-old competition described as a 'Fight Club' with beer games.
#
# —Anonymous
# Summary 3
# ---------
# 	summary_id	:	3
# 	movie_id	:	tt0486551
# 	summary_text	:	After the death of their grandfather Johann von Wolfhause, the brothers Jan and Todd Wolfhouse travel to Munich to fulfill a family tradition, spreading the ashes of Johann during the Oktoberfest. Their contact brings them to a secret beer competition, the Beerfest', where they are offended by Baron Wolfgang von Wolfhausen and the German branch of their family that accuse their great-grandmothe...
# Summary 4
# ---------
# 	summary_id	:	4
# 	movie_id	:	tt0331953
# 	summary_text	:	When a serial killer interrupts the fun at the swanky Coconut Pete's Coconut Beach Resort--a hedonistic island paradise for swingers--it's up to the club's staff to stop the violence...or at least hide it.
#
# —Anonymous
# Summary 5
# ---------
# 	summary_id	:	5
# 	movie_id	:	tt0331953
# 	summary_text	:	Broken Lizard is surrounded by limber, wanton women on a booze-soaked island resort owned by Coconut Pete, a rock star has-been. But the non-stop party takes a turn for the weird when dead bodies start turning up. Everyone begins to look suspicious. Could it be Sam, of the Fun Police brigade, who is quick-on-the-trigger with his tequila-loaded Super Soaker; Jenny, the over-sexed fitness instruc...
# Summary 6
# ---------
# 	summary_id	:	6
# 	movie_id	:	tt0456554
# 	summary_text	:	A thirty-five-year-old video game tester has to move in with his grandma and her two old lady roommates.
# Summary 7
# ---------
# 	summary_id	:	7
# 	movie_id	:	tt0456554
# 	summary_text	:	When his roommate spends the rent money on hookers, Alex, a 35 year old video game tester has to find a new place to live. After an 'encounter' with his friend's mom, Alex is forced to move in with his grandmother. Trying to save face with his younger co-workers, Alex says that 'a really cute chick said I could sleep with her and her two crazy girlfriends' (meaning his grandmother and her two r...
# Summary 8
# ---------
# 	summary_id	:	8
# 	movie_id	:	tt1135525
# 	summary_text	:	The owner of a Miami restaurant indebted to the mob institutes a contest to see what waiter can earn the most money in one night.
#
# —Anonymous
# Summary 9
# ---------
# 	summary_id	:	9
# 	movie_id	:	tt1135525
# 	summary_text	:	The brutal former heavyweight boxing champion Cleon 'Slammin'' Salmon, now owner of a Miami restaurant, institutes a competition to see which waiter can earn the most money in one night: the winner stands to gain $10,000, while the loser will endure a beating at the hands of the champ.
#
# —Anonymous
# Summary 10
# ----------
# 	summary_id	:	10
# 	movie_id	:	tt0245686
# 	summary_text	:	After being abandoned by his parents at the Grand Canyon, Joe Dirt tells the story of his journey to find his parents.
# Summary 11
# ----------
# 	summary_id	:	11
# 	movie_id	:	tt0245686
# 	summary_text	:	Joe Dirt is a janitor with a mullet hairdo, acid-washed jeans and a dream to find the parents that he lost at the Grand Canyon when he was a belligerent, trailer park-raised eight-year-old. Now, blasting Van Halen in his jacked-up economy car, the irrepressibly optimistic Joe hits the road alone in search of his folks. As his wandering, misguided search takes him from one hilarious misadventure...
# Summary 12
# ----------
# 	summary_id	:	12
# 	movie_id	:	tt0114694
# 	summary_text	:	After his auto-parts tycoon father dies, the overweight, underachieving son teams up with a snide accountant to try and save the family business.
#
# —Dynasti Noble
# Summary 13
# ----------
# 	summary_id	:	13
# 	movie_id	:	tt0114694
# 	summary_text	:	Tommy Callahan Jr. is a slow-witted, clumsy guy who recently graduated college after attending for seven years. His father, Big Tom Callahan, owns an auto parts factory in Ohio. When Tommy arrives back home, he finds he has a position at the factory waiting for him. His dad also introduces Tommy to the new brake pad division of the factory and to Tommy's soon-to-be stepmother, Beverly, and her ...
# Summary 14
# ----------
# 	summary_id	:	14
# 	movie_id	:	tt0115697
# 	summary_text	:	A gubernatorial candidate hires a wormy special assistant whose only job is to make sure the candidate's well-meaning but incompetent brother doesn't ruin the election.
#
# —<jgp3553@yahoo.com>
# Summary 15
# ----------
# 	summary_id	:	15
# 	movie_id	:	tt0115697
# 	summary_text	:	Comedy about the prospective Washington State Governor Al Donnelly whose only stumbling block on the road to power is his embarrassing younger brother Mike. To keep him out of mischief, Al forces one of his aides, Steve Dodds to keep an eye on him during the election. However, this is easier said than done...
#
# —Jonathan Broxton <j.w.broxton@sheffield.ac.uk>
# Summary 16
# ----------
# 	summary_id	:	16
# 	movie_id	:	tt0144557
# 	summary_text	:	A student falls in love with a fellow student who is defending his buddies in university court. He 'proves his love' (more like his masculinity) to her by playing rugby against her ex-boyfriend.
#
# —Tristan Lawrence <tlawrence@pmsystems.com>
# Summary 17
# ----------
# 	summary_id	:	17
# 	movie_id	:	tt0348333
# 	summary_text	:	Young employees at Shenaniganz restaurant collectively stave off boredom and adulthood with their antics.
#
# —Anonymous
# Summary 18
# ----------
# 	summary_id	:	18
# 	movie_id	:	tt0348333
# 	summary_text	:	It's the dinner shift at Shenanigan's. Dan, the clueless boss, assigns Mitch, 22, a trainee, to Monty, the smooth talker who chases girls for one-night stands. Dean, a waiter, also 22, feels that life is passing him by. Dan offers him the assistant manager job and gives him until midnight to decide. Other waiters, cooks, and bus boys have their issues and personalities. Bishop, the dishwasher, ...
# Summary 19
# ----------
# 	summary_id	:	19
# 	movie_id	:	tt0366551
# 	summary_text	:	A Korean-American office worker and his Indian-American stoner friend embark on a quest to satisfy their desire for White Castle burgers.
#
# —Anonymous
# Summary 20
# ----------
# 	summary_id	:	20
# 	movie_id	:	tt0366551
# 	summary_text	:	Harold Lee and Kumar Patel are two stoners who end up getting the munchies. What they crave the most after seeing a TV advertisement, is a trip to White Castle. So from here, follows a journey for the burgers they require. On their way they will encounter many obstacles including a raccoon, a racist officer, and a horny Neil Patrick Harris.
#
# —Film_Fan
# Summary 21
# ----------
# 	summary_id	:	21
# 	movie_id	:	tt0069239
# 	summary_text	:	A neglected, unhappy suburban housewife with gets mixed up in witchcraft with unexpected consequences.
#
# —Anonymous
# Summary 22
# ----------
# 	summary_id	:	22
# 	movie_id	:	tt0069239
# 	summary_text	:	Joan Mitchell is an alienated suburban housewife pushing 40, who has a boorish businessman husband and a distant, distracted 19-year-old daughter whose, on the verge of moving out of the house. Frustrated at her current situation, Joan seeks solace in witchcraft after visiting Marion Hamilton, a local tarot reader and leader of a secret black arts wicca sect, who inspires Joan to follow her own...
# Summary 23
# ----------
# 	summary_id	:	23
# 	movie_id	:	tt0077914
# 	summary_text	:	A young man, who believes himself to be a vampire, goes to live with his elderly and hostile cousin in a small Pennsylvania town where he tries to redeem his blood-craving urges.
#
# —matt-282
# Summary 24
# ----------
# 	summary_id	:	24
# 	movie_id	:	tt0077914
# 	summary_text	:	George Romero does for vampires what he has already done to zombies - an intense and realistic treatment that follows the exploits of Martin, who claims to be 84 years old, and who certainly drinks human blood. The boy arrives in Pittsburgh to stay with his cousin, who promises to save Martin's soul and destroy him once he is finished, but Martin's loneliness finds other means of release.
#
# —Dav...
# Summary 25
# ----------
# 	summary_id	:	25
# 	movie_id	:	tt0455407
# 	summary_text	:	After a strange and insecure plane crash, an unusual toxic virus enters a quaint farming town. A young couple are quarantined, but they fight for survival along with help from a couple of people.
#
# —Bethan
# Summary 26
# ----------
# 	summary_id	:	26
# 	movie_id	:	tt0455407
# 	summary_text	:	As a toxin begins to turn the residents of Ogden Marsh, Iowa into violent psychopaths, sheriff David Dutton tries to make sense of the situation while he, his wife, and two other unaffected townspeople band together in a fight for survival.
#
# —ahmetkozan
# Summary 27
# ----------
# 	summary_id	:	27
# 	movie_id	:	tt0166843
# 	summary_text	:	A young man returns to his home city of Pittsburgh and moves in with an older woman whom he begins to rely on for emotional and financial support.
#
# —matt-282
# Summary 28
# ----------
# 	summary_id	:	28
# 	movie_id	:	tt0166843
# 	summary_text	:	Chris Bradley is a young man who returns to his home city of Pittsburgh after several years of drifting and working odd jobs around the country since his discharge from the U.S. Army. Rejecting moving back in with his father and not wanting to return to the family business of manufacturing baby food, Chris meets and shacks up with Lynn, an older woman who works as a model in local TV commercial...
# Summary 29
# ----------
# 	summary_id	:	29
# 	movie_id	:	tt0095652
# 	summary_text	:	A quadriplegic man has a trained monkey help him with his paralysis, until the little monkey begins to develop feelings, and rage, against its new master.
#
# —Matt Patay
# Summary 30
# ----------
# 	summary_id	:	30
# 	movie_id	:	tt0095652
# 	summary_text	:	When Allan becomes a quadriplegic he loses all hope for living until he meets Ella - a monkey trained to fetch and carry for him around the house, obeying him in all things. But Ella is part of another experiment, and when she starts responding to Allan's underlying rage and frustration she has the ability to carry out her master's darkest wishes.
#
# —David Carroll <davidc@atom.ansto.gov.au>
# Summary 31
# ----------
# 	summary_id	:	31
# 	movie_id	:	tt1134854
# 	summary_text	:	On an island off the coast of North America, local residents simultaneously fight a zombie epidemic while hoping for a cure to return their un-dead relatives back to their human state.
#
# —Anonymous
# Summary 32
# ----------
# 	summary_id	:	32
# 	movie_id	:	tt1134854
# 	summary_text	:	In the Plum Island, off the coast of Delaware, the long feud between the families of the patriarchs Captain Patrick O'Flynn (Kenneth Welsh) that intends to eliminate the zombies and Seamus Muldoon (Richard Fitzpatrick) that intends to keep his undead relatives waiting for a cure culminates with O'Flynn expelled from Plum. Meanwhile in the continent Sarge 'Nicotine' Crocket (Alan Van Sprang), Ch...
# Summary 33
# ----------
# 	summary_id	:	33
# 	movie_id	:	tt0088993
# 	summary_text	:	A small group of military officers and scientists dwell in an underground bunker as the world above is overrun by zombies.
#
# —Anonymous
# Summary 34
# ----------
# 	summary_id	:	34
# 	movie_id	:	tt0088993
# 	summary_text	:	Zombies rule the world, except for a small group of scientists and military personnel who reside in an underground bunker in Florida. The scientists are using the undead in gruesome experiments; much to the chagrin of the military. Finally the military finds that their men have been used in the scientists' experiments, and banish the scientists to the caves that house the Living Dead. Unfortuna...
# Summary 35
# ----------
# 	summary_id	:	35
# 	movie_id	:	tt0082622
# 	summary_text	:	A medieval reenactment troupe find it increasingly difficult to keep their family-like group together, with pressure from local law enforcement, interest from entertainment agents and a growing sense of delusion from their leader.
#
# —Daniel Jos. Leary
# Summary 36
# ----------
# 	summary_id	:	36
# 	movie_id	:	tt0082622
# 	summary_text	:	A travelling troupe of jousters and performers are slowly cracking under the pressure of hick cops, financial troubles and their failure to live up to their own ideals. The group's leader, King Billy, is increasingly unable to maintain his warrior's rule while the Black Knight is being tempted away to LA and stardom, as they all have to ask why they were here in the first place.
#
# —David Carroll...
# Summary 37
# ----------
# 	summary_id	:	37
# 	movie_id	:	tt0077402
# 	summary_text	:	Following an ever-growing epidemic of zombies that have risen from the dead, two Philadelphia S.W.A.T. team members, a traffic reporter, and his television executive girlfriend seek refuge in a secluded shopping mall.
#
# —Anonymous
# Summary 38
# ----------
# 	summary_id	:	38
# 	movie_id	:	tt0077402
# 	summary_text	:	The zombie apocalypse has hit Earth. Two personnel from a TV station and two policemen set off in a helicopter to find a safe place to hide out. Their search leads them to a shopping mall where they manage to find a place that, while not zombie-free, is quite secure. So far, so good.
#
# —grantss
# Summary 39
# ----------
# 	summary_id	:	39
# 	movie_id	:	tt0848557
# 	summary_text	:	A group of young film students run into real-life zombies while filming a horror movie of their own.
#
# —Anonymous
# Summary 40
# ----------
# 	summary_id	:	40
# 	movie_id	:	tt0848557
# 	summary_text	:	While filming a horror movie of mummy in a forest, the students and their professor of the University of Pittsburgh hear on the TV the news that the dead are awaking and walking. Ridley and Francine decide to leave the group, while Jason heads to the dormitory of his girlfriend Debra Monahan. She does not succeed in contacting her family and they travel in Mary's van to the house of Debra's par...
# Summary 41
# ----------
# 	summary_id	:	41
# 	movie_id	:	tt0067341
# 	summary_text	:	A recently institutionalized woman has bizarre experiences after moving into a supposedly haunted country farmhouse and fears she may be losing her sanity once again.
#
# —Scott
# Summary 42
# ----------
# 	summary_id	:	42
# 	movie_id	:	tt0067341
# 	summary_text	:	After a stint in a psychiatric facility Jessica, her husband and a friend move to remote farm they have recently purchased. There they find a young woman by the name of Emily living in the house and they invite her to stay. When Jessica goes for a swim in the lake, she sees a body just below the water's surface. When they go into the village to sell some old furniture, they learn that a woman b...
# Summary 43
# ----------
# 	summary_id	:	43
# 	movie_id	:	tt0418819
# 	summary_text	:	The living dead have taken over the world, and the last humans live in a walled city to protect themselves as they come to grips with the situation.
#
# —Erik Paniccia
# Summary 44
# ----------
# 	summary_id	:	44
# 	movie_id	:	tt0418819
# 	summary_text	:	Now that zombies have taken over the world, the living have built a walled-in city to keep the dead out. But all's not well where it's most safe, as a revolution plans to overthrow the city leadership, and the zombies are turning into more advanced creatures.
#
# —Anonymous
# Summary 45
# ----------
# 	summary_id	:	45
# 	movie_id	:	tt0119177
# 	summary_text	:	A genetically inferior man assumes the identity of a superior one in order to pursue his lifelong dream of space travel.
#
# —Anonymous
# Summary 46
# ----------
# 	summary_id	:	46
# 	movie_id	:	tt0119177
# 	summary_text	:	In the not-too-distant future, a less-than-perfect man wants to travel to the stars. Society has categorized Vincent Freeman as less than suitable given his genetic make-up and he has become one of the underclass of humans that are only useful for menial jobs. To move ahead, he assumes the identity of Jerome Morrow, a perfect genetic specimen who is a paraplegic as a result of a car accident. W...
# Summary 47
# ----------
# 	summary_id	:	47
# 	movie_id	:	tt0253556
# 	summary_text	:	A brood of fire-breathing dragons emerges from the earth and begins setting everything ablaze, establishing dominance over the planet.
#
# —Anonymous
# Summary 48
# ----------
# 	summary_id	:	48
# 	movie_id	:	tt0253556
# 	summary_text	:	In present-day London, 12-year-old Quinn Abercromby witnesses the awakening of a hibernating dragon from a centuries-long slumber, the result of a construction dig supervised by his mother and an incident for which Quinn feels partially responsible. Twenty years later, the adult Quinn (Christian Bale) is the fire chief of a refortified castle community, responsible for dousing the blazes lit by...
# Summary 49
# ----------
# 	summary_id	:	49
# 	movie_id	:	tt0119116
# 	summary_text	:	In the colorful future, a cab driver unwittingly becomes the central figure in the search for a legendary cosmic weapon to keep Evil and Mr. Zorg at bay.
#
# —Murray Chapman
# Summary 50
# ----------
# 	summary_id	:	50
# 	movie_id	:	tt0119116
# 	summary_text	:	In the twenty-third century, the universe is threatened by evil. The only hope for mankind is the Fifth Element, who comes to Earth every five thousand years to protect the humans with four stones of the four elements: fire, water, Earth and air. A Mondoshawan spacecraft is bringing The Fifth Element back to Earth but it is destroyed by the evil Mangalores. However, a team of scientists use the...
# Summary 51
# ----------
# 	summary_id	:	51
# 	movie_id	:	tt0448134
# 	summary_text	:	A team of international astronauts are sent on a dangerous mission to reignite the dying Sun with a nuclear fission bomb in 2057.
#
# —Skip4591
# Summary 52
# ----------
# 	summary_id	:	52
# 	movie_id	:	tt0448134
# 	summary_text	:	50 years into the future, the Sun begins to die, and Earth is dying as a result. A team of astronauts is sent to revive the Sun - but the mission fails. Seven years later, a new team is sent to finish the mission as mankind's last hope.
#
# —harpster_2004@yahoo.co.uk
# Summary 53
# ----------
# 	summary_id	:	53
# 	movie_id	:	tt0361862
# 	summary_text	:	An industrial worker who hasn't slept in a year begins to doubt his own sanity.
#
# —IMDb Editors
# Summary 54
# ----------
# 	summary_id	:	54
# 	movie_id	:	tt0361862
# 	summary_text	:	Trevor Reznik is a machinist in a factory. An extreme case of insomnia has led to him not sleeping in a year, and his body withering away to almost nothing. He has an obsessive compulsion to write himself reminder notes and keep track of his dwindling weight, both scribbled on yellow stickies in his apartment. The only person he lets into his life in an emotional sense is Stevie, a prostitute, ...
# Summary 55
# ----------
# 	summary_id	:	55
# 	movie_id	:	tt0118929
# 	summary_text	:	A man struggles with memories of his past, which includes a wife he cannot remember, and a nightmarish world, no one else seems to be waking up from.
#
# —John Sacksteder <jsack@ka.net>
# Summary 56
# ----------
# 	summary_id	:	56
# 	movie_id	:	tt0118929
# 	summary_text	:	John Murdoch awakens alone in a strange hotel to find that he has lost his memory and is wanted for a series of brutal and bizarre murders. While trying to piece together his past, he stumbles upon a fiendish underworld controlled by a group of beings known as The Strangers who possess the ability to put people to sleep and alter the city and its inhabitants. Now Murdoch must find a way to stop...
# Summary 57
# ----------
# 	summary_id	:	57
# 	movie_id	:	tt1182345
# 	summary_text	:	Astronaut Sam Bell has a quintessentially personal encounter toward the end of his three-year stint on the Moon, where he, working alongside his computer, GERTY, sends back to Earth parcels of a resource that has helped diminish our planet's power problems.
#
# —Anonymous
# Summary 58
# ----------
# 	summary_id	:	58
# 	movie_id	:	tt1182345
# 	summary_text	:	Sam Bell has a three year contract to work for Lunar Industries. For the contract's entire duration, he is the sole employee based at their lunar station. His primary job responsibility is to harvest and periodically rocket back to Earth supplies of helium-3, the current clean and abundant fuel used on Earth. There is no direct communication link available between the lunar station and Earth, s...
# Summary 59
# ----------
# 	summary_id	:	59
# 	movie_id	:	tt0118884
# 	summary_text	:	Dr. Ellie Arroway, after years of searching, finds conclusive radio proof of extraterrestrial intelligence, sending plans for a mysterious machine.
#
# —Jon Reeves <jreeves@imdb.com>
# Summary 60
# ----------
# 	summary_id	:	60
# 	movie_id	:	tt0118884
# 	summary_text	:	Astronomer Dr. Ellie Arroway has long been interested in contact to faraway lands, a love fostered in her childhood by her father, Ted Arroway (David Morse), who died when she was nine-years-old, leaving her orphaned. Her current work in monitoring for extraterrestrial life is based on that love and is in part an homage to her father. Ever since funding from the National Science Foundation (N.S...
# Summary 61
# ----------
# 	summary_id	:	61
# 	movie_id	:	tt0462504
# 	summary_text	:	A U.S. fighter pilot's epic struggle of survival after being shot down on a mission over Laos during the Vietnam War.
# Summary 62
# ----------
# 	summary_id	:	62
# 	movie_id	:	tt0462504
# 	summary_text	:	In 1965, while bombing Laos in a classified mission, the propeller plane of the German-American US Navy pilot Dieter Dengler is hit and crashes in the jungle. Dieter is arrested by the peasants, tortured by the Vietcong and sent to a prisoner camp, where he meets five other mentally deranged prisoners and guards. He becomes close to Duane and organizes an escape plan; however, the unstable Gene...
# Summary 63
# ----------
# 	summary_id	:	63
# 	movie_id	:	tt0381849
# 	summary_text	:	A small-time rancher agrees to hold a captured outlaw who's awaiting a train to go to court in Yuma. A battle of wills ensues as the outlaw tries to psych out the rancher.
#
# —Anonymous
# Summary 64
# ----------
# 	summary_id	:	64
# 	movie_id	:	tt0381849
# 	summary_text	:	Rancher Dan Evans heads into Bisbee to clear up issues concerning the sale of his land when he witnesses the closing events of a stagecoach robbery led by famed outlaw Ben Wade. Shortly thereafter, Wade is captured by the law in Bisbee and Evans finds himself one of the escorts who will take Wade to the 3:10 to Yuma train in Contention for the reward of $200. Evans' effort to take Wade to the s...
# Summary 65
# ----------
# 	summary_id	:	65
# 	movie_id	:	tt0433387
# 	summary_text	:	A tough-minded drama about two friends in South Central Los Angeles and the violence that comes between them.
#
# —Anonymous
# Summary 66
# ----------
# 	summary_id	:	66
# 	movie_id	:	tt0433387
# 	summary_text	:	Jim Davis is an ex-Army Ranger who finds himself slipping back into his old life of petty crime after a job offer from the LAPD evaporates. His best friend is pressured by his girlfriend Sylvia to find a job, but Jim is more interested in hanging out and making cash from small heists, while trying to get a law enforcement job so he can marry his Mexican girlfriend.
#
# —batfreak79
# Summary 67
# ----------
# 	summary_id	:	67
# 	movie_id	:	tt0114746
# 	summary_text	:	In a future world devastated by disease, a convict is sent back in time to gather information about the man-made virus that wiped out most of the human population on the planet.
#
# —Anonymous
# Summary 68
# ----------
# 	summary_id	:	68
# 	movie_id	:	tt0114746
# 	summary_text	:	An intense film about time travel, this Sci-Fi entry was directed by Terry Gilliam, a member of the comedy troupe Monty Python. The film stars Bruce Willis as James Cole, a prisoner of the state in the year 2035 who can earn parole if he agrees to travel back in time and thwart a devastating plague. The virus has wiped out most of the Earth's population and the remainder live underground becaus...
#
# ======================
# ||                  ||
# ||     4. Quote     ||
# ||                  ||
# ======================
# Quote 0
# -------
# 	quote_id	:	0
# 	movie_id	:	tt0859635
# 	quote_text	:	Genevieve Aubois:
# I coach a girls hockey team so I know my way around a gash.
# Quote 1
# -------
# 	quote_id	:	1
# 	movie_id	:	tt0859635
# 	quote_text	:	Guy LeFranc:
# Great Tim Horton's ghost!
# Quote 2
# -------
# 	quote_id	:	2
# 	movie_id	:	tt0486551
# 	quote_text	:	Barry Badrinath:
# I wish it were winter so we could freeze it into ice blocks and skate on it and melt it in the spring time and drink it!
# Quote 3
# -------
# 	quote_id	:	3
# 	movie_id	:	tt0486551
# 	quote_text	:	Barry Badrinath:
# I was in Thailand playing ping-pong in Ding Dang. I was in a real high stakes game in some opium den. Turns out the guys I was playing aren't the kind of guys who like to lose. After I beat 'em, they beat me. Worked me over pretty good. And this is hard to say... they held me down and shoved a ping-pong paddle up my ass. It's never been the same. Damaged goods.
# Steve 'Fink' Fi...
# Quote 4
# -------
# 	quote_id	:	4
# 	movie_id	:	tt0331953
# 	quote_text	:	Putman:
# [with disdain]
# What kind of a man has sex with a goat?
# Juan:
# Hey, I used a condom.
# Jenny:
# [who had had sex with Juan]
# You told me they were against your religion.
# Juan:
# Ehh, you know, I need to find Peen-a-lope. I am sure you all understand.
# Quote 5
# -------
# 	quote_id	:	5
# 	movie_id	:	tt0331953
# 	quote_text	:	Juan:
# [after 'interrogating' Penelope by having passionate sex]
# I may need a few more hours to pump her for information.
# Quote 6
# -------
# 	quote_id	:	6
# 	movie_id	:	tt0456554
# 	quote_text	:	Alex:
# Anyway, I was wondering if maybe I could crash here for a while.
# Dante:
# Whoa, I don't know, man. I got a business to run. This is like my office as well as my home. Plus, the lion comes in a couple days.
# Alex:
# You're getting a lion?
# Dante:
# Yeah.
# Alex:
# Why?
# Dante:
# To protect my shit.
# Alex:
# Never heard of a dog?
# Dante:
# Dude, you can get past a dog. Nobody fucks with a lion.
# Alex:
# Ye...
# Quote 7
# -------
# 	quote_id	:	7
# 	movie_id	:	tt0456554
# 	quote_text	:	Alex:
# Dude, your bed is a car...
# Jeff:
# Yeah, but it's a fucking sweet car.
# Quote 8
# -------
# 	quote_id	:	8
# 	movie_id	:	tt1135525
# 	quote_text	:	Cleon Salmon:
# You know what ten grand feels like in your pocket? It feels like a third cock.
# Quote 9
# -------
# 	quote_id	:	9
# 	movie_id	:	tt1135525
# 	quote_text	:	Cleon Salmon:
# Who is Guy... Meatdrapes? What kind of name is that?
# Guy:
# It's, um, it's Metdrapedes, sir. It's Greek.
# Cleon Salmon:
# I think you're pronouncing it wrong. This says Meatdrapes.
# Guy:
# It's actually pronounced Metdrapedes.
# Cleon Salmon:
# Well, why doesn't it sound like that when I say it? Meatdrapes.
# Quote 10
# --------
# 	quote_id	:	10
# 	movie_id	:	tt0245686
# 	quote_text	:	Joe Dirt:
# So you're gonna tell me that you don't have no black cats, no Roman Candles, or screaming mimis?
# Kicking Wing:
# No.
# Joe Dirt:
# Oh come on, man. You got no lady fingers, fuzz buttles, snicker bombs, church burners, finger blasters, gut busters, zippity do das, or crap flappers?
# Kicking Wing:
# No, I don't.
# Joe Dirt:
# You're gonna stand there, ownin' a fireworks stand, and tell me you do...
# Quote 11
# --------
# 	quote_id	:	11
# 	movie_id	:	tt0245686
# 	quote_text	:	Clem:
# [talking to fire extinguisher]
# You're talking to me all wrong... It's the wrong tone. You do it again and I'll stab you in the face with a soldering iron. Hey, tell me, does your mother sew? BOOM. Get her to sew that!
# Quote 12
# --------
# 	quote_id	:	12
# 	movie_id	:	tt0114694
# 	quote_text	:	[saying it correctly]
#
# Tommy:
# I can get a good look at a T-bone by sticking my head up a bull's ass, but I'd rather take a butcher's word for it.
# Quote 13
# --------
# 	quote_id	:	13
# 	movie_id	:	tt0114694
# 	quote_text	:	Tommy:
# Brothers don't shake hands. Brothers gotta hug.
# Quote 14
# --------
# 	quote_id	:	14
# 	movie_id	:	tt0115697
# 	quote_text	:	[phoning citizens in an attempt to secure votes]
#
# Mike:
# Hi there, this is Mike Donnelly. I work over here at the recreational center. To be honest with you, I pretty much run the place ha, ha, ha. Is this ah Pat Gyles? Good, Good. Hey, hope everything's going great in your fine town of... er... Avery? Edward! Ha, ha, ha. Say, the reason I'm calling is I wanted to tell you a little bit about the...
# Quote 15
# --------
# 	quote_id	:	15
# 	movie_id	:	tt0115697
# 	quote_text	:	[Mike is pretending to be a cop, Steve is pretending to be a prisoner]
#
# Steve:
# Ro-ads. Ro-ods.
# Mike:
# Quiet back there! I've taken enough guff from you for one day!
# [turns to state trooper]
#
# Mike:
# Raving psycho! Butchered 400 chickens and screwed a beagle. I'm taking him back to Nevada where he's wanted for banging horses!
# Quote 16
# --------
# 	quote_id	:	16
# 	movie_id	:	tt0144557
# 	quote_text	:	Zach:
# So what's his name?
# Felix Bean:
# Traci Shannon.
# Zach:
# Traci Shannon! That's not just a firsty, firsty. It's also a girly girly
# Quote 17
# --------
# 	quote_id	:	17
# 	movie_id	:	tt0144557
# 	quote_text	:	Matt:
# Well hey, Sara.
# Sara:
# Hey, Matt. Grogan's so funny.
# Matt:
# Yeah. Hey, sounds to me like you like him.
# Sara:
# Well...
# Matt:
# Wow. You and Garbage Dick. That's great, I mean he was just saying that...
# Sara:
# Wait, what did you say?
# Matt:
# I was just saying how Garbage Dick told me how he thought you were...
# Sara:
# Garbage Dick?
# Matt:
# Yeah. Oh, no, no. It's no big deal. I mean, that was at...
# Quote 18
# --------
# 	quote_id	:	18
# 	movie_id	:	tt0348333
# 	quote_text	:	Monty:
# [using a Forrest Gump voice]
# Momma said they's my magic shoes. Mama said they would take me anywhere. 'Course Mama used to beat me with a rubber hose and call me a retard.
# Quote 19
# --------
# 	quote_id	:	19
# 	movie_id	:	tt0348333
# 	quote_text	:	Dan:
# We need to seize the day. Be enthusiastic.
# Floyd:
# [enthusiastically]
# Yeah! Carpe deez nuts! God I can't wait to quit this job!
# Quote 20
# --------
# 	quote_id	:	20
# 	movie_id	:	tt0366551
# 	quote_text	:	Harold:
# Did Doogie Howser just steal my fucking car?
# Quote 21
# --------
# 	quote_id	:	21
# 	movie_id	:	tt0366551
# 	quote_text	:	Harold:
# So what are you in here for?
# Tarik:
# For being black.
# Harold:
# Seriously.
# Tarik:
# I am serious. You wanna know what happened? I was walking out of a Barnes & Noble, and a cop stops me. Now evidently, a black guy robbed a store in Newark. I told him, 'I haven't even been to Newark in months.' So he starts beating me with his gun, telling me to stop resisting arrest.
# Harold:
# Holy shit! W...
# Quote 22
# --------
# 	quote_id	:	22
# 	movie_id	:	tt0069239
# 	quote_text	:	Shirley:
# [reading from the Witchcraft primer]
# 'The religion offers, further, a retreat for emotional women, repressed women, masculine women and those suffering from personal disappointment or nervous maladjustment.' Christ, what other kind of women are there? No wonder this stuff's getting so damn popular.
# Quote 23
# --------
# 	quote_id	:	23
# 	movie_id	:	tt0069239
# 	quote_text	:	Jack:
# Your own goddamned daughter, balled in the next room and you go with it.
# Quote 24
# --------
# 	quote_id	:	24
# 	movie_id	:	tt0077914
# 	quote_text	:	Martin Madahas:
# Things only seem to be magic. There is no real magic. There's no real magic ever.
# Quote 25
# --------
# 	quote_id	:	25
# 	movie_id	:	tt0077914
# 	quote_text	:	Christina:
# How old are you, Martin?
# Martin Madahas:
# Oh, I'm old.
# Christina:
# How old?
# Martin Madahas:
# Eighty four.
# Quote 26
# --------
# 	quote_id	:	26
# 	movie_id	:	tt0455407
# 	quote_text	:	David Dutton:
# Don't ask me why I can't leave without my wife and I won't ask you why you can.
# Quote 27
# --------
# 	quote_id	:	27
# 	movie_id	:	tt0455407
# 	quote_text	:	David Dutton:
# [In the car wash, to the Deputy firing his shotgun out of the car window]
# RUSSELL!
# Russell Clank:
# I saw a movement!
# David Dutton:
# Everything is fuckin' moving!
# Quote 28
# --------
# 	quote_id	:	28
# 	movie_id	:	tt0166843
# 	quote_text	:	Chris Bradley:
# Dad, I just don't want to go to work in your baby food factory. And, I don't want to sell vacuum cleaners. I don't want to sell little toy plastic aircraft carriers. I don't wanna... I don't know what I want.
# Mr. Bradley:
# Chris, I think I understand what you're talking about. A little bit anyway. But these problems are a little bit like going to Howard Johnsons for some ice crea...
# Quote 29
# --------
# 	quote_id	:	29
# 	movie_id	:	tt0166843
# 	quote_text	:	Mr. Bradley:
# Chris... why don't you let me send you back to school? I might as well put my money to good use.
# Chris Bradley:
# No thanks, Dad, I don't want to hold back my education.
# Mr. Bradley:
# You better come down out of those clouds, boy... or you're not going to be worth the powder to blow you to hell.
# Quote 30
# --------
# 	quote_id	:	30
# 	movie_id	:	tt0095652
# 	quote_text	:	Geoffrey Fisher:
# You're a clinical cunt.
# Quote 31
# --------
# 	quote_id	:	31
# 	movie_id	:	tt0095652
# 	quote_text	:	Geoffrey Fisher:
# That's one of the advantages of working in a chem lab. I finally figured it out, Allan. Every three days that I stay awake, I gain 24 hours. That's 122 days every year. So even if I die at 50, I will have lived 65 years.
# Quote 32
# --------
# 	quote_id	:	32
# 	movie_id	:	tt1134854
# 	quote_text	:	Sarge 'Nicotine' Crocket:
# Where's Cisco?
# Tomboy:
# He's... in heaven... telling the Virgin Mary he can change her life.
# Quote 33
# --------
# 	quote_id	:	33
# 	movie_id	:	tt1134854
# 	quote_text	:	[first lines]
#
# Sarge 'Nicotine' Crocket:
# [voice-over]
# Last time anyone counted, fifty-three million people were dying every year, a hundred-fifty thousand every day, a hundred and seven every minute, and that was in normal times.
# Quote 34
# --------
# 	quote_id	:	34
# 	movie_id	:	tt0088993
# 	quote_text	:	Captain Rhodes:
# [as the zombies are disembowling him and eating his entrails]
# Choke on 'em!
# Quote 35
# --------
# 	quote_id	:	35
# 	movie_id	:	tt0088993
# 	quote_text	:	Dr. Logan:
# [interrupting Rhodes]
# Is there food?
# Rhodes:
# [screaming]
# I'm running this monkey farm now Frankenstein and I wanna know... what the fuck you're doing with my time?
# Quote 36
# --------
# 	quote_id	:	36
# 	movie_id	:	tt0082622
# 	quote_text	:	Linet:
# Everybody here made a conscious, adult decision to be here. To be with you. When you go crazy, you force them to rethink that decision. You've got to...
# Billy:
# Compromise.
# Linet:
# Change doesn't have to mean compromise. We're bigger now. Things are different. Christ, we've got an overhead.
# Billy:
# Publicity helps the overhead by bringing in more crowds, more suckerheaded American driftw...
# Quote 37
# --------
# 	quote_id	:	37
# 	movie_id	:	tt0082622
# 	quote_text	:	Merlin:
# If I didn't believe in magic, I'd still be treating gall bladders, prostates and stuff like that. See, magic ain't got nothing to do with organs and glands and busted necks. Magic got to do with the soul, man. Only the soul's got destiny. It got wings. It's can fly. That's magic. The body? The body's just got a few minutes down here in the dirt with the rest of us.
# Billy:
# You see thing...
# Quote 38
# --------
# 	quote_id	:	38
# 	movie_id	:	tt0077402
# 	quote_text	:	Francine Parker:
# They're still here.
# Stephen:
# They're after us. They know we're still in here.
# Peter:
# They're after the place. They don't know why; they just remember. Remember that they want to be in here.
# Francine Parker:
# What the hell are they?
# Peter:
# They're us, that's all, when there's no more room in hell.
# Stephen:
# What?
# ...
# Role 57
# -------
# 	movie_id	:	tt0077914
# 	role_code	:	1
# 	person_id	:	51
# Role 58
# -------
# 	movie_id	:	tt0077914
# 	role_code	:	2
# 	person_id	:	100
# Role 59
# -------
# 	movie_id	:	tt0077914
# 	role_code	:	2
# 	person_id	:	50
# Role 60
# -------
# 	movie_id	:	tt0077914
# 	role_code	:	2
# 	person_id	:	37
# Role 61
# -------
# 	movie_id	:	tt0455407
# 	role_code	:	0
# 	person_id	:	9
# Role 62
# -------
# 	movie_id	:	tt0455407
# 	role_code	:	1
# 	person_id	:	115
# Role 63
# -------
# 	movie_id	:	tt0455407
# 	role_code	:	2
# 	person_id	:	84
# Role 64
# -------
# 	movie_id	:	tt0455407
# 	role_code	:	2
# 	person_id	:	119
# Role 65
# -------
# 	movie_id	:	tt0455407
# 	role_code	:	2
# 	person_id	:	8
# Role 66
# -------
# 	movie_id	:	tt0166843
# 	role_code	:	0
# 	person_id	:	51
# Role 67
# -------
# 	movie_id	:	tt0166843
# 	role_code	:	1
# 	person_id	:	49
# Role 68
# -------
# 	movie_id	:	tt0166843
# 	role_code	:	2
# 	person_id	:	22
# Role 69
# -------
# 	movie_id	:	tt0166843
# 	role_code	:	2
# 	person_id	:	83
# Role 70
# -------
# 	movie_id	:	tt0166843
# 	role_code	:	2
# 	person_id	:	61
# Role 71
# -------
# 	movie_id	:	tt0095652
# 	role_code	:	0
# 	person_id	:	51
# Role 72
# -------
# 	movie_id	:	tt0095652
# 	role_code	:	1
# 	person_id	:	54
# Role 73
# -------
# 	movie_id	:	tt0095652
# 	role_code	:	2
# 	person_id	:	13
# Role 74
# -------
# 	movie_id	:	tt0095652
# 	role_code	:	2
# 	person_id	:	62
# Role 75
# -------
# 	movie_id	:	tt0095652
# 	role_code	:	2
# 	person_id	:	87
# Role 76
# -------
# 	movie_id	:	tt1134854
# 	role_code	:	0
# 	person_id	:	51
# Role 77
# -------
# 	movie_id	:	tt1134854
# 	role_code	:	1
# 	person_id	:	51
# Role 78
# -------
# 	movie_id	:	tt1134854
# 	role_code	:	2
# 	person_id	:	24
# Role 79
# -------
# 	movie_id	:	tt1134854
# 	role_code	:	2
# 	person_id	:	96
# Role 80
# -------
# 	movie_id	:	tt1134854
# 	role_code	:	2
# 	person_id	:	93
# Role 81
# -------
# 	movie_id	:	tt0088993
# 	role_code	:	0
# 	person_id	:	51
# Role 82
# -------
# 	movie_id	:	tt0088993
# 	role_code	:	1
# 	person_id	:	51
# Role 83
# -------
# 	movie_id	:	tt0088993
# 	role_code	:	2
# 	person_id	:	55
# Role 84
# -------
# 	movie_id	:	tt0088993
# 	role_code	:	2
# 	person_id	:	110
# Role 85
# -------
# 	movie_id	:	tt0088993
# 	role_code	:	2
# 	person_id	:	39
# Role 86
# -------
# 	movie_id	:	tt0082622
# 	role_code	:	0
# 	person_id	:	51
# Role 87
# -------
# 	movie_id	:	tt0082622
# 	role_code	:	1
# 	person_id	:	51
# Role 88
# -------
# 	movie_id	:	tt0082622
# 	role_code	:	2
# 	person_id	:	58
# Role 89
# -------
# 	movie_id	:	tt0082622
# 	role_code	:	2
# 	person_id	:	81
# Role 90
# -------
# 	movie_id	:	tt0082622
# 	role_code	:	2
# 	person_id	:	85
# Role 91
# -------
# 	movie_id	:	tt0077402
# 	role_code	:	0
# 	person_id	:	51
# Role 92
# -------
# 	movie_id	:	tt0077402
# 	role_code	:	1
# 	person_id	:	51
# Role 93
# -------
# 	movie_id	:	tt0077402
# 	role_code	:	2
# 	person_id	:	14
# Role 94
# -------
# 	movie_id	:	tt0077402
# 	role_code	:	2
# 	person_id	:	77
# Role 95
# -------
# 	movie_id	:	tt0077402
# 	role_code	:	2
# 	person_id	:	45
# Role 96
# -------
# 	movie_id	:	tt0848557
# 	role_code	:	0
# 	person_id	:	51
# Role 97
# -------
# 	movie_id	:	tt0848557
# 	role_code	:	1
# 	person_id	:	51
# Role 98
# -------
# 	movie_id	:	tt0848557
# 	role_code	:	2
# 	person_id	:	106
# Role 99
# -------
# 	movie_id	:	tt0848557
# 	role_code	:	2
# 	person_id	:	25
# Role 100
# --------
# 	movie_id	:	tt0848557
# 	role_code	:	2
# 	person_id	:	1
# Role 101
# --------
# 	movie_id	:	tt0067341
# 	role_code	:	0
# 	person_id	:	95
# Role 102
# --------
# 	movie_id	:	tt0067341
# 	role_code	:	1
# 	person_id	:	95
# Role 103
# --------
# 	movie_id	:	tt0067341
# 	role_code	:	2
# 	person_id	:	82
# Role 104
# --------
# 	movie_id	:	tt0067341
# 	role_code	:	2
# 	person_id	:	109
# Role 105
# --------
# 	movie_id	:	tt0067341
# 	role_code	:	2
# 	person_id	:	91
# Role 106
# --------
# 	movie_id	:	tt0418819
# 	role_code	:	0
# 	person_id	:	51
# Role 107
# --------
# 	movie_id	:	tt0418819
# 	role_code	:	1
# 	person_id	:	51
# Role 108
# --------
# 	movie_id	:	tt0418819
# 	role_code	:	2
# 	person_id	:	118
# Role 109
# --------
# 	movie_id	:	tt0418819
# 	role_code	:	2
# 	person_id	:	3
# Role 110
# --------
# 	movie_id	:	tt0418819
# 	role_code	:	2
# 	person_id	:	17
# Role 111
# --------
# 	movie_id	:	tt0119177
# 	role_code	:	0
# 	person_id	:	53
# Role 112
# --------
# 	movie_id	:	tt0119177
# 	role_code	:	1
# 	person_id	:	53
# Role 113
# --------
# 	movie_id	:	tt0119177
# 	role_code	:	2
# 	person_id	:	74
# Role 114
# --------
# 	movie_id	:	tt0119177
# 	role_code	:	2
# 	person_id	:	16
# Role 115
# --------
# 	movie_id	:	tt0119177
# 	role_code	:	2
# 	person_id	:	28
# Role 116
# --------
# 	movie_id	:	tt0253556
# 	role_code	:	0
# 	person_id	:	7
# Role 117
# --------
# 	movie_id	:	tt0253556
# 	role_code	:	1
# 	person_id	:	92
# Role 118
# --------
# 	movie_id	:	tt0253556
# 	role_code	:	2
# 	person_id	:	36
# Role 119
# --------
# 	movie_id	:	tt0253556
# 	role_code	:	2
# 	person_id	:	70
# Role 120
# --------
# 	movie_id	:	tt0253556
# 	role_code	:	2
# 	person_id	:	42
# Role 121
# --------
# 	movie_id	:	tt0119116
# 	role_code	:	0
# 	person_id	:	103
# Role 122
# --------
# 	movie_id	:	tt0119116
# 	role_code	:	1
# 	person_id	:	103
# Role 123
# --------
# 	movie_id	:	tt0119116
# 	role_code	:	2
# 	person_id	:	21
# Role 124
# --------
# 	movie_id	:	tt0119116
# 	role_code	:	2
# 	person_id	:	44
# Role 125
# --------
# 	movie_id	:	tt0119116
# 	role_code	:	2
# 	person_id	:	90
# Role 126
# --------
# 	movie_id	:	tt0448134
# 	role_code	:	0
# 	person_id	:	11
# Role 127
# --------
# 	movie_id	:	tt0448134
# 	role_code	:	1
# 	person_id	:	97
# Role 128
# --------
# 	movie_id	:	tt0448134
# 	role_code	:	2
# 	person_id	:	34
# Role 129
# --------
# 	movie_id	:	tt0448134
# 	role_code	:	2
# 	person_id	:	68
# Role 130
# --------
# 	movie_id	:	tt0448134
# 	role_code	:	2
# 	person_id	:	94
# Role 131
# --------
# 	movie_id	:	tt0361862
# 	role_code	:	0
# 	person_id	:	80
# Role 132
# --------
# 	movie_id	:	tt0361862
# 	role_code	:	1
# 	person_id	:	115
# Role 133
# --------
# 	movie_id	:	tt0361862
# 	role_code	:	2
# 	person_id	:	70
# Role 134
# --------
# 	movie_id	:	tt0361862
# 	role_code	:	2
# 	person_id	:	63
# Role 135
# --------
# 	movie_id	:	tt0361862
# 	role_code	:	2
# 	person_id	:	78
# Role 136
# --------
# 	movie_id	:	tt0118929
# 	role_code	:	0
# 	person_id	:	33
# Role 137
# --------
# 	movie_id	:	tt0118929
# 	role_code	:	1
# 	person_id	:	33
# Role 138
# --------
# 	movie_id	:	tt0118929
# 	role_code	:	2
# 	person_id	:	88
# Role 139
# --------
# 	movie_id	:	tt0118929
# 	role_code	:	2
# 	person_id	:	26
# Role 140
# --------
# 	movie_id	:	tt0118929
# 	role_code	:	2
# 	person_id	:	64
# Role 141
# --------
# 	movie_id	:	tt1182345
# 	role_code	:	0
# 	person_id	:	101
# Role 142
# --------
# 	movie_id	:	tt1182345
# 	role_code	:	1
# 	person_id	:	101
# Role 143
# --------
# 	movie_id	:	tt1182345
# 	role_code	:	2
# 	person_id	:	4
# Role 144
# --------
# 	movie_id	:	tt1182345
# 	role_code	:	2
# 	person_id	:	107
# Role 145
# --------
# 	movie_id	:	tt1182345
# 	role_code	:	2
# 	person_id	:	15
# Role 146
# --------
# 	movie_id	:	tt0118884
# 	role_code	:	0
# 	person_id	:	41
# Role 147
# --------
# 	movie_id	:	tt0118884
# 	role_code	:	1
# 	person_id	:	75
# Role 148
# --------
# 	movie_id	:	tt0118884
# 	role_code	:	2
# 	person_id	:	112
# Role 149
# --------
# 	movie_id	:	tt0118884
# 	role_code	:	2
# 	person_id	:	36
# Role 150
# --------
# 	movie_id	:	tt0118884
# 	role_code	:	2
# 	person_id	:	114
# Role 151
# --------
# 	movie_id	:	tt0462504
# 	role_code	:	0
# 	person_id	:	46
# Role 152
# --------
# 	movie_id	:	tt0462504
# 	role_code	:	1
# 	person_id	:	46
# Role 153
# --------
# 	movie_id	:	tt0462504
# 	role_code	:	2
# 	person_id	:	70
# Role 154
# --------
# 	movie_id	:	tt0462504
# 	role_code	:	2
# 	person_id	:	19
# Role 155
# --------
# 	movie_id	:	tt0462504
# 	role_code	:	2
# 	person_id	:	38
# Role 156
# --------
# 	movie_id	:	tt0381849
# 	role_code	:	0
# 	person_id	:	111
# Role 157
# --------
# 	movie_id	:	tt0381849
# 	role_code	:	1
# 	person_id	:	47
# Role 158
# --------
# 	movie_id	:	tt0381849
# 	role_code	:	2
# 	person_id	:	56
# Role 159
# --------
# 	movie_id	:	tt0381849
# 	role_code	:	2
# 	person_id	:	70
# Role 160
# --------
# 	movie_id	:	tt0381849
# 	role_code	:	2
# 	person_id	:	2
# Role 161
# --------
# 	movie_id	:	tt0433387
# 	role_code	:	0
# 	person_id	:	104
# Role 162
# --------
# 	movie_id	:	tt0433387
# 	role_code	:	1
# 	person_id	:	104
# Role 163
# --------
# 	movie_id	:	tt0433387
# 	role_code	:	2
# 	person_id	:	70
# Role 164
# --------
# 	movie_id	:	tt0433387
# 	role_code	:	2
# 	person_id	:	116
# Role 165
# --------
# 	movie_id	:	tt0433387
# 	role_code	:	2
# 	person_id	:	32
# Role 166
# --------
# 	movie_id	:	tt0114746
# 	role_code	:	0
# 	person_id	:	98
# Role 167
# --------
# 	movie_id	:	tt0114746
# 	role_code	:	1
# 	person_id	:	65
# Role 168
# --------
# 	movie_id	:	tt0114746
# 	role_code	:	2
# 	person_id	:	21
# Role 169
# --------
# 	movie_id	:	tt0114746
# 	role_code	:	2
# 	person_id	:	66
# Role 170
# --------
# 	movie_id	:	tt0114746
# 	role_code	:	2
# 	person_id	:	6
#
# =======================
# ||                   ||
# ||     11. Award     ||
# ||                   ||
# =======================
# Award 0
# -------
# 	award_id	:	0
# 	movie_id	:	tt0859635
# 	person_id	:	None
# 	award_text	:	Golden Trailer Nominee: Best Radio/Audio Spot
# Award 1
# -------
# 	award_id	:	1
# 	movie_id	:	tt0859635
# 	person_id	:	None
# 	award_text	:	Golden Trailer Winner: Best Teaser Poster
# Award 2
# -------
# 	award_id	:	2
# 	movie_id	:	tt0859635
# 	person_id	:	None
# 	award_text	:	Golden Trailer Winner: Best Trailerbyte for a Feature Film
# Award 3
# -------
# 	award_id	:	3
# 	movie_id	:	tt0486551
# 	person_id	:	None
# 	award_text	:	Stinker Award Nominee: Most Painfully Unfunny Comedy
# Award 4
# -------
# 	award_id	:	4
# 	movie_id	:	tt0486551
# 	person_id	:	None
# 	award_text	:	Stinker Award Nominee: Most Annoying Fake Accent: Female
# Award 5
# -------
# 	award_id	:	5
# 	movie_id	:	tt0456554
# 	person_id	:	None
# 	award_text	:	Razzie Award Nominee: Worst Actor of the Decade
# Award 6
# -------
# 	award_id	:	6
# 	movie_id	:	tt0456554
# 	person_id	:	None
# 	award_text	:	Razzie Award Nominee: and
# Award 7
# -------
# 	award_id	:	7
# 	movie_id	:	tt0456554
# 	person_id	:	None
# 	award_text	:	Razzie Award Nominee:   Little Nicky
# Award 8
# -------
# 	award_id	:	8
# 	movie_id	:	tt0245686
# 	person_id	:	18
# 	award_text	:	Stinker Award Winner: Worst On-Screen Hairstyle
# Award 9
# -------
# 	award_id	:	9
# 	movie_id	:	tt0114694
# 	person_id	:	73
# 	award_text	:	MTV Movie Award Winner: Best On-Screen Duo
# Award 10
# --------
# 	award_id	:	10
# 	movie_id	:	tt0114694
# 	person_id	:	18
# 	award_text	:	MTV Movie Award Winner: Best On-Screen Duo
# Award 11
# --------
# 	award_id	:	11
# 	movie_id	:	tt0144557
# 	person_id	:	27
# 	award_text	:	Golden Starfish Award Winner: Best American Independent Film
# Award 12
# --------
# 	award_id	:	12
# 	movie_id	:	tt0144557
# 	person_id	:	27
# 	award_text	:	Golden Starfish Award Winner: Best American Independent Film
# Award 13
# --------
# 	award_id	:	13
# 	movie_id	:	tt0366551
# 	person_id	:	29
# 	award_text	:	MTV Movie Award Nominee: Best On-Screen Team
# Award 14
# --------
# 	award_id	:	14
# 	movie_id	:	tt0366551
# 	person_id	:	76
# 	award_text	:	MTV Movie Award Nominee: Best On-Screen Team
# Award 15
# --------
# 	award_id	:	15
# 	movie_id	:	tt0077914
# 	person_id	:	None
# 	award_text	:	Special Award Winner: Best Rediscoveries
# Award 16
# --------
# 	award_id	:	16
# 	movie_id	:	tt0455407
# 	person_id	:	9
# 	award_text	:	Fright Meter Award Nominee: Best Director
# Award 17
# --------
# 	award_id	:	17
# 	movie_id	:	tt0455407
# 	person_id	:	119
# 	award_text	:	Scream Award Nominee: Best Horror Actor
# Award 18
# --------
# 	award_id	:	18
# 	movie_id	:	tt0095652
# 	person_id	:	None
# 	award_text	:	International Fantasy Film Award Winner George A. Romero Critics' Award Winner: Best Film
# Award 19
# --------
# 	award_id	:	19
# 	movie_id	:	tt1134854
# 	person_id	:	None
# 	award_text	:	Canadian Cinema Editors Award Nominee: Best Editing in Feature Length
# Award 20
# --------
# 	award_id	:	20
# 	movie_id	:	tt0088993
# 	person_id	:	55
# 	award_text	:	Caixa de Catalunya Winner: Best Actress
# Award 21
# --------
# 	award_id	:	21
# 	movie_id	:	tt0077402
# 	person_id	:	None
# 	award_text	:	Saturn Award Winner: Best DVD Classic Film Release
# Award 22
# --------
# 	award_id	:	22
# 	movie_id	:	tt0077402
# 	person_id	:	None
# 	award_text	:	Saturn Award Nominee: Best Make-Up
# Award 23
# --------
# 	award_id	:	23
# 	movie_id	:	tt0077402
# 	person_id	:	None
# 	award_text	:	Golden Satellite Award Nominee: Best Overall DVD
# Award 24
# --------
# 	award_id	:	24
# 	movie_id	:	tt0848557
# 	person_id	:	None
# 	award_text	:	Rondo Statuette Nominee: Best Film
# Award 25
# --------
# 	award_id	:	25
# 	movie_id	:	tt0418819
# 	person_id	:	118
# 	award_text	:	Chainsaw Award Winner: Best Actor
# Award 26
# --------
# 	award_id	:	26
# 	movie_id	:	tt0418819
# 	person_id	:	3
# 	award_text	:	Scream Award Nominee: Scream Queen
# Award 27
# --------
# 	award_id	:	27
# 	movie_id	:	tt0119177
# 	person_id	:	53
# 	award_text	:	Hugo Nominee: Best Dramatic Presentation
# Award 28
# --------
# 	award_id	:	28
# 	movie_id	:	tt0119177
# 	person_id	:	53
# 	award_text	:	Hugo Nominee: Best Dramatic Presentation
# Award 29
# --------
# 	award_id	:	29
# 	movie_id	:	tt0119177
# 	person_id	:	74
# 	award_text	:	OFTA Film Award Nominee: Best Sci-Fi/Fantasy/Horror Actor
# Award 30
# --------
# 	award_id	:	30
# 	movie_id	:	tt0253556
# 	person_id	:	7
# 	award_text	:	Rondo Statuette Nominee: Best Genre Film
# Award 31
# --------
# 	award_id	:	31
# 	movie_id	:	tt0119116
# 	person_id	:	103
# 	award_text	:	Stinker Award Nominee: Worst Sense of Direction (Stop them before they direct again!)
# Award 32
# --------
# 	award_id	:	32
# 	movie_id	:	tt0119116
# 	person_id	:	103
# 	award_text	:	Stinker Award Nominee: Worst Sense of Direction (Stop them before they direct again!)
# Award 33
# --------
# 	award_id	:	33
# 	movie_id	:	tt0119116
# 	person_id	:	21
# 	award_text	:	OFTA Film Award Winner: Best Sci-Fi/Fantasy/Horror Actor
# Award 34
# --------
# 	award_id	:	34
# 	movie_id	:	tt0448134
# 	person_id	:	11
# 	award_text	:	ALFS Award Nominee: British Director of the Year
# Award 35
# --------
# 	award_id	:	35
# 	movie_id	:	tt0448134
# 	person_id	:	34
# 	award_text	:	Scream Award Nominee: Sci-Fi Star
# Award 36
# --------
# 	award_id	:	36
# 	movie_id	:	tt0361862
# 	person_id	:	80
# 	award_text	:	Narcisse Award Winner: Best Fantastic Feature Film
# Award 37
# --------
# 	award_id	:	37
# 	movie_id	:	tt0361862
# 	person_id	:	115
# 	award_text	:	Chainsaw Award Nominee: Best Screenplay
# Award 38
# --------
# 	award_id	:	38
# 	movie_id	:	tt0361862
# 	person_id	:	70
# 	award_text	:	ALFS Award Nominee: British Actor of the Year
# Award 39
# --------
# 	award_id	:	39
# 	movie_id	:	tt0118929
# 	person_id	:	33
# 	award_text	:	Saturn Award Winner: Best Director
# Award 40
# --------
# 	award_id	:	40
# 	movie_id	:	tt0118929
# 	person_id	:	33
# 	award_text	:	Saturn Award Winner: Best Director
# Award 41
# --------
# 	award_id	:	41
# 	movie_id	:	tt0118929
# 	person_id	:	88
# 	award_text	:	OFTA Film Award Winner: Best Sci-Fi/Fantasy/Horror Actor
# Award 42
# --------
# 	award_id	:	42
# 	movie_id	:	tt1182345
# 	person_id	:	101
# 	award_text	:	BAFTA Film Award Winner: Outstanding Debut by a British Writer, Director or Producer
# Award 43
# --------
# 	award_id	:	43
# 	movie_id	:	tt1182345
# 	person_id	:	101
# 	award_text	:	BAFTA Film Award Winner: Outstanding Debut by a British Writer, Director or Producer
# Award 44
# --------
# 	award_id	:	44
# 	movie_id	:	tt1182345
# 	person_id	:	4
# 	award_text	:	Golden Space Needle Award Winner: Best Actor
# Award 45
# --------
# 	award_id	:	45
# 	movie_id	:	tt0118884
# 	person_id	:	41
# 	award_text	:	Saturn Award Winner: Best Director
# Award 46
# --------
# 	award_id	:	46
# 	movie_id	:	tt0118884
# 	person_id	:	112
# 	award_text	:	Audience Award Winner: Best Actress
# Award 47
# --------
# 	award_id	:	47
# 	movie_id	:	tt0118884
# 	person_id	:	36
# 	award_text	:	Blockbuster Entertainment Award Nominee: Favorite Actor - Drama
# Award 48
# --------
# 	award_id	:	48
# 	movie_id	:	tt0462504
# 	person_id	:	70
# 	award_text	:	Satellite Award Nominee: Best Actor in a Motion Picture, Drama
# Award 49
# --------
# 	award_id	:	49
# 	movie_id	:	tt0462504
# 	person_id	:	19
# 	award_text	:	Independent Spirit Award Nominee: Best Supporting Male
# Award 50
# --------
# 	award_id	:	50
# 	movie_id	:	tt0381849
# 	person_id	:	56
# 	award_text	:	Actor Nominee: Outstanding Performance by a Cast in a Motion Picture
# Award 51
# --------
# 	award_id	:	51
# 	movie_id	:	tt0381849
# 	person_id	:	70
# 	award_text	:	Actor Nominee: Outstanding Performance by a Cast in a Motion Picture
# Award 52
# --------
# 	award_id	:	52
# 	movie_id	:	tt0433387
# 	person_id	:	70
# 	award_text	:	DFCC Nominee: Best Actor
# Award 53
# --------
# 	award_id	:	53
# 	movie_id	:	tt0114746
# 	person_id	:	98
# 	award_text	:	Empire Award Winner: Best Director
# Award 54
# --------
# 	award_id	:	54
# 	movie_id	:	tt0114746
# 	person_id	:	65
# 	award_text	:	Hugo Nominee: Best Dramatic Presentation
# Award 55
# --------
# 	award_id	:	55
# 	movie_id	:	tt0114746
# 	person_id	:	21
# 	award_text	:	Saturn Award Winner: Best Actor
#
# ==========================
# ||                      ||
# ||     12. RoleCode     ||
# ||                      ||
# ==========================
# RoleCode 0
# ----------
# 	role_code	:	0
# 	role_name	:	Director
# RoleCode 1
# ----------
# 	role_code	:	1
# 	role_name	:	Writer
# RoleCode 2
# ----------
# 	role_code	:	2
# 	role_name	:	Actor

# %% [markdown]
# # Load: generate INSERT INTO statements

# %%
x
# Out:
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0859635", 2018, "Super Troopers 2", 13500000, 31626386, 100);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0486551", 2006, "Beerfest", 17500000, 20387597, 110);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0331953", 2004, "Club Dread", 8600000, 7565807, 104);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0456554", 2006, "Grandma's Boy", Null, 6566277, 94);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt1135525", 2009, "The Slammin' Salmon", Null, 60421, 99);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0245686", 2001, "Joe Dirt", 17700000, 30987695, 91);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0114694", 1995, "Tommy Boy", Null, 32679899, 97);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0115697", 1996, "Black Sheep", Null, 32417995, 87);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0144557", 1996, "Puddle Cruiser", 160000, Null, 102);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0348333", 2005, "Waiting...", 3000000, 18637690, 94);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0366551", 2004, "Harold & Kumar Go to White Castle", 9000000, 23936908, 88);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0069239", 1972, "Season of the Witch", 90000, Null, 130);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0077914", 1977, "Martin", 80000, Null, 95);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0455407", 2010, "The Crazies", 20000000, 54806823, 101);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0166843", 1971, "There's Always Vanilla", 70000, Null, 93);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0095652", 1988, "Monkey Shines", 7000000, 5344577, 113);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt1134854", 2009, "Survival of the Dead", 4000000, 386078, 90);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0088993", 1985, "Day of the Dead", 3500000, 5000000, 96);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0082622", 1981, "Knightriders", 3000000, Null, 146);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0077402", 1978, "Dawn of the Dead", 650000, 159822, 127);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0848557", 2007, "Diary of the Dead", 2000000, 5540941, 95);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0067341", 1971, "Let's Scare Jessica to Death", 180000, Null, 89);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0418819", 2005, "Land of the Dead", 15000000, 47074133, 93);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0119177", 1997, "Gattaca", 36000000, 12532777, 106);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0253556", 2002, "Reign of Fire", 60000000, 82150183, 101);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0119116", 1997, "The Fifth Element", 93000000, 263920180, 126);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0448134", 2007, "Sunshine", Null, 34806360, 107);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0361862", 2004, "The Machinist", 5000000, 8203235, 101);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0118929", 1998, "Dark City", 27000000, 27200316, 100);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt1182345", 2009, "Moon", 5000000, 9760107, 97);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0118884", 1997, "Contact", 90000000, 171120329, 150);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0462504", 2006, "Rescue Dawn", 10000000, 7177143, 120);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0381849", 2007, "3:10 to Yuma", 55000000, 70016220, 122);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0433387", 2005, "Harsh Times", 2000000, 5969708, 116);
# INSERT INTO Movie (movie_id, movie_year, movie_title, movie_budget, movie_boxoffice, movie_runtime) VALUES ("tt0114746", 1995, "12 Monkeys", 29000001, 168839459, 129);
#
# INSERT INTO Production (production_id, production_name) VALUES (0, "Element Films");
# INSERT INTO Production (production_id, production_name) VALUES (1, "Gibraltar Films");
# INSERT INTO Production (production_id, production_name) VALUES (2, "Votiv Films");
# INSERT INTO Production (production_id, production_name) VALUES (3, "UK Film Council");
# INSERT INTO Production (production_id, production_name) VALUES (4, "Moving Picture Company (MPC)");
# INSERT INTO Production (production_id, production_name) VALUES (5, "Cataland Films");
# INSERT INTO Production (production_id, production_name) VALUES (6, "Classico");
# INSERT INTO Production (production_id, production_name) VALUES (7, "Participant");
# INSERT INTO Production (production_id, production_name) VALUES (8, "Overture Films");
# INSERT INTO Production (production_id, production_name) VALUES (9, "Liberty Films UK");
# INSERT INTO Production (production_id, production_name) VALUES (10, "DNA Films");
# INSERT INTO Production (production_id, production_name) VALUES (11, "Kingsgate Films");
# INSERT INTO Production (production_id, production_name) VALUES (12, "The Latent Image");
# INSERT INTO Production (production_id, production_name) VALUES (13, "Universal Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (14, "Ingenious Film Partners");
# INSERT INTO Production (production_id, production_name) VALUES (15, "New Romero");
# INSERT INTO Production (production_id, production_name) VALUES (16, "Orion Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (17, "Laurel Productons");
# INSERT INTO Production (production_id, production_name) VALUES (18, "Twelve Monkeys Productions");
# INSERT INTO Production (production_id, production_name) VALUES (19, "Crave Films");
# INSERT INTO Production (production_id, production_name) VALUES (20, "Columbia Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (21, "Gaumont");
# INSERT INTO Production (production_id, production_name) VALUES (22, "Spyglass Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (23, "Broken Lizard Industries");
# INSERT INTO Production (production_id, production_name) VALUES (24, "Castelao Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (25, "Dawn Associates");
# INSERT INTO Production (production_id, production_name) VALUES (26, "Eden Rock Media");
# INSERT INTO Production (production_id, production_name) VALUES (27, "Sony Pictures Classics");
# INSERT INTO Production (production_id, production_name) VALUES (28, "Fox Searchlight Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (29, "Imagenation Abu Dhabi FZ");
# INSERT INTO Production (production_id, production_name) VALUES (30, "Yuma");
# INSERT INTO Production (production_id, production_name) VALUES (31, "The Jessica Company");
# INSERT INTO Production (production_id, production_name) VALUES (32, "Level 1 Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (33, "Mystery Clock Cinema");
# INSERT INTO Production (production_id, production_name) VALUES (34, "Coconut Pete Productions");
# INSERT INTO Production (production_id, production_name) VALUES (35, "Jersey Films");
# INSERT INTO Production (production_id, production_name) VALUES (36, "Blue Rider Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (37, "Adobe Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (38, "Touchstone Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (39, "Independent");
# INSERT INTO Production (production_id, production_name) VALUES (40, "Metro-Goldwyn-Mayer (MGM)");
# INSERT INTO Production (production_id, production_name) VALUES (41, "Twentieth Century Fox");
# INSERT INTO Production (production_id, production_name) VALUES (42, "Relativity Media");
# INSERT INTO Production (production_id, production_name) VALUES (43, "Needle's Eye Productions");
# INSERT INTO Production (production_id, production_name) VALUES (44, "Bruin Grip Services");
# INSERT INTO Production (production_id, production_name) VALUES (45, "Happy Madison Productions");
# INSERT INTO Production (production_id, production_name) VALUES (46, "Exception Wild Bunch");
# INSERT INTO Production (production_id, production_name) VALUES (47, "Filmax Group");
# INSERT INTO Production (production_id, production_name) VALUES (48, "Andrea Sperling Productions");
# INSERT INTO Production (production_id, production_name) VALUES (49, "Sudden Storm Productions");
# INSERT INTO Production (production_id, production_name) VALUES (50, "Castelao Producciones");
# INSERT INTO Production (production_id, production_name) VALUES (51, "Laurel Entertainment Inc.");
# INSERT INTO Production (production_id, production_name) VALUES (52, "C.M. Films");
# INSERT INTO Production (production_id, production_name) VALUES (53, "Braddock Associates");
# INSERT INTO Production (production_id, production_name) VALUES (54, "Romero-Grunwald Productions");
# INSERT INTO Production (production_id, production_name) VALUES (55, "United Film Distribution Company (UFDC)");
# INSERT INTO Production (production_id, production_name) VALUES (56, "At Play With the Angels");
# INSERT INTO Production (production_id, production_name) VALUES (57, "Rangerkim");
# INSERT INTO Production (production_id, production_name) VALUES (58, "Blank of the Dead Productions");
# INSERT INTO Production (production_id, production_name) VALUES (59, "Top Gun Productions");
# INSERT INTO Production (production_id, production_name) VALUES (60, "Limelight Fund");
# INSERT INTO Production (production_id, production_name) VALUES (61, "Wisenheimer Films");
# INSERT INTO Production (production_id, production_name) VALUES (62, "The Zanuck Company");
# INSERT INTO Production (production_id, production_name) VALUES (63, "New Line Cinema");
# INSERT INTO Production (production_id, production_name) VALUES (64, "Tree Line Film");
# INSERT INTO Production (production_id, production_name) VALUES (65, "Laurel Group");
# INSERT INTO Production (production_id, production_name) VALUES (66, "Robert Simonds Productions");
# INSERT INTO Production (production_id, production_name) VALUES (67, "Harsh Times");
# INSERT INTO Production (production_id, production_name) VALUES (68, "Penn Station Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (69, "World 2000 Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (70, "Thema Production");
# INSERT INTO Production (production_id, production_name) VALUES (71, "Devonshire Productions");
# INSERT INTO Production (production_id, production_name) VALUES (72, "Laurel Productions");
# INSERT INTO Production (production_id, production_name) VALUES (73, "Paramount Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (74, "Senator International");
# INSERT INTO Production (production_id, production_name) VALUES (75, "Canal+ España");
# INSERT INTO Production (production_id, production_name) VALUES (76, "Broadway Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (77, "Stage 6 Films");
# INSERT INTO Production (production_id, production_name) VALUES (78, "Instituto de la Cinematografía y de las Ar...");
# INSERT INTO Production (production_id, production_name) VALUES (79, "Gerber Pictures");
# INSERT INTO Production (production_id, production_name) VALUES (80, "South Side Amusement Company");
# INSERT INTO Production (production_id, production_name) VALUES (81, "L.I.F.T. Production");
# INSERT INTO Production (production_id, production_name) VALUES (82, "Tripod Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (83, "Heretical Reason Productions");
# INSERT INTO Production (production_id, production_name) VALUES (84, "Artfire Films");
# INSERT INTO Production (production_id, production_name) VALUES (85, "Pinewood Studios");
# INSERT INTO Production (production_id, production_name) VALUES (86, "Lionsgate");
# INSERT INTO Production (production_id, production_name) VALUES (87, "Harold & Kumar");
# INSERT INTO Production (production_id, production_name) VALUES (88, "Atmosphere Entertainment MM");
# INSERT INTO Production (production_id, production_name) VALUES (89, "Xingu Films");
# INSERT INTO Production (production_id, production_name) VALUES (90, "Lunar Industries");
# INSERT INTO Production (production_id, production_name) VALUES (91, "ICF");
# INSERT INTO Production (production_id, production_name) VALUES (92, "Atlas Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (93, "Ontario Media Development Corporation (OMDC)");
# INSERT INTO Production (production_id, production_name) VALUES (94, "Legendary Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (95, "Warner Bros.");
# INSERT INTO Production (production_id, production_name) VALUES (96, "Endgame Entertainment");
# INSERT INTO Production (production_id, production_name) VALUES (97, "Wild Bunch");
#
# INSERT INTO Genre (genre_id, genre_name) VALUES (0, "Horror");
# INSERT INTO Genre (genre_id, genre_name) VALUES (1, "Mystery");
# INSERT INTO Genre (genre_id, genre_name) VALUES (2, "Thriller");
# INSERT INTO Genre (genre_id, genre_name) VALUES (3, "Action");
# INSERT INTO Genre (genre_id, genre_name) VALUES (4, "Fantasy");
# INSERT INTO Genre (genre_id, genre_name) VALUES (5, "Adventure");
# INSERT INTO Genre (genre_id, genre_name) VALUES (6, "Biography");
# INSERT INTO Genre (genre_id, genre_name) VALUES (7, "Western");
# INSERT INTO Genre (genre_id, genre_name) VALUES (8, "Romance");
# INSERT INTO Genre (genre_id, genre_name) VALUES (9, "War");
# INSERT INTO Genre (genre_id, genre_name) VALUES (10, "Crime");
# INSERT INTO Genre (genre_id, genre_name) VALUES (11, "Drama");
# INSERT INTO Genre (genre_id, genre_name) VALUES (12, "Comedy");
# INSERT INTO Genre (genre_id, genre_name) VALUES (13, "Sci-Fi");
#
# INSERT INTO Person (person_id, person_name) VALUES (0, "Ethan Embry ");
# INSERT INTO Person (person_id, person_name) VALUES (1, "Shawn Roberts ");
# INSERT INTO Person (person_id, person_name) VALUES (2, "Ben Foster ");
# INSERT INTO Person (person_id, person_name) VALUES (3, "Asia Argento");
# INSERT INTO Person (person_id, person_name) VALUES (4, "Sam Rockwell");
# INSERT INTO Person (person_id, person_name) VALUES (5, "Jon Hurwitz,");
# INSERT INTO Person (person_id, person_name) VALUES (6, "Brad Pitt ");
# INSERT INTO Person (person_id, person_name) VALUES (7, "Rob Bowman");
# INSERT INTO Person (person_id, person_name) VALUES (8, "Danielle Panabaker ");
# INSERT INTO Person (person_id, person_name) VALUES (9, "Breck Eisner");
# INSERT INTO Person (person_id, person_name) VALUES (10, "Brian Dennehy ");
# INSERT INTO Person (person_id, person_name) VALUES (11, "Danny Boyle");
# INSERT INTO Person (person_id, person_name) VALUES (12, "Brittany Daniel");
# INSERT INTO Person (person_id, person_name) VALUES (13, "Jason Beghe");
# INSERT INTO Person (person_id, person_name) VALUES (14, "David Emge");
# INSERT INTO Person (person_id, person_name) VALUES (15, "Dominique McElligott ");
# INSERT INTO Person (person_id, person_name) VALUES (16, "Uma Thurman");
# INSERT INTO Person (person_id, person_name) VALUES (17, "Simon Baker ");
# INSERT INTO Person (person_id, person_name) VALUES (18, "David Spade");
# INSERT INTO Person (person_id, person_name) VALUES (19, "Steve Zahn");
# INSERT INTO Person (person_id, person_name) VALUES (20, "John Francis Daley ");
# INSERT INTO Person (person_id, person_name) VALUES (21, "Bruce Willis");
# INSERT INTO Person (person_id, person_name) VALUES (22, "Raymond Laine");
# INSERT INTO Person (person_id, person_name) VALUES (23, "Michael Clarke Duncan");
# INSERT INTO Person (person_id, person_name) VALUES (24, "Alan Van Sprang");
# INSERT INTO Person (person_id, person_name) VALUES (25, "Joshua Close");
# INSERT INTO Person (person_id, person_name) VALUES (26, "Kiefer Sutherland");
# INSERT INTO Person (person_id, person_name) VALUES (27, "Jay Chandrasekhar");
# INSERT INTO Person (person_id, person_name) VALUES (28, "Jude Law ");
# INSERT INTO Person (person_id, person_name) VALUES (29, "John Cho");
# INSERT INTO Person (person_id, person_name) VALUES (30, "Ann Muffly ");
# INSERT INTO Person (person_id, person_name) VALUES (31, "Jan White");
# INSERT INTO Person (person_id, person_name) VALUES (32, "Eva Longoria ");
# INSERT INTO Person (person_id, person_name) VALUES (33, "Alex Proyas");
# INSERT INTO Person (person_id, person_name) VALUES (34, "Cillian Murphy");
# INSERT INTO Person (person_id, person_name) VALUES (35, "Barry Wernick,");
# INSERT INTO Person (person_id, person_name) VALUES (36, "Matthew McConaughey");
# INSERT INTO Person (person_id, person_name) VALUES (37, "Christine Forrest ");
# INSERT INTO Person (person_id, person_name) VALUES (38, "Jeremy Davies ");
# INSERT INTO Person (person_id, person_name) VALUES (39, "Joseph Pilato ");
# INSERT INTO Person (person_id, person_name) VALUES (40, "Bill Paxton");
# INSERT INTO Person (person_id, person_name) VALUES (41, "Robert Zemeckis");
# INSERT INTO Person (person_id, person_name) VALUES (42, "Izabella Scorupco ");
# INSERT INTO Person (person_id, person_name) VALUES (43, "Shirley Jones ");
# INSERT INTO Person (person_id, person_name) VALUES (44, "Milla Jovovich");
# INSERT INTO Person (person_id, person_name) VALUES (45, "Scott H. Reiniger ");
# INSERT INTO Person (person_id, person_name) VALUES (46, "Werner Herzog");
# INSERT INTO Person (person_id, person_name) VALUES (47, "Halsted Welles");
# INSERT INTO Person (person_id, person_name) VALUES (48, "Danny Leiner");
# INSERT INTO Person (person_id, person_name) VALUES (49, "Rudy Ricci");
# INSERT INTO Person (person_id, person_name) VALUES (50, "Lincoln Maazel");
# INSERT INTO Person (person_id, person_name) VALUES (51, "George A.");
# INSERT INTO Person (person_id, person_name) VALUES (52, "Anna Faris");
# INSERT INTO Person (person_id, person_name) VALUES (53, "Andrew Niccol");
# INSERT INTO Person (person_id, person_name) VALUES (54, "Michael Stewart");
# INSERT INTO Person (person_id, person_name) VALUES (55, "Lori Cardille");
# INSERT INTO Person (person_id, person_name) VALUES (56, "Russell Crowe");
# INSERT INTO Person (person_id, person_name) VALUES (57, "Penelope Spheeris");
# INSERT INTO Person (person_id, person_name) VALUES (58, "Ed Harris");
# INSERT INTO Person (person_id, person_name) VALUES (59, "Peter Segal");
# INSERT INTO Person (person_id, person_name) VALUES (60, "Allen Covert");
# INSERT INTO Person (person_id, person_name) VALUES (61, "Johanna Lawrence ");
# INSERT INTO Person (person_id, person_name) VALUES (62, "John Pankow");
# INSERT INTO Person (person_id, person_name) VALUES (63, "Jennifer Jason Leigh");
# INSERT INTO Person (person_id, person_name) VALUES (64, "Jennifer Connelly ");
# INSERT INTO Person (person_id, person_name) VALUES (65, "Chris Marker");
# INSERT INTO Person (person_id, person_name) VALUES (66, "Madeleine Stowe");
# INSERT INTO Person (person_id, person_name) VALUES (67, "Dennie Gordon");
# INSERT INTO Person (person_id, person_name) VALUES (68, "Rose Byrne");
# INSERT INTO Person (person_id, person_name) VALUES (69, "Steve Lemme ");
# INSERT INTO Person (person_id, person_name) VALUES (70, "Christian Bale");
# INSERT INTO Person (person_id, person_name) VALUES (71, "Kevin Heffernan");
# INSERT INTO Person (person_id, person_name) VALUES (72, "Bonnie Turner,");
# INSERT INTO Person (person_id, person_name) VALUES (73, "Chris Farley");
# INSERT INTO Person (person_id, person_name) VALUES (74, "Ethan Hawke");
# INSERT INTO Person (person_id, person_name) VALUES (75, "James V.");
# INSERT INTO Person (person_id, person_name) VALUES (76, "Kal Penn");
# INSERT INTO Person (person_id, person_name) VALUES (77, "Ken Foree");
# INSERT INTO Person (person_id, person_name) VALUES (78, "Aitana Sánchez-Gijón ");
# INSERT INTO Person (person_id, person_name) VALUES (79, "Fred Wolf");
# INSERT INTO Person (person_id, person_name) VALUES (80, "Brad Anderson");
# INSERT INTO Person (person_id, person_name) VALUES (81, "Gary Lahti");
# INSERT INTO Person (person_id, person_name) VALUES (82, "Zohra Lampert");
# INSERT INTO Person (person_id, person_name) VALUES (83, "Judith Ridley");
# INSERT INTO Person (person_id, person_name) VALUES (84, "Radha Mitchell");
# INSERT INTO Person (person_id, person_name) VALUES (85, "Tom Savini ");
# INSERT INTO Person (person_id, person_name) VALUES (86, "David Spade,");
# INSERT INTO Person (person_id, person_name) VALUES (87, "Kate McNeil ");
# INSERT INTO Person (person_id, person_name) VALUES (88, "Rufus Sewell");
# INSERT INTO Person (person_id, person_name) VALUES (89, "Linda Cardellini");
# INSERT INTO Person (person_id, person_name) VALUES (90, "Gary Oldman ");
# INSERT INTO Person (person_id, person_name) VALUES (91, "Kevin O'Connor ");
# INSERT INTO Person (person_id, person_name) VALUES (92, "Gregg Chabot");
# INSERT INTO Person (person_id, person_name) VALUES (93, "Kathleen Munroe ");
# INSERT INTO Person (person_id, person_name) VALUES (94, "Chris Evans ");
# INSERT INTO Person (person_id, person_name) VALUES (95, "John D.");
# INSERT INTO Person (person_id, person_name) VALUES (96, "Kenneth Welsh");
# INSERT INTO Person (person_id, person_name) VALUES (97, "Alex Garland");
# INSERT INTO Person (person_id, person_name) VALUES (98, "Terry Gilliam");
# INSERT INTO Person (person_id, person_name) VALUES (99, "Nicholaus Goossen");
# INSERT INTO Person (person_id, person_name) VALUES (100, "John Amplas");
# INSERT INTO Person (person_id, person_name) VALUES (101, "Duncan Jones");
# INSERT INTO Person (person_id, person_name) VALUES (102, "Kevin Heffernan ");
# INSERT INTO Person (person_id, person_name) VALUES (103, "Luc Besson");
# INSERT INTO Person (person_id, person_name) VALUES (104, "David Ayer");
# INSERT INTO Person (person_id, person_name) VALUES (105, "Dennis Miller ");
# INSERT INTO Person (person_id, person_name) VALUES (106, "Michelle Morgan");
# INSERT INTO Person (person_id, person_name) VALUES (107, "Kevin Spacey");
# INSERT INTO Person (person_id, person_name) VALUES (108, "Ryan Reynolds");
# INSERT INTO Person (person_id, person_name) VALUES (109, "Barton Heyman");
# INSERT INTO Person (person_id, person_name) VALUES (110, "Terry Alexander");
# INSERT INTO Person (person_id, person_name) VALUES (111, "James Mangold");
# INSERT INTO Person (person_id, person_name) VALUES (112, "Jodie Foster");
# INSERT INTO Person (person_id, person_name) VALUES (113, "Tim Matheson ");
# INSERT INTO Person (person_id, person_name) VALUES (114, "Tom Skerritt ");
# INSERT INTO Person (person_id, person_name) VALUES (115, "Scott Kosar");
# INSERT INTO Person (person_id, person_name) VALUES (116, "Freddy Rodríguez");
# INSERT INTO Person (person_id, person_name) VALUES (117, "Rob McKittrick");
# INSERT INTO Person (person_id, person_name) VALUES (118, "John Leguizamo");
# INSERT INTO Person (person_id, person_name) VALUES (119, "Timothy Olyphant");
#
# INSERT INTO RoleCode (role_code, role_name) VALUES (0, "Director");
# INSERT INTO RoleCode (role_code, role_name) VALUES (1, "Writer");
# INSERT INTO RoleCode (role_code, role_name) VALUES (2, "Actor");
#
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (0, "tt0859635", "When a border dispute arises between the U.S. and Canada, the Super Troopers are tasked with establishing a Highway Patrol station in the disputed area.
#
# —Fox Searchlight Pictures");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (1, "tt0859635", "Several years after the first film, the officers have been fired from the Spurbury Police Department after taking Fred Savage on a ride-along that resulted in his death. Farva (Heffernan) is now a construction supervisor, with Mac (Lemme) and Rabbit (Stolhanske) working for him. Thorny (Chandrasekhar) works in logging, and Foster (Soter) is living with his girlfriend and former coworker, Spurbu...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (2, "tt0486551", "Two brothers travel to Germany for Oktoberfest, only to stumble upon a secret, centuries-old competition described as a 'Fight Club' with beer games.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (3, "tt0486551", "After the death of their grandfather Johann von Wolfhause, the brothers Jan and Todd Wolfhouse travel to Munich to fulfill a family tradition, spreading the ashes of Johann during the Oktoberfest. Their contact brings them to a secret beer competition, the Beerfest', where they are offended by Baron Wolfgang von Wolfhausen and the German branch of their family that accuse their great-grandmothe...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (4, "tt0331953", "When a serial killer interrupts the fun at the swanky Coconut Pete's Coconut Beach Resort--a hedonistic island paradise for swingers--it's up to the club's staff to stop the violence...or at least hide it.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (5, "tt0331953", "Broken Lizard is surrounded by limber, wanton women on a booze-soaked island resort owned by Coconut Pete, a rock star has-been. But the non-stop party takes a turn for the weird when dead bodies start turning up. Everyone begins to look suspicious. Could it be Sam, of the Fun Police brigade, who is quick-on-the-trigger with his tequila-loaded Super Soaker; Jenny, the over-sexed fitness instruc...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (6, "tt0456554", "A thirty-five-year-old video game tester has to move in with his grandma and her two old lady roommates.");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (7, "tt0456554", "When his roommate spends the rent money on hookers, Alex, a 35 year old video game tester has to find a new place to live. After an 'encounter' with his friend's mom, Alex is forced to move in with his grandmother. Trying to save face with his younger co-workers, Alex says that 'a really cute chick said I could sleep with her and her two crazy girlfriends' (meaning his grandmother and her two r...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (8, "tt1135525", "The owner of a Miami restaurant indebted to the mob institutes a contest to see what waiter can earn the most money in one night.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (9, "tt1135525", "The brutal former heavyweight boxing champion Cleon 'Slammin'' Salmon, now owner of a Miami restaurant, institutes a competition to see which waiter can earn the most money in one night: the winner stands to gain $10,000, while the loser will endure a beating at the hands of the champ.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (10, "tt0245686", "After being abandoned by his parents at the Grand Canyon, Joe Dirt tells the story of his journey to find his parents.");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (11, "tt0245686", "Joe Dirt is a janitor with a mullet hairdo, acid-washed jeans and a dream to find the parents that he lost at the Grand Canyon when he was a belligerent, trailer park-raised eight-year-old. Now, blasting Van Halen in his jacked-up economy car, the irrepressibly optimistic Joe hits the road alone in search of his folks. As his wandering, misguided search takes him from one hilarious misadventure...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (12, "tt0114694", "After his auto-parts tycoon father dies, the overweight, underachieving son teams up with a snide accountant to try and save the family business.
#
# —Dynasti Noble");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (13, "tt0114694", "Tommy Callahan Jr. is a slow-witted, clumsy guy who recently graduated college after attending for seven years. His father, Big Tom Callahan, owns an auto parts factory in Ohio. When Tommy arrives back home, he finds he has a position at the factory waiting for him. His dad also introduces Tommy to the new brake pad division of the factory and to Tommy's soon-to-be stepmother, Beverly, and her ...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (14, "tt0115697", "A gubernatorial candidate hires a wormy special assistant whose only job is to make sure the candidate's well-meaning but incompetent brother doesn't ruin the election.
#
# —<jgp3553@yahoo.com>");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (15, "tt0115697", "Comedy about the prospective Washington State Governor Al Donnelly whose only stumbling block on the road to power is his embarrassing younger brother Mike. To keep him out of mischief, Al forces one of his aides, Steve Dodds to keep an eye on him during the election. However, this is easier said than done...
#
# —Jonathan Broxton <j.w.broxton@sheffield.ac.uk>");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (16, "tt0144557", "A student falls in love with a fellow student who is defending his buddies in university court. He 'proves his love' (more like his masculinity) to her by playing rugby against her ex-boyfriend.
#
# —Tristan Lawrence <tlawrence@pmsystems.com>");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (17, "tt0348333", "Young employees at Shenaniganz restaurant collectively stave off boredom and adulthood with their antics.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (18, "tt0348333", "It's the dinner shift at Shenanigan's. Dan, the clueless boss, assigns Mitch, 22, a trainee, to Monty, the smooth talker who chases girls for one-night stands. Dean, a waiter, also 22, feels that life is passing him by. Dan offers him the assistant manager job and gives him until midnight to decide. Other waiters, cooks, and bus boys have their issues and personalities. Bishop, the dishwasher, ...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (19, "tt0366551", "A Korean-American office worker and his Indian-American stoner friend embark on a quest to satisfy their desire for White Castle burgers.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (20, "tt0366551", "Harold Lee and Kumar Patel are two stoners who end up getting the munchies. What they crave the most after seeing a TV advertisement, is a trip to White Castle. So from here, follows a journey for the burgers they require. On their way they will encounter many obstacles including a raccoon, a racist officer, and a horny Neil Patrick Harris.
#
# —Film_Fan");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (21, "tt0069239", "A neglected, unhappy suburban housewife with gets mixed up in witchcraft with unexpected consequences.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (22, "tt0069239", "Joan Mitchell is an alienated suburban housewife pushing 40, who has a boorish businessman husband and a distant, distracted 19-year-old daughter whose, on the verge of moving out of the house. Frustrated at her current situation, Joan seeks solace in witchcraft after visiting Marion Hamilton, a local tarot reader and leader of a secret black arts wicca sect, who inspires Joan to follow her own...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (23, "tt0077914", "A young man, who believes himself to be a vampire, goes to live with his elderly and hostile cousin in a small Pennsylvania town where he tries to redeem his blood-craving urges.
#
# —matt-282");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (24, "tt0077914", "George Romero does for vampires what he has already done to zombies - an intense and realistic treatment that follows the exploits of Martin, who claims to be 84 years old, and who certainly drinks human blood. The boy arrives in Pittsburgh to stay with his cousin, who promises to save Martin's soul and destroy him once he is finished, but Martin's loneliness finds other means of release.
#
# —Dav...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (25, "tt0455407", "After a strange and insecure plane crash, an unusual toxic virus enters a quaint farming town. A young couple are quarantined, but they fight for survival along with help from a couple of people.
#
# —Bethan");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (26, "tt0455407", "As a toxin begins to turn the residents of Ogden Marsh, Iowa into violent psychopaths, sheriff David Dutton tries to make sense of the situation while he, his wife, and two other unaffected townspeople band together in a fight for survival.
#
# —ahmetkozan");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (27, "tt0166843", "A young man returns to his home city of Pittsburgh and moves in with an older woman whom he begins to rely on for emotional and financial support.
#
# —matt-282");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (28, "tt0166843", "Chris Bradley is a young man who returns to his home city of Pittsburgh after several years of drifting and working odd jobs around the country since his discharge from the U.S. Army. Rejecting moving back in with his father and not wanting to return to the family business of manufacturing baby food, Chris meets and shacks up with Lynn, an older woman who works as a model in local TV commercial...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (29, "tt0095652", "A quadriplegic man has a trained monkey help him with his paralysis, until the little monkey begins to develop feelings, and rage, against its new master.
#
# —Matt Patay");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (30, "tt0095652", "When Allan becomes a quadriplegic he loses all hope for living until he meets Ella - a monkey trained to fetch and carry for him around the house, obeying him in all things. But Ella is part of another experiment, and when she starts responding to Allan's underlying rage and frustration she has the ability to carry out her master's darkest wishes.
#
# —David Carroll <davidc@atom.ansto.gov.au>");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (31, "tt1134854", "On an island off the coast of North America, local residents simultaneously fight a zombie epidemic while hoping for a cure to return their un-dead relatives back to their human state.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (32, "tt1134854", "In the Plum Island, off the coast of Delaware, the long feud between the families of the patriarchs Captain Patrick O'Flynn (Kenneth Welsh) that intends to eliminate the zombies and Seamus Muldoon (Richard Fitzpatrick) that intends to keep his undead relatives waiting for a cure culminates with O'Flynn expelled from Plum. Meanwhile in the continent Sarge 'Nicotine' Crocket (Alan Van Sprang), Ch...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (33, "tt0088993", "A small group of military officers and scientists dwell in an underground bunker as the world above is overrun by zombies.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (34, "tt0088993", "Zombies rule the world, except for a small group of scientists and military personnel who reside in an underground bunker in Florida. The scientists are using the undead in gruesome experiments; much to the chagrin of the military. Finally the military finds that their men have been used in the scientists' experiments, and banish the scientists to the caves that house the Living Dead. Unfortuna...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (35, "tt0082622", "A medieval reenactment troupe find it increasingly difficult to keep their family-like group together, with pressure from local law enforcement, interest from entertainment agents and a growing sense of delusion from their leader.
#
# —Daniel Jos. Leary");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (36, "tt0082622", "A travelling troupe of jousters and performers are slowly cracking under the pressure of hick cops, financial troubles and their failure to live up to their own ideals. The group's leader, King Billy, is increasingly unable to maintain his warrior's rule while the Black Knight is being tempted away to LA and stardom, as they all have to ask why they were here in the first place.
#
# —David Carroll...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (37, "tt0077402", "Following an ever-growing epidemic of zombies that have risen from the dead, two Philadelphia S.W.A.T. team members, a traffic reporter, and his television executive girlfriend seek refuge in a secluded shopping mall.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (38, "tt0077402", "The zombie apocalypse has hit Earth. Two personnel from a TV station and two policemen set off in a helicopter to find a safe place to hide out. Their search leads them to a shopping mall where they manage to find a place that, while not zombie-free, is quite secure. So far, so good.
#
# —grantss");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (39, "tt0848557", "A group of young film students run into real-life zombies while filming a horror movie of their own.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (40, "tt0848557", "While filming a horror movie of mummy in a forest, the students and their professor of the University of Pittsburgh hear on the TV the news that the dead are awaking and walking. Ridley and Francine decide to leave the group, while Jason heads to the dormitory of his girlfriend Debra Monahan. She does not succeed in contacting her family and they travel in Mary's van to the house of Debra's par...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (41, "tt0067341", "A recently institutionalized woman has bizarre experiences after moving into a supposedly haunted country farmhouse and fears she may be losing her sanity once again.
#
# —Scott");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (42, "tt0067341", "After a stint in a psychiatric facility Jessica, her husband and a friend move to remote farm they have recently purchased. There they find a young woman by the name of Emily living in the house and they invite her to stay. When Jessica goes for a swim in the lake, she sees a body just below the water's surface. When they go into the village to sell some old furniture, they learn that a woman b...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (43, "tt0418819", "The living dead have taken over the world, and the last humans live in a walled city to protect themselves as they come to grips with the situation.
#
# —Erik Paniccia");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (44, "tt0418819", "Now that zombies have taken over the world, the living have built a walled-in city to keep the dead out. But all's not well where it's most safe, as a revolution plans to overthrow the city leadership, and the zombies are turning into more advanced creatures.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (45, "tt0119177", "A genetically inferior man assumes the identity of a superior one in order to pursue his lifelong dream of space travel.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (46, "tt0119177", "In the not-too-distant future, a less-than-perfect man wants to travel to the stars. Society has categorized Vincent Freeman as less than suitable given his genetic make-up and he has become one of the underclass of humans that are only useful for menial jobs. To move ahead, he assumes the identity of Jerome Morrow, a perfect genetic specimen who is a paraplegic as a result of a car accident. W...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (47, "tt0253556", "A brood of fire-breathing dragons emerges from the earth and begins setting everything ablaze, establishing dominance over the planet.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (48, "tt0253556", "In present-day London, 12-year-old Quinn Abercromby witnesses the awakening of a hibernating dragon from a centuries-long slumber, the result of a construction dig supervised by his mother and an incident for which Quinn feels partially responsible. Twenty years later, the adult Quinn (Christian Bale) is the fire chief of a refortified castle community, responsible for dousing the blazes lit by...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (49, "tt0119116", "In the colorful future, a cab driver unwittingly becomes the central figure in the search for a legendary cosmic weapon to keep Evil and Mr. Zorg at bay.
#
# —Murray Chapman");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (50, "tt0119116", "In the twenty-third century, the universe is threatened by evil. The only hope for mankind is the Fifth Element, who comes to Earth every five thousand years to protect the humans with four stones of the four elements: fire, water, Earth and air. A Mondoshawan spacecraft is bringing The Fifth Element back to Earth but it is destroyed by the evil Mangalores. However, a team of scientists use the...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (51, "tt0448134", "A team of international astronauts are sent on a dangerous mission to reignite the dying Sun with a nuclear fission bomb in 2057.
#
# —Skip4591");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (52, "tt0448134", "50 years into the future, the Sun begins to die, and Earth is dying as a result. A team of astronauts is sent to revive the Sun - but the mission fails. Seven years later, a new team is sent to finish the mission as mankind's last hope.
#
# —harpster_2004@yahoo.co.uk");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (53, "tt0361862", "An industrial worker who hasn't slept in a year begins to doubt his own sanity.
#
# —IMDb Editors");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (54, "tt0361862", "Trevor Reznik is a machinist in a factory. An extreme case of insomnia has led to him not sleeping in a year, and his body withering away to almost nothing. He has an obsessive compulsion to write himself reminder notes and keep track of his dwindling weight, both scribbled on yellow stickies in his apartment. The only person he lets into his life in an emotional sense is Stevie, a prostitute, ...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (55, "tt0118929", "A man struggles with memories of his past, which includes a wife he cannot remember, and a nightmarish world, no one else seems to be waking up from.
#
# —John Sacksteder <jsack@ka.net>");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (56, "tt0118929", "John Murdoch awakens alone in a strange hotel to find that he has lost his memory and is wanted for a series of brutal and bizarre murders. While trying to piece together his past, he stumbles upon a fiendish underworld controlled by a group of beings known as The Strangers who possess the ability to put people to sleep and alter the city and its inhabitants. Now Murdoch must find a way to stop...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (57, "tt1182345", "Astronaut Sam Bell has a quintessentially personal encounter toward the end of his three-year stint on the Moon, where he, working alongside his computer, GERTY, sends back to Earth parcels of a resource that has helped diminish our planet's power problems.
#
# —Anonymous");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (58, "tt1182345", "Sam Bell has a three year contract to work for Lunar Industries. For the contract's entire duration, he is the sole employee based at their lunar station. His primary job responsibility is to harvest and periodically rocket back to Earth supplies of helium-3, the current clean and abundant fuel used on Earth. There is no direct communication link available between the lunar station and Earth, s...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (59, "tt0118884", "Dr. Ellie Arroway, after years of searching, finds conclusive radio proof of extraterrestrial intelligence, sending plans for a mysterious machine.
#
# —Jon Reeves <jreeves@imdb.com>");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (60, "tt0118884", "Astronomer Dr. Ellie Arroway has long been interested in contact to faraway lands, a love fostered in her childhood by her father, Ted Arroway (David Morse), who died when she was nine-years-old, leaving her orphaned. Her current work in monitoring for extraterrestrial life is based on that love and is in part an homage to her father. Ever since funding from the National Science Foundation (N.S...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (61, "tt0462504", "A U.S. fighter pilot's epic struggle of survival after being shot down on a mission over Laos during the Vietnam War.");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (62, "tt0462504", "In 1965, while bombing Laos in a classified mission, the propeller plane of the German-American US Navy pilot Dieter Dengler is hit and crashes in the jungle. Dieter is arrested by the peasants, tortured by the Vietcong and sent to a prisoner camp, where he meets five other mentally deranged prisoners and guards. He becomes close to Duane and organizes an escape plan; however, the unstable Gene...");
# INSERT INTO Summary (summary_id, movie_id, summary_text) VALUES (63, "tt0381849", "A small-time rancher agrees to hold a captured outlaw who's awaiting a train to go to court in Yuma. A battle of wills ensues as the outlaw tries to psych out the rancher.
#
# —Anonymous");
# ...
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (40, "tt0118929", 33, "Saturn Award Winner: Best Director");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (41, "tt0118929", 88, "OFTA Film Award Winner: Best Sci-Fi/Fantasy/Horror Actor");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (42, "tt1182345", 101, "BAFTA Film Award Winner: Outstanding Debut by a British Writer, Director or Producer");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (43, "tt1182345", 101, "BAFTA Film Award Winner: Outstanding Debut by a British Writer, Director or Producer");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (44, "tt1182345", 4, "Golden Space Needle Award Winner: Best Actor");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (45, "tt0118884", 41, "Saturn Award Winner: Best Director");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (46, "tt0118884", 112, "Audience Award Winner: Best Actress");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (47, "tt0118884", 36, "Blockbuster Entertainment Award Nominee: Favorite Actor - Drama");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (48, "tt0462504", 70, "Satellite Award Nominee: Best Actor in a Motion Picture, Drama");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (49, "tt0462504", 19, "Independent Spirit Award Nominee: Best Supporting Male");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (50, "tt0381849", 56, "Actor Nominee: Outstanding Performance by a Cast in a Motion Picture");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (51, "tt0381849", 70, "Actor Nominee: Outstanding Performance by a Cast in a Motion Picture");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (52, "tt0433387", 70, "DFCC Nominee: Best Actor");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (53, "tt0114746", 98, "Empire Award Winner: Best Director");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (54, "tt0114746", 65, "Hugo Nominee: Best Dramatic Presentation");
# INSERT INTO Award (award_id, movie_id, person_id, award_text) VALUES (55, "tt0114746", 21, "Saturn Award Winner: Best Actor");
#
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0859635", 0, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0859635", 1, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0859635", 2, 71);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0859635", 2, 69);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0486551", 0, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0486551", 1, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0486551", 2, 71);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0486551", 2, 69);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0331953", 0, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0331953", 1, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0331953", 2, 40);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0331953", 2, 102);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0456554", 0, 99);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0456554", 1, 35);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0456554", 2, 60);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0456554", 2, 89);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0456554", 2, 43);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1135525", 0, 71);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1135525", 1, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1135525", 2, 23);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1135525", 2, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1135525", 2, 102);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0245686", 0, 67);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0245686", 1, 86);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0245686", 2, 18);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0245686", 2, 12);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0245686", 2, 105);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114694", 0, 59);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114694", 1, 72);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114694", 2, 73);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114694", 2, 18);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114694", 2, 10);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0115697", 0, 57);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0115697", 1, 79);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0115697", 2, 73);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0115697", 2, 18);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0115697", 2, 113);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0144557", 0, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0144557", 1, 27);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0144557", 2, 71);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0144557", 2, 69);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0348333", 0, 117);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0348333", 1, 117);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0348333", 2, 108);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0348333", 2, 52);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0348333", 2, 20);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0366551", 0, 48);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0366551", 1, 5);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0366551", 2, 29);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0366551", 2, 76);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0366551", 2, 0);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0069239", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0069239", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0069239", 2, 31);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0069239", 2, 22);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0069239", 2, 30);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077914", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077914", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077914", 2, 100);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077914", 2, 50);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077914", 2, 37);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0455407", 0, 9);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0455407", 1, 115);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0455407", 2, 84);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0455407", 2, 119);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0455407", 2, 8);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0166843", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0166843", 1, 49);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0166843", 2, 22);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0166843", 2, 83);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0166843", 2, 61);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0095652", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0095652", 1, 54);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0095652", 2, 13);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0095652", 2, 62);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0095652", 2, 87);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1134854", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1134854", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1134854", 2, 24);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1134854", 2, 96);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1134854", 2, 93);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0088993", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0088993", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0088993", 2, 55);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0088993", 2, 110);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0088993", 2, 39);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0082622", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0082622", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0082622", 2, 58);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0082622", 2, 81);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0082622", 2, 85);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077402", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077402", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077402", 2, 14);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077402", 2, 77);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0077402", 2, 45);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0848557", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0848557", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0848557", 2, 106);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0848557", 2, 25);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0848557", 2, 1);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0067341", 0, 95);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0067341", 1, 95);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0067341", 2, 82);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0067341", 2, 109);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0067341", 2, 91);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0418819", 0, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0418819", 1, 51);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0418819", 2, 118);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0418819", 2, 3);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0418819", 2, 17);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119177", 0, 53);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119177", 1, 53);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119177", 2, 74);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119177", 2, 16);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119177", 2, 28);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0253556", 0, 7);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0253556", 1, 92);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0253556", 2, 36);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0253556", 2, 70);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0253556", 2, 42);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119116", 0, 103);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119116", 1, 103);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119116", 2, 21);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119116", 2, 44);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0119116", 2, 90);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0448134", 0, 11);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0448134", 1, 97);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0448134", 2, 34);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0448134", 2, 68);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0448134", 2, 94);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0361862", 0, 80);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0361862", 1, 115);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0361862", 2, 70);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0361862", 2, 63);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0361862", 2, 78);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118929", 0, 33);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118929", 1, 33);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118929", 2, 88);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118929", 2, 26);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118929", 2, 64);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1182345", 0, 101);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1182345", 1, 101);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1182345", 2, 4);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1182345", 2, 107);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt1182345", 2, 15);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118884", 0, 41);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118884", 1, 75);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118884", 2, 112);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118884", 2, 36);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0118884", 2, 114);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0462504", 0, 46);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0462504", 1, 46);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0462504", 2, 70);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0462504", 2, 19);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0462504", 2, 38);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0381849", 0, 111);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0381849", 1, 47);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0381849", 2, 56);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0381849", 2, 70);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0381849", 2, 2);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0433387", 0, 104);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0433387", 1, 104);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0433387", 2, 70);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0433387", 2, 116);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0433387", 2, 32);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114746", 0, 98);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114746", 1, 65);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114746", 2, 21);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114746", 2, 66);
# INSERT INTO Role (movie_id, role_code, person_id) VALUES ("tt0114746", 2, 6);
